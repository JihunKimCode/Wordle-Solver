# %%
import random

# %%
# Load the list of possible words from the file
with open('../Dataset/reduced_possible_words.txt', 'r') as file:
    possible_words = [line.strip() for line in file]

# Load the list of words for testing from the file
with open('../Dataset/prev_words_chr.txt', 'r') as file:
    testing_set = [line.strip() for line in file]

# %%
# Define feedback symbols
MISS = "⬛"
MISPLACED = "🟨"
EXACT = "🟩"

# %%
# Function to evaluate a guess based on feedback
def evaluate_guess(secret_word, guess):
    guess_copy = guess
    feedback = []
    remaining_secret_letters = list(secret_word)
    # First, check exact matches (greens)
    for i, (g1, g2) in enumerate(zip(secret_word, guess_copy)):
        if g1 == g2:
            feedback.append("🟩")
            remaining_secret_letters.remove(g1)
            guess_copy = guess_copy[:i] + "🟩" + guess_copy[i+1:]
        else:
            feedback.append("⬛")
    feedback_str = "".join(feedback)
    # Then, check letters but not in location (yellows)
    for i, g2 in enumerate(guess_copy):
        if g2 in remaining_secret_letters:
            feedback_str = feedback_str[:i] + "🟨" + feedback_str[i+1:]
            remaining_secret_letters.remove(g2)
    feedback = feedback_str
    return "".join(feedback)

# %%
# Function to generate a random word from the list of possible words
def choose_random_word(list):
    word = random.choice(possible_words)
    while word in list: word = random.choice(possible_words)
    return word

# %%
# Bayesian algorithm for word selection
def bayesian_choose_word(possible_words, previous_guesses):
    scores = {word: 0 for word in possible_words}
    for word in possible_words:
        for guess, feedback in previous_guesses:
            guess_feedback = evaluate_guess(word, guess)
            if guess_feedback == feedback:
                scores[word] += 1
    best_words = [word for word, score in scores.items() if score == max(scores.values())]
    return random.choice(best_words)

# %%
#  Training phase
training_set_size = 1000  # Adjust as needed
training_set = []
training_set = [choose_random_word(training_set) for _ in range(training_set_size)]
training_attempts = []

great_starting_word = []
great_starting_word_attempts = float('inf')

word = 0
the_word = None

# with open('best_words.txt', 'r') as file:
#     best_initial_words = [line.strip() for line in file]
best_initial_words = ['often']

counter = 0
for element in best_initial_words:    
    initial_guess = best_initial_words[counter]
    print(f"Initial Guess: {initial_guess}")
    for target_word in training_set:
        attempts = 1
        previous_guesses = [(initial_guess, evaluate_guess(target_word, initial_guess))]
        word += 1
        print(f"word #{word}: {target_word}")
        while True:
            guess = bayesian_choose_word(possible_words, previous_guesses)
            attempts += 1
            if attempts == 1:
                the_word = guess
            # elif attempts == 2:
            #     the_word = guess
            
            feedback = evaluate_guess(target_word, guess)
            previous_guesses.append((guess, feedback))
            if target_word == guess:
                print(f"attempt: {attempts}")
                training_attempts.append(attempts)
                
                if attempts < 3:
                    great_starting_word.append(the_word)
                    # great_starting_word_attempts = attempts
                break
    counter += 1
# Out:
# Initial Guess: often
# word #1: troop
# attempt: 5
# word #2: lapse
# attempt: 5
# word #3: crier
# attempt: 6
# word #4: ovate
# attempt: 3
# word #5: deuce
# attempt: 3
# word #6: sweet
# attempt: 5
# word #7: booby
# attempt: 5
# word #8: would
# attempt: 4
# word #9: scale
# attempt: 5
# word #10: urine
# attempt: 3
# word #11: realm
# attempt: 5
# word #12: midge
# attempt: 4
# word #13: poser
# attempt: 6
# word #14: hunky
# attempt: 4
# word #15: crate
# attempt: 4
# word #16: craft
# attempt: 3
# word #17: boast
# attempt: 4
# word #18: slunk
# attempt: 3
# word #19: sharp
# attempt: 4
# word #20: snaky
# attempt: 3
# word #21: furry
# attempt: 5
# word #22: giver
# attempt: 5
# word #23: ranch
# attempt: 4
# word #24: affix
# attempt: 2
# word #25: muddy
# attempt: 5
# word #26: dread
# attempt: 3
# word #27: speck
# attempt: 4
# word #28: zebra
# attempt: 5
# word #29: ghost
# attempt: 4
# word #30: cause
# attempt: 4
# word #31: waxen
# attempt: 4
# word #32: daddy
# attempt: 5
# word #33: visor
# attempt: 5
# word #34: infer
# attempt: 3
# word #35: steam
# attempt: 5
# word #36: hello
# attempt: 5
# word #37: lusty
# attempt: 6
# word #38: gruff
# attempt: 3
# word #39: elite
# attempt: 5
# word #40: night
# attempt: 4
# word #41: freon
# attempt: 2
# word #42: pulse
# attempt: 5
# word #43: hoist
# attempt: 4
# word #44: bleak
# attempt: 4
# word #45: obese
# attempt: 3
# word #46: aorta
# attempt: 4
# word #47: amply
# attempt: 4
# word #48: frond
# attempt: 2
# word #49: rebel
# attempt: 4
# word #50: joker
# attempt: 3
# word #51: idyll
# attempt: 4
# word #52: fleet
# attempt: 2
# word #53: slimy
# attempt: 5
# word #54: quell
# attempt: 5
# word #55: rarer
# attempt: 4
# word #56: rebus
# attempt: 5
# word #57: diary
# attempt: 4
# word #58: globe
# attempt: 6
# word #59: savoy
# attempt: 3
# word #60: niche
# attempt: 5
# word #61: swore
# attempt: 5
# word #62: candy
# attempt: 4
# word #63: frank
# attempt: 4
# word #64: metro
# attempt: 3
# word #65: torso
# attempt: 4
# word #66: tweed
# attempt: 4
# word #67: curry
# attempt: 4
# word #68: debar
# attempt: 4
# word #69: bloom
# attempt: 4
# word #70: palsy
# attempt: 7
# word #71: bagel
# attempt: 4
# word #72: comfy
# attempt: 3
# word #73: leaky
# attempt: 4
# word #74: bylaw
# attempt: 3
# word #75: moult
# attempt: 5
# word #76: bosom
# attempt: 4
# word #77: surge
# attempt: 4
# word #78: exact
# attempt: 4
# word #79: smelt
# attempt: 3
# word #80: giant
# attempt: 4
# word #81: datum
# attempt: 4
# word #82: plunk
# attempt: 3
# word #83: saucy
# attempt: 4
# word #84: undue
# attempt: 3
# word #85: polar
# attempt: 6
# word #86: mange
# attempt: 3
# word #87: myrrh
# attempt: 3
# word #88: stink
# attempt: 3
# word #89: candy
# attempt: 6
# word #90: chard
# attempt: 4
# word #91: spray
# attempt: 4
# word #92: gauze
# attempt: 7
# word #93: crier
# attempt: 4
# word #94: defer
# attempt: 4
# word #95: miner
# attempt: 4
# word #96: great
# attempt: 3
# word #97: muddy
# attempt: 4
# word #98: catty
# attempt: 6
# word #99: rifle
# attempt: 3
# word #100: unfit
# attempt: 3
# word #101: cabal
# attempt: 5
# word #102: crush
# attempt: 4
# word #103: sulky
# attempt: 4
# word #104: tract
# attempt: 4
# word #105: scare
# attempt: 5
# word #106: kazoo
# attempt: 5
# word #107: bigot
# attempt: 6
# word #108: fanny
# attempt: 3
# word #109: daunt
# attempt: 6
# word #110: snarl
# attempt: 4
# word #111: cabby
# attempt: 5
# word #112: going
# attempt: 2
# word #113: glove
# attempt: 5
# word #114: equal
# attempt: 3
# word #115: ranch
# attempt: 4
# word #116: shave
# attempt: 3
# word #117: hater
# attempt: 2
# word #118: fling
# attempt: 3
# word #119: miner
# attempt: 3
# word #120: prude
# attempt: 4
# word #121: abate
# attempt: 6
# word #122: scarf
# attempt: 3
# word #123: gamma
# attempt: 6
# word #124: willy
# attempt: 7
# word #125: ovate
# attempt: 2
# word #126: brake
# attempt: 4
# word #127: canon
# attempt: 4
# word #128: catch
# attempt: 5
# word #129: attic
# attempt: 3
# word #130: tweet
# attempt: 5
# word #131: silky
# attempt: 4
# word #132: cigar
# attempt: 4
# word #133: quick
# attempt: 4
# word #134: sling
# attempt: 4
# word #135: throw
# attempt: 5
# word #136: title
# attempt: 3
# word #137: dowel
# attempt: 5
# word #138: vaunt
# attempt: 3
# word #139: testy
# attempt: 4
# word #140: upset
# attempt: 4
# word #141: evict
# attempt: 4
# word #142: diner
# attempt: 2
# word #143: scant
# attempt: 4
# word #144: bulge
# attempt: 4
# word #145: eager
# attempt: 5
# word #146: elfin
# attempt: 2
# word #147: acute
# attempt: 4
# word #148: mouth
# attempt: 6
# word #149: expel
# attempt: 4
# word #150: larva
# attempt: 5
# word #151: fluff
# attempt: 5
# word #152: hippy
# attempt: 5
# word #153: terra
# attempt: 4
# word #154: wagon
# attempt: 3
# word #155: fudge
# attempt: 4
# word #156: cello
# attempt: 4
# word #157: mover
# attempt: 5
# word #158: zebra
# attempt: 5
# word #159: refit
# attempt: 3
# word #160: beach
# attempt: 5
# word #161: hitch
# attempt: 6
# word #162: rainy
# attempt: 4
# word #163: poker
# attempt: 5
# word #164: hotly
# attempt: 3
# word #165: rodeo
# attempt: 3
# word #166: freon
# attempt: 2
# word #167: deign
# attempt: 4
# word #168: baler
# attempt: 3
# word #169: error
# attempt: 4
# word #170: unset
# attempt: 2
# word #171: craft
# attempt: 3
# word #172: caste
# attempt: 3
# word #173: lurch
# attempt: 4
# word #174: flaky
# attempt: 4
# word #175: fluid
# attempt: 3
# word #176: lapse
# attempt: 4
# word #177: waste
# attempt: 3
# word #178: broke
# attempt: 4
# word #179: heist
# attempt: 3
# word #180: front
# attempt: 2
# word #181: triad
# attempt: 3
# word #182: gusto
# attempt: 4
# word #183: pizza
# attempt: 4
# word #184: tonic
# attempt: 4
# word #185: sadly
# attempt: 3
# word #186: juice
# attempt: 4
# word #187: lefty
# attempt: 3
# word #188: sully
# attempt: 5
# word #189: showy
# attempt: 4
# word #190: cream
# attempt: 4
# word #191: straw
# attempt: 5
# word #192: cagey
# attempt: 3
# word #193: baron
# attempt: 3
# word #194: matey
# attempt: 3
# word #195: batch
# attempt: 8
# word #196: vixen
# attempt: 4
# word #197: ditty
# attempt: 4
# word #198: spine
# attempt: 4
# word #199: dozen
# attempt: 3
# word #200: story
# attempt: 5
# word #201: caddy
# attempt: 3
# word #202: belie
# attempt: 4
# word #203: state
# attempt: 4
# word #204: smote
# attempt: 3
# word #205: women
# attempt: 3
# word #206: slice
# attempt: 5
# word #207: poise
# attempt: 4
# word #208: swell
# attempt: 5
# word #209: trust
# attempt: 6
# word #210: mania
# attempt: 3
# word #211: smell
# attempt: 6
# word #212: seedy
# attempt: 4
# word #213: brood
# attempt: 3
# word #214: briar
# attempt: 4
# word #215: attic
# attempt: 3
# word #216: waltz
# attempt: 4
# word #217: macro
# attempt: 4
# word #218: spoil
# attempt: 3
# word #219: chaos
# attempt: 5
# word #220: lathe
# attempt: 3
# word #221: crown
# attempt: 5
# word #222: elfin
# attempt: 3
# word #223: utile
# attempt: 4
# word #224: avert
# attempt: 5
# word #225: chord
# attempt: 3
# word #226: prune
# attempt: 5
# word #227: payee
# attempt: 4
# word #228: unite
# attempt: 4
# word #229: smite
# attempt: 5
# word #230: stave
# attempt: 4
# word #231: caput
# attempt: 5
# word #232: augur
# attempt: 4
# word #233: wince
# attempt: 5
# word #234: logic
# attempt: 4
# word #235: talon
# attempt: 3
# word #236: cater
# attempt: 6
# word #237: thief
# attempt: 3
# word #238: helix
# attempt: 4
# word #239: rocky
# attempt: 5
# word #240: layer
# attempt: 7
# word #241: extol
# attempt: 2
# word #242: pupil
# attempt: 4
# word #243: quota
# attempt: 3
# word #244: enema
# attempt: 3
# word #245: tipsy
# attempt: 4
# word #246: media
# attempt: 2
# word #247: purer
# attempt: 4
# word #248: trial
# attempt: 4
# word #249: dodge
# attempt: 3
# word #250: baron
# attempt: 4
# word #251: silly
# attempt: 4
# word #252: outdo
# attempt: 3
# word #253: horse
# attempt: 6
# word #254: decoy
# attempt: 3
# word #255: loser
# attempt: 5
# word #256: enact
# attempt: 3
# word #257: sixth
# attempt: 4
# word #258: vigor
# attempt: 6
# word #259: grade
# attempt: 5
# word #260: clack
# attempt: 4
# word #261: clasp
# attempt: 3
# word #262: champ
# attempt: 3
# word #263: yearn
# attempt: 5
# word #264: crude
# attempt: 5
# word #265: aloof
# attempt: 3
# word #266: stole
# attempt: 4
# word #267: peril
# attempt: 5
# word #268: chuck
# attempt: 3
# word #269: caulk
# attempt: 4
# word #270: bilge
# attempt: 4
# word #271: lapel
# attempt: 4
# word #272: grope
# attempt: 4
# word #273: cycle
# attempt: 3
# word #274: lingo
# attempt: 4
# word #275: annex
# attempt: 4
# word #276: spice
# attempt: 5
# word #277: aglow
# attempt: 4
# word #278: skunk
# attempt: 5
# word #279: legal
# attempt: 3
# word #280: plant
# attempt: 4
# word #281: expel
# attempt: 3
# word #282: randy
# attempt: 4
# word #283: stack
# attempt: 4
# word #284: vomit
# attempt: 4
# word #285: brain
# attempt: 4
# word #286: couch
# attempt: 4
# word #287: impel
# attempt: 5
# word #288: dough
# attempt: 5
# word #289: twang
# attempt: 3
# word #290: godly
# attempt: 5
# word #291: mogul
# attempt: 4
# word #292: yearn
# attempt: 4
# word #293: atone
# attempt: 3
# word #294: niche
# attempt: 4
# word #295: spunk
# attempt: 6
# word #296: tweed
# attempt: 3
# word #297: balsa
# attempt: 5
# word #298: draft
# attempt: 4
# word #299: stock
# attempt: 4
# word #300: badly
# attempt: 5
# word #301: fight
# attempt: 4
# word #302: boast
# attempt: 5
# word #303: apply
# attempt: 4
# word #304: foamy
# attempt: 4
# word #305: cross
# attempt: 5
# word #306: fight
# attempt: 3
# word #307: these
# attempt: 5
# word #308: dying
# attempt: 4
# word #309: jetty
# attempt: 3
# word #310: inept
# attempt: 3
# word #311: trope
# attempt: 4
# word #312: tilde
# attempt: 4
# word #313: chess
# attempt: 5
# word #314: glean
# attempt: 3
# word #315: surge
# attempt: 3
# word #316: inner
# attempt: 4
# word #317: tried
# attempt: 4
# word #318: visit
# attempt: 5
# word #319: habit
# attempt: 4
# word #320: pithy
# attempt: 3
# word #321: newer
# attempt: 2
# word #322: block
# attempt: 5
# word #323: laden
# attempt: 4
# word #324: welsh
# attempt: 4
# word #325: grown
# attempt: 4
# word #326: ruler
# attempt: 5
# word #327: snuff
# attempt: 3
# word #328: fatty
# attempt: 3
# word #329: spore
# attempt: 5
# word #330: usurp
# attempt: 4
# word #331: nosey
# attempt: 2
# word #332: revel
# attempt: 5
# word #333: slung
# attempt: 4
# word #334: flask
# attempt: 4
# word #335: stick
# attempt: 5
# word #336: guppy
# attempt: 4
# word #337: exalt
# attempt: 4
# word #338: rainy
# attempt: 4
# word #339: sooty
# attempt: 5
# word #340: flair
# attempt: 4
# word #341: worst
# attempt: 5
# word #342: defer
# attempt: 5
# word #343: basin
# attempt: 4
# word #344: noisy
# attempt: 3
# word #345: ferry
# attempt: 3
# word #346: stoic
# attempt: 4
# word #347: bliss
# attempt: 5
# word #348: staid
# attempt: 4
# word #349: alien
# attempt: 3
# word #350: askew
# attempt: 4
# word #351: human
# attempt: 4
# word #352: bushy
# attempt: 4
# word #353: shell
# attempt: 3
# word #354: aglow
# attempt: 4
# word #355: civic
# attempt: 4
# word #356: armor
# attempt: 3
# word #357: badly
# attempt: 4
# word #358: debug
# attempt: 5
# word #359: slink
# attempt: 3
# word #360: where
# attempt: 5
# word #361: prose
# attempt: 4
# word #362: drake
# attempt: 4
# word #363: wreak
# attempt: 3
# word #364: proxy
# attempt: 4
# word #365: caper
# attempt: 4
# word #366: gripe
# attempt: 4
# word #367: emcee
# attempt: 4
# word #368: fluff
# attempt: 4
# word #369: naive
# attempt: 3
# word #370: arose
# attempt: 5
# word #371: donut
# attempt: 3
# word #372: kazoo
# attempt: 5
# word #373: gavel
# attempt: 3
# word #374: greed
# attempt: 3
# word #375: erect
# attempt: 3
# word #376: blunt
# attempt: 4
# word #377: drier
# attempt: 3
# word #378: maize
# attempt: 3
# word #379: prank
# attempt: 5
# word #380: preen
# attempt: 4
# word #381: stall
# attempt: 4
# word #382: caput
# attempt: 5
# word #383: punch
# attempt: 7
# word #384: habit
# attempt: 3
# word #385: penne
# attempt: 4
# word #386: agony
# attempt: 5
# word #387: pinky
# attempt: 5
# word #388: boozy
# attempt: 4
# word #389: child
# attempt: 4
# word #390: woody
# attempt: 4
# word #391: strip
# attempt: 2
# word #392: lance
# attempt: 5
# word #393: verge
# attempt: 5
# word #394: conic
# attempt: 4
# word #395: water
# attempt: 4
# word #396: email
# attempt: 4
# word #397: seize
# attempt: 5
# word #398: choke
# attempt: 6
# word #399: clump
# attempt: 4
# word #400: grime
# attempt: 4
# word #401: movie
# attempt: 5
# word #402: label
# attempt: 4
# word #403: sheep
# attempt: 4
# word #404: slick
# attempt: 5
# word #405: curvy
# attempt: 5
# word #406: plane
# attempt: 4
# word #407: baler
# attempt: 4
# word #408: eaten
# attempt: 2
# word #409: swear
# attempt: 4
# word #410: noble
# attempt: 3
# word #411: groom
# attempt: 3
# word #412: bagel
# attempt: 3
# word #413: urine
# attempt: 4
# word #414: spice
# attempt: 6
# word #415: aptly
# attempt: 5
# word #416: graft
# attempt: 3
# word #417: acorn
# attempt: 4
# word #418: civic
# attempt: 4
# word #419: bring
# attempt: 3
# word #420: unset
# attempt: 3
# word #421: latte
# attempt: 3
# word #422: white
# attempt: 5
# word #423: butte
# attempt: 4
# word #424: umbra
# attempt: 4
# word #425: guest
# attempt: 3
# word #426: lodge
# attempt: 4
# word #427: gleam
# attempt: 4
# word #428: elect
# attempt: 4
# word #429: humid
# attempt: 4
# word #430: havoc
# attempt: 4
# word #431: lumpy
# attempt: 4
# word #432: booze
# attempt: 3
# word #433: blare
# attempt: 6
# word #434: drama
# attempt: 5
# word #435: unwed
# attempt: 3
# word #436: stair
# attempt: 5
# word #437: sheep
# attempt: 4
# word #438: shady
# attempt: 5
# word #439: flora
# attempt: 4
# word #440: cable
# attempt: 5
# word #441: leaky
# attempt: 4
# word #442: igloo
# attempt: 4
# word #443: cameo
# attempt: 3
# word #444: cobra
# attempt: 5
# word #445: atone
# attempt: 3
# word #446: baron
# attempt: 3
# word #447: frill
# attempt: 4
# word #448: filer
# attempt: 3
# word #449: spine
# attempt: 5
# word #450: ghost
# attempt: 4
# word #451: merry
# attempt: 4
# word #452: clout
# attempt: 4
# word #453: patsy
# attempt: 3
# word #454: helix
# attempt: 5
# word #455: privy
# attempt: 5
# word #456: patio
# attempt: 4
# word #457: twirl
# attempt: 4
# word #458: slosh
# attempt: 4
# word #459: smote
# attempt: 3
# word #460: crept
# attempt: 5
# word #461: miner
# attempt: 5
# word #462: mouse
# attempt: 3
# word #463: refer
# attempt: 5
# word #464: gross
# attempt: 5
# word #465: guest
# attempt: 4
# word #466: croup
# attempt: 4
# word #467: tried
# attempt: 3
# word #468: guilt
# attempt: 3
# word #469: rearm
# attempt: 4
# word #470: lunch
# attempt: 6
# word #471: unwed
# attempt: 3
# word #472: aisle
# attempt: 5
# word #473: spire
# attempt: 3
# word #474: short
# attempt: 4
# word #475: swung
# attempt: 4
# word #476: lover
# attempt: 4
# word #477: exist
# attempt: 4
# word #478: alpha
# attempt: 3
# word #479: total
# attempt: 3
# word #480: optic
# attempt: 4
# word #481: borax
# attempt: 4
# word #482: sense
# attempt: 6
# word #483: chair
# attempt: 4
# word #484: sheep
# attempt: 4
# word #485: least
# attempt: 5
# word #486: magma
# attempt: 4
# word #487: chute
# attempt: 4
# word #488: power
# attempt: 3
# word #489: fault
# attempt: 3
# word #490: cling
# attempt: 4
# word #491: patch
# attempt: 5
# word #492: alloy
# attempt: 3
# word #493: upset
# attempt: 4
# word #494: axiom
# attempt: 5
# word #495: badge
# attempt: 5
# word #496: suing
# attempt: 4
# word #497: snuff
# attempt: 3
# word #498: cover
# attempt: 6
# word #499: write
# attempt: 4
# word #500: oddly
# attempt: 2
# word #501: rinse
# attempt: 5
# word #502: skirt
# attempt: 4
# word #503: jaunt
# attempt: 6
# word #504: ascot
# attempt: 4
# word #505: donor
# attempt: 3
# word #506: hilly
# attempt: 8
# word #507: tonic
# attempt: 3
# word #508: ratio
# attempt: 3
# word #509: embed
# attempt: 4
# word #510: verge
# attempt: 3
# word #511: guard
# attempt: 5
# word #512: often
# attempt: 2
# word #513: elder
# attempt: 6
# word #514: scamp
# attempt: 4
# word #515: drink
# attempt: 4
# word #516: sever
# attempt: 4
# word #517: sniff
# attempt: 3
# word #518: click
# attempt: 5
# word #519: icing
# attempt: 3
# word #520: goody
# attempt: 4
# word #521: exalt
# attempt: 5
# word #522: gauge
# attempt: 4
# word #523: crane
# attempt: 4
# word #524: cagey
# attempt: 5
# word #525: alone
# attempt: 3
# word #526: chose
# attempt: 6
# word #527: croak
# attempt: 5
# word #528: flaky
# attempt: 4
# word #529: gauze
# attempt: 4
# word #530: scoop
# attempt: 4
# word #531: relax
# attempt: 5
# word #532: sneer
# attempt: 3
# word #533: slimy
# attempt: 5
# word #534: drive
# attempt: 5
# word #535: joint
# attempt: 3
# word #536: borax
# attempt: 5
# word #537: piety
# attempt: 5
# word #538: swore
# attempt: 5
# word #539: light
# attempt: 5
# word #540: skulk
# attempt: 4
# word #541: gnash
# attempt: 3
# word #542: child
# attempt: 7
# word #543: diary
# attempt: 3
# word #544: cleft
# attempt: 3
# word #545: marry
# attempt: 5
# word #546: pleat
# attempt: 3
# word #547: lousy
# attempt: 6
# word #548: drool
# attempt: 4
# word #549: leper
# attempt: 5
# word #550: savvy
# attempt: 5
# word #551: drool
# attempt: 5
# word #552: clock
# attempt: 4
# word #553: hutch
# attempt: 3
# word #554: amble
# attempt: 4
# word #555: chest
# attempt: 4
# word #556: feral
# attempt: 4
# word #557: debut
# attempt: 4
# word #558: worse
# attempt: 5
# word #559: along
# attempt: 5
# word #560: plank
# attempt: 5
# word #561: blaze
# attempt: 5
# word #562: flunk
# attempt: 3
# word #563: vinyl
# attempt: 5
# word #564: crypt
# attempt: 3
# word #565: store
# attempt: 5
# word #566: sinew
# attempt: 4
# word #567: stash
# attempt: 3
# word #568: sunny
# attempt: 5
# word #569: saute
# attempt: 4
# word #570: cliff
# attempt: 5
# word #571: royal
# attempt: 3
# word #572: royal
# attempt: 3
# word #573: bonus
# attempt: 3
# word #574: inter
# attempt: 2
# word #575: pesto
# attempt: 3
# word #576: swung
# attempt: 4
# word #577: attic
# attempt: 3
# word #578: arson
# attempt: 3
# word #579: suing
# attempt: 3
# word #580: goofy
# attempt: 3
# word #581: fault
# attempt: 3
# word #582: union
# attempt: 5
# word #583: crust
# attempt: 4
# word #584: trove
# attempt: 4
# word #585: oxide
# attempt: 2
# word #586: talon
# attempt: 3
# word #587: arbor
# attempt: 5
# word #588: ratio
# attempt: 3
# word #589: drier
# attempt: 4
# word #590: fugue
# attempt: 3
# word #591: three
# attempt: 4
# word #592: rebus
# attempt: 3
# word #593: cabal
# attempt: 3
# word #594: scold
# attempt: 5
# word #595: drown
# attempt: 6
# word #596: shaky
# attempt: 3
# word #597: mayor
# attempt: 7
# word #598: flank
# attempt: 3
# word #599: jerky
# attempt: 6
# word #600: batty
# attempt: 6
# word #601: ashen
# attempt: 3
# word #602: awoke
# attempt: 3
# word #603: spasm
# attempt: 4
# word #604: berry
# attempt: 5
# word #605: axion
# attempt: 3
# word #606: resin
# attempt: 3
# word #607: vaunt
# attempt: 3
# word #608: rearm
# attempt: 4
# word #609: roast
# attempt: 4
# word #610: molar
# attempt: 5
# word #611: soapy
# attempt: 3
# word #612: liver
# attempt: 6
# word #613: fresh
# attempt: 3
# word #614: climb
# attempt: 3
# word #615: carve
# attempt: 4
# word #616: femme
# attempt: 4
# word #617: avoid
# attempt: 4
# word #618: wring
# attempt: 4
# word #619: essay
# attempt: 4
# word #620: moron
# attempt: 4
# word #621: night
# attempt: 4
# word #622: awoke
# attempt: 4
# word #623: climb
# attempt: 4
# word #624: gavel
# attempt: 6
# word #625: safer
# attempt: 3
# word #626: merit
# attempt: 5
# word #627: opine
# attempt: 3
# word #628: bible
# attempt: 4
# word #629: tramp
# attempt: 3
# word #630: avert
# attempt: 4
# word #631: tilde
# attempt: 3
# word #632: snail
# attempt: 3
# word #633: wacky
# attempt: 4
# word #634: sneak
# attempt: 4
# word #635: raspy
# attempt: 4
# word #636: point
# attempt: 5
# word #637: augur
# attempt: 4
# word #638: thumb
# attempt: 5
# word #639: tulle
# attempt: 3
# word #640: spiel
# attempt: 5
# word #641: poppy
# attempt: 5
# word #642: braid
# attempt: 4
# word #643: mince
# attempt: 4
# word #644: myrrh
# attempt: 4
# word #645: evade
# attempt: 5
# word #646: banjo
# attempt: 5
# word #647: dolly
# attempt: 5
# word #648: thigh
# attempt: 4
# word #649: claim
# attempt: 3
# word #650: tardy
# attempt: 5
# word #651: leave
# attempt: 6
# word #652: plier
# attempt: 6
# word #653: surly
# attempt: 7
# word #654: coyly
# attempt: 3
# word #655: igloo
# attempt: 4
# word #656: dowdy
# attempt: 4
# word #657: surer
# attempt: 5
# word #658: tawny
# attempt: 4
# word #659: mural
# attempt: 6
# word #660: eaten
# attempt: 2
# word #661: sixth
# attempt: 3
# word #662: smell
# attempt: 4
# word #663: racer
# attempt: 4
# word #664: tough
# attempt: 3
# word #665: slept
# attempt: 5
# word #666: sweat
# attempt: 6
# word #667: snowy
# attempt: 4
# word #668: yacht
# attempt: 4
# word #669: lying
# attempt: 3
# word #670: steam
# attempt: 4
# word #671: impel
# attempt: 4
# word #672: beret
# attempt: 2
# word #673: ivory
# attempt: 3
# word #674: frock
# attempt: 3
# word #675: roomy
# attempt: 4
# word #676: stamp
# attempt: 4
# word #677: salve
# attempt: 3
# word #678: flair
# attempt: 3
# word #679: prove
# attempt: 4
# word #680: spiny
# attempt: 4
# word #681: throb
# attempt: 3
# word #682: nasty
# attempt: 3
# word #683: blond
# attempt: 3
# word #684: mount
# attempt: 5
# word #685: camel
# attempt: 4
# word #686: occur
# attempt: 2
# word #687: large
# attempt: 4
# word #688: nylon
# attempt: 4
# word #689: dirty
# attempt: 4
# word #690: inlay
# attempt: 4
# word #691: exert
# attempt: 4
# word #692: gully
# attempt: 5
# word #693: decoy
# attempt: 5
# word #694: tawny
# attempt: 3
# word #695: bugle
# attempt: 5
# word #696: hedge
# attempt: 5
# word #697: stank
# attempt: 4
# word #698: medal
# attempt: 6
# word #699: plant
# attempt: 4
# word #700: harry
# attempt: 5
# word #701: maple
# attempt: 4
# word #702: detox
# attempt: 3
# word #703: clone
# attempt: 3
# word #704: stink
# attempt: 4
# word #705: young
# attempt: 4
# word #706: sooty
# attempt: 4
# word #707: befit
# attempt: 3
# word #708: index
# attempt: 4
# word #709: orbit
# attempt: 3
# word #710: gonad
# attempt: 4
# word #711: force
# attempt: 3
# word #712: rebar
# attempt: 4
# word #713: marry
# attempt: 6
# word #714: howdy
# attempt: 5
# word #715: junto
# attempt: 2
# word #716: perky
# attempt: 4
# word #717: lumen
# attempt: 5
# word #718: thank
# attempt: 5
# word #719: ennui
# attempt: 4
# word #720: ethic
# attempt: 4
# word #721: swill
# attempt: 6
# word #722: cloud
# attempt: 5
# word #723: terse
# attempt: 4
# word #724: cameo
# attempt: 3
# word #725: snuck
# attempt: 3
# word #726: until
# attempt: 3
# word #727: charm
# attempt: 5
# word #728: mulch
# attempt: 4
# word #729: spook
# attempt: 4
# word #730: endow
# attempt: 3
# word #731: twist
# attempt: 5
# word #732: latte
# attempt: 4
# word #733: swill
# attempt: 5
# word #734: barge
# attempt: 6
# word #735: bleep
# attempt: 2
# word #736: mogul
# attempt: 4
# word #737: ladle
# attempt: 5
# word #738: climb
# attempt: 3
# word #739: knock
# attempt: 3
# word #740: field
# attempt: 3
# word #741: slunk
# attempt: 4
# word #742: awake
# attempt: 3
# word #743: video
# attempt: 3
# word #744: craze
# attempt: 5
# word #745: apron
# attempt: 4
# word #746: preen
# attempt: 6
# word #747: eager
# attempt: 4
# word #748: cabal
# attempt: 4
# word #749: fatal
# attempt: 3
# word #750: leech
# attempt: 3
# word #751: briar
# attempt: 3
# word #752: youth
# attempt: 4
# word #753: dealt
# attempt: 4
# word #754: butch
# attempt: 5
# word #755: alert
# attempt: 4
# word #756: hutch
# attempt: 4
# word #757: awoke
# attempt: 2
# word #758: apnea
# attempt: 2
# word #759: lilac
# attempt: 5
# word #760: newer
# attempt: 3
# word #761: augur
# attempt: 4
# word #762: skunk
# attempt: 5
# word #763: heard
# attempt: 3
# word #764: dirge
# attempt: 4
# word #765: began
# attempt: 3
# word #766: trend
# attempt: 3
# word #767: oxide
# attempt: 3
# word #768: frost
# attempt: 3
# word #769: terra
# attempt: 4
# word #770: easel
# attempt: 4
# word #771: adopt
# attempt: 5
# word #772: shiny
# attempt: 4
# word #773: oxide
# attempt: 4
# word #774: ralph
# attempt: 3
# word #775: heave
# attempt: 3
# word #776: attic
# attempt: 3
# word #777: study
# attempt: 5
# word #778: prank
# attempt: 4
# word #779: plaid
# attempt: 4
# word #780: snore
# attempt: 4
# word #781: manly
# attempt: 3
# word #782: voice
# attempt: 4
# word #783: beget
# attempt: 3
# word #784: snake
# attempt: 5
# word #785: tibia
# attempt: 4
# word #786: cache
# attempt: 3
# word #787: teach
# attempt: 4
# word #788: think
# attempt: 3
# word #789: regal
# attempt: 4
# word #790: upper
# attempt: 4
# word #791: amble
# attempt: 6
# word #792: drill
# attempt: 4
# word #793: valid
# attempt: 5
# word #794: morph
# attempt: 5
# word #795: scowl
# attempt: 4
# word #796: tweak
# attempt: 4
# word #797: teary
# attempt: 4
# word #798: ingot
# attempt: 3
# word #799: retch
# attempt: 4
# word #800: gavel
# attempt: 5
# word #801: finer
# attempt: 2
# word #802: wooly
# attempt: 4
# word #803: baggy
# attempt: 6
# word #804: crack
# attempt: 5
# word #805: horny
# attempt: 3
# word #806: heart
# attempt: 3
# word #807: nanny
# attempt: 5
# word #808: climb
# attempt: 4
# word #809: ghost
# attempt: 4
# word #810: refit
# attempt: 4
# word #811: hovel
# attempt: 4
# word #812: booty
# attempt: 4
# word #813: mambo
# attempt: 3
# word #814: fanny
# attempt: 4
# word #815: align
# attempt: 4
# word #816: rehab
# attempt: 3
# word #817: atone
# attempt: 4
# word #818: youth
# attempt: 3
# word #819: laden
# attempt: 4
# word #820: manly
# attempt: 3
# word #821: palsy
# attempt: 5
# word #822: snipe
# attempt: 3
# word #823: basin
# attempt: 3
# word #824: surly
# attempt: 5
# word #825: anime
# attempt: 4
# word #826: harem
# attempt: 5
# word #827: kebab
# attempt: 6
# word #828: shrew
# attempt: 5
# word #829: freer
# attempt: 4
# word #830: radar
# attempt: 4
# word #831: frill
# attempt: 4
# word #832: bison
# attempt: 4
# word #833: worst
# attempt: 5
# word #834: steal
# attempt: 3
# word #835: defer
# attempt: 4
# word #836: sieve
# attempt: 3
# word #837: afoot
# attempt: 2
# word #838: snore
# attempt: 4
# word #839: piney
# attempt: 4
# word #840: lousy
# attempt: 5
# word #841: valor
# attempt: 3
# word #842: maple
# attempt: 4
# word #843: thorn
# attempt: 4
# word #844: mucky
# attempt: 6
# word #845: brave
# attempt: 4
# word #846: above
# attempt: 6
# word #847: noose
# attempt: 4
# word #848: vomit
# attempt: 4
# word #849: palsy
# attempt: 3
# word #850: plied
# attempt: 4
# word #851: shock
# attempt: 5
# word #852: posse
# attempt: 4
# word #853: boxer
# attempt: 7
# word #854: payer
# attempt: 3
# word #855: dowdy
# attempt: 4
# word #856: axiom
# attempt: 4
# word #857: gaunt
# attempt: 4
# word #858: stoke
# attempt: 2
# word #859: lingo
# attempt: 5
# word #860: flier
# attempt: 3
# word #861: cabin
# attempt: 3
# word #862: lever
# attempt: 5
# word #863: plate
# attempt: 5
# word #864: squat
# attempt: 4
# word #865: urine
# attempt: 4
# word #866: cling
# attempt: 3
# word #867: super
# attempt: 5
# word #868: kazoo
# attempt: 5
# word #869: mammy
# attempt: 5
# word #870: ovoid
# attempt: 2
# word #871: molar
# attempt: 5
# word #872: stark
# attempt: 3
# word #873: truly
# attempt: 5
# word #874: swarm
# attempt: 4
# word #875: movie
# attempt: 4
# word #876: noise
# attempt: 5
# word #877: puffy
# attempt: 4
# word #878: saint
# attempt: 4
# word #879: porch
# attempt: 4
# word #880: clove
# attempt: 3
# word #881: vapor
# attempt: 5
# word #882: theta
# attempt: 4
# word #883: plied
# attempt: 4
# word #884: issue
# attempt: 4
# word #885: queue
# attempt: 5
# word #886: basic
# attempt: 5
# word #887: virus
# attempt: 3
# word #888: alarm
# attempt: 4
# word #889: clock
# attempt: 3
# word #890: trawl
# attempt: 4
# word #891: jazzy
# attempt: 5
# word #892: polyp
# attempt: 4
# word #893: stern
# attempt: 2
# word #894: brick
# attempt: 5
# word #895: prong
# attempt: 4
# word #896: hefty
# attempt: 3
# word #897: maple
# attempt: 5
# word #898: fleet
# attempt: 3
# word #899: ombre
# attempt: 2
# word #900: moist
# attempt: 4
# word #901: freon
# attempt: 2
# word #902: nymph
# attempt: 4
# word #903: joker
# attempt: 6
# word #904: duchy
# attempt: 3
# word #905: weird
# attempt: 3
# word #906: alibi
# attempt: 4
# word #907: surer
# attempt: 5
# word #908: beset
# attempt: 3
# word #909: forth
# attempt: 2
# word #910: slang
# attempt: 3
# word #911: stamp
# attempt: 3
# word #912: prude
# attempt: 4
# word #913: dowry
# attempt: 5
# word #914: fecal
# attempt: 4
# word #915: rhyme
# attempt: 3
# word #916: offer
# attempt: 2
# word #917: winch
# attempt: 6
# word #918: upset
# attempt: 3
# word #919: queue
# attempt: 4
# word #920: helix
# attempt: 5
# word #921: paint
# attempt: 5
# word #922: exert
# attempt: 4
# word #923: slyly
# attempt: 5
# word #924: staff
# attempt: 3
# word #925: prawn
# attempt: 5
# word #926: boost
# attempt: 3
# word #927: essay
# attempt: 3
# word #928: dally
# attempt: 6
# word #929: covey
# attempt: 5
# word #930: happy
# attempt: 5
# word #931: cubic
# attempt: 3
# word #932: octal
# attempt: 2
# word #933: hunch
# attempt: 3
# word #934: belie
# attempt: 5
# word #935: payee
# attempt: 4
# word #936: remit
# attempt: 5
# word #937: fable
# attempt: 4
# word #938: metro
# attempt: 3
# word #939: smirk
# attempt: 5
# word #940: aloud
# attempt: 4
# word #941: bough
# attempt: 5
# word #942: pluck
# attempt: 5
# word #943: empty
# attempt: 4
# word #944: ensue
# attempt: 4
# word #945: scale
# attempt: 6
# word #946: media
# attempt: 5
# word #947: billy
# attempt: 5
# word #948: ghoul
# attempt: 5
# word #949: slink
# attempt: 4
# word #950: lasso
# attempt: 4
# word #951: guile
# attempt: 5
# word #952: sassy
# attempt: 5
# word #953: filet
# attempt: 3
# word #954: slosh
# attempt: 4
# word #955: nanny
# attempt: 3
# word #956: tally
# attempt: 3
# word #957: scaly
# attempt: 4
# word #958: fluke
# attempt: 3
# word #959: joint
# attempt: 4
# word #960: carol
# attempt: 5
# word #961: stage
# attempt: 4
# word #962: nasal
# attempt: 2
# word #963: surer
# attempt: 4
# word #964: tulle
# attempt: 5
# word #965: bossy
# attempt: 4
# word #966: slack
# attempt: 5
# word #967: maple
# attempt: 5
# word #968: piggy
# attempt: 6
# word #969: spark
# attempt: 4
# word #970: knead
# attempt: 4
# word #971: drain
# attempt: 3
# word #972: shard
# attempt: 3
# word #973: medal
# attempt: 5
# word #974: vowel
# attempt: 6
# word #975: ferry
# attempt: 3
# word #976: mower
# attempt: 4
# word #977: oddly
# attempt: 3
# word #978: hazel
# attempt: 5
# word #979: flack
# attempt: 3
# word #980: crept
# attempt: 4
# word #981: goose
# attempt: 4
# word #982: treat
# attempt: 4
# word #983: erase
# attempt: 6
# word #984: cider
# attempt: 3
# word #985: decor
# attempt: 3
# word #986: flock
# attempt: 4
# word #987: creak
# attempt: 5
# word #988: rivet
# attempt: 3
# word #989: faith
# attempt: 4
# word #990: whelp
# attempt: 5
# word #991: sweet
# attempt: 3
# word #992: twine
# attempt: 3
# word #993: goner
# attempt: 3
# word #994: cargo
# attempt: 4
# word #995: bribe
# attempt: 4
# word #996: heave
# attempt: 4
# word #997: habit
# attempt: 4
# word #998: wordy
# attempt: 4
# word #999: bleak
# attempt: 5
# word #1000: blank
# attempt: 4

# %%
# Testing phase
testing_attempts = []
word = 0
the_word = None
feedback = []
best_starting_word = []
best_starting_word_attempts = float('inf')
# print(possible_words)

counter = 0
for element in best_initial_words:  
    initial_guess = best_initial_words[counter]
    print(f"Initial Guess: {initial_guess}")

    for target_word in testing_set:
        attempts = 1
        previous_guesses = [(initial_guess, evaluate_guess(target_word, initial_guess))]
        word += 1
        print(f"word #{word}: {target_word}")

        while True:
            attempts += 1
            guess = bayesian_choose_word(possible_words, previous_guesses)
            # print(guess)
            if attempts == 1:
                # guess = random.choice(great_starting_word)
                the_word = guess
            # elif attempts == 2:
            #     the_word = guess
            
            feedback = evaluate_guess(target_word, guess)
            previous_guesses.append((guess, feedback))
            if target_word == guess:
                print(f"attempt: {attempts}")
                testing_attempts.append(attempts)
                if attempts < 3:
                    best_starting_word.append(the_word)
                    # best_starting_word_attempts = attempts
                break
    counter += 1
# Out:
# Initial Guess: often
# word #1: noise
# attempt: 4
# word #2: bleak
# attempt: 5
# word #3: grail
# attempt: 4
# word #4: phony
# attempt: 3
# word #5: mason
# attempt: 3
# word #6: noble
# attempt: 3
# word #7: pique
# attempt: 3
# word #8: retry
# attempt: 4
# word #9: cause
# attempt: 5
# word #10: tempo
# attempt: 3
# word #11: given
# attempt: 5
# word #12: smirk
# attempt: 4
# word #13: occur
# attempt: 2
# word #14: splat
# attempt: 4
# word #15: mercy
# attempt: 3
# word #16: adult
# attempt: 4
# word #17: graph
# attempt: 4
# word #18: leaky
# attempt: 4
# word #19: agent
# attempt: 5
# word #20: uncle
# attempt: 3
# word #21: knelt
# attempt: 3
# word #22: skunk
# attempt: 3
# word #23: snail
# attempt: 3
# word #24: truth
# attempt: 4
# word #25: binge
# attempt: 5
# word #26: viola
# attempt: 4
# word #27: chime
# attempt: 5
# word #28: bunch
# attempt: 6
# word #29: spurt
# attempt: 3
# word #30: while
# attempt: 6
# word #31: merry
# attempt: 3
# word #32: beret
# attempt: 4
# word #33: daddy
# attempt: 6
# word #34: azure
# attempt: 5
# word #35: coach
# attempt: 4
# word #36: smile
# attempt: 4
# word #37: loyal
# attempt: 4
# word #38: rocky
# attempt: 3
# word #39: right
# attempt: 3
# word #40: carol
# attempt: 4
# word #41: brush
# attempt: 5
# word #42: stone
# attempt: 3
# word #43: snare
# attempt: 4
# word #44: close
# attempt: 5
# word #45: frank
# attempt: 4
# word #46: music
# attempt: 4
# word #47: angel
# attempt: 3
# word #48: exert
# attempt: 4
# word #49: rayon
# attempt: 4
# word #50: clear
# attempt: 4
# word #51: whisk
# attempt: 3
# word #52: older
# attempt: 2
# word #53: quote
# attempt: 5
# word #54: lucky
# attempt: 4
# word #55: rouse
# attempt: 3
# word #56: dwell
# attempt: 4
# word #57: gnash
# attempt: 4
# word #58: birch
# attempt: 4
# word #59: giddy
# attempt: 4
# word #60: await
# attempt: 4
# word #61: onion
# attempt: 3
# word #62: space
# attempt: 4
# word #63: bride
# attempt: 3
# word #64: audio
# attempt: 4
# word #65: caper
# attempt: 4
# word #66: write
# attempt: 5
# word #67: peace
# attempt: 3
# word #68: choir
# attempt: 4
# word #69: ocean
# attempt: 2
# word #70: wordy
# attempt: 5
# word #71: verve
# attempt: 4
# word #72: spice
# attempt: 3
# word #73: beach
# attempt: 4
# word #74: quest
# attempt: 5
# word #75: magma
# attempt: 5
# word #76: exact
# attempt: 3
# word #77: amiss
# attempt: 5
# word #78: scrub
# attempt: 4
# word #79: index
# attempt: 3
# word #80: snaky
# attempt: 4
# word #81: wrath
# attempt: 4
# word #82: quick
# attempt: 3
# word #83: hello
# attempt: 4
# word #84: empty
# attempt: 4
# word #85: lover
# attempt: 6
# word #86: bully
# attempt: 5
# word #87: brook
# attempt: 4
# word #88: polyp
# attempt: 5
# word #89: anode
# attempt: 3
# word #90: chart
# attempt: 4
# word #91: party
# attempt: 4
# word #92: beget
# attempt: 4
# word #93: tenth
# attempt: 4
# word #94: style
# attempt: 3
# word #95: bathe
# attempt: 4
# word #96: curly
# attempt: 5
# word #97: ethos
# attempt: 3
# word #98: disco
# attempt: 5
# word #99: heart
# attempt: 5
# word #100: wheel
# attempt: 4
# word #101: hobby
# attempt: 4
# word #102: whale
# attempt: 6
# word #103: froze
# attempt: 3
# word #104: burly
# attempt: 3
# word #105: flank
# attempt: 3
# word #106: tonic
# attempt: 3
# word #107: flyer
# attempt: 2
# word #108: droop
# attempt: 4
# word #109: topaz
# attempt: 4
# word #110: crone
# attempt: 5
# word #111: fiend
# attempt: 3
# word #112: barge
# attempt: 4
# word #113: whirl
# attempt: 4
# word #114: earth
# attempt: 4
# word #115: folly
# attempt: 4
# word #116: enter
# attempt: 2
# word #117: cower
# attempt: 2
# word #118: donut
# attempt: 4
# word #119: windy
# attempt: 3
# word #120: venom
# attempt: 3
# word #121: irate
# attempt: 4
# word #122: hotel
# attempt: 2
# word #123: mossy
# attempt: 4
# word #124: bleep
# attempt: 4
# word #125: straw
# attempt: 4
# word #126: diner
# attempt: 4
# word #127: tract
# attempt: 4
# word #128: about
# attempt: 3
# word #129: guest
# attempt: 4
# word #130: rodeo
# attempt: 3
# word #131: grand
# attempt: 4
# word #132: covet
# attempt: 4
# word #133: taste
# attempt: 6
# word #134: crane
# attempt: 5
# word #135: frost
# attempt: 3
# word #136: kazoo
# attempt: 6
# word #137: shyly
# attempt: 4
# word #138: ranch
# attempt: 4
# word #139: strap
# attempt: 3
# word #140: maybe
# attempt: 5
# word #141: crime
# attempt: 3
# word #142: plunk
# attempt: 4
# word #143: wrong
# attempt: 5
# word #144: guard
# attempt: 6
# word #145: again
# attempt: 5
# word #146: balsa
# attempt: 3
# word #147: crumb
# attempt: 4
# word #148: hater
# attempt: 6
# word #149: scout
# attempt: 4
# word #150: ennui
# attempt: 3
# word #151: beast
# attempt: 3
# word #152: nanny
# attempt: 5
# word #153: humid
# attempt: 4
# word #154: jazzy
# attempt: 4
# word #155: agile
# attempt: 4
# word #156: kneel
# attempt: 3
# word #157: mouse
# attempt: 3
# word #158: skimp
# attempt: 4
# word #159: ramen
# attempt: 5
# word #160: swine
# attempt: 5
# word #161: bagel
# attempt: 5
# word #162: utter
# attempt: 4
# word #163: clerk
# attempt: 4
# word #164: igloo
# attempt: 4
# word #165: brash
# attempt: 5
# word #166: flask
# attempt: 3
# word #167: grief
# attempt: 4
# word #168: shorn
# attempt: 4
# word #169: plank
# attempt: 5
# word #170: latte
# attempt: 4
# word #171: canoe
# attempt: 3
# word #172: scarf
# attempt: 3
# word #173: acrid
# attempt: 5
# word #174: snack
# attempt: 4
# word #175: broom
# attempt: 5
# word #176: ethic
# attempt: 4
# word #177: cocoa
# attempt: 5
# word #178: aglow
# attempt: 4
# word #179: ghoul
# attempt: 4
# word #180: anger
# attempt: 2
# word #181: below
# attempt: 3
# word #182: guppy
# attempt: 6
# word #183: horde
# attempt: 4
# word #184: sulky
# attempt: 5
# word #185: range
# attempt: 3
# word #186: plaza
# attempt: 5
# word #187: cedar
# attempt: 4
# word #188: circa
# attempt: 4
# word #189: logic
# attempt: 4
# word #190: metro
# attempt: 3
# word #191: joker
# attempt: 6
# word #192: ditto
# attempt: 4
# word #193: unzip
# attempt: 3
# word #194: broke
# attempt: 4
# word #195: kayak
# attempt: 3
# word #196: plate
# attempt: 6
# word #197: thump
# attempt: 4
# word #198: hound
# attempt: 4
# word #199: whiff
# attempt: 4
# word #200: dwelt
# attempt: 4
# word #201: agony
# attempt: 5
# word #202: thief
# attempt: 2
# word #203: carat
# attempt: 3
# word #204: borax
# attempt: 3
# word #205: qualm
# attempt: 4
# word #206: under
# attempt: 3
# word #207: snafu
# attempt: 4
# word #208: ledge
# attempt: 4
# word #209: locus
# attempt: 4
# word #210: leafy
# attempt: 3
# word #211: smash
# attempt: 3
# word #212: ratio
# attempt: 2
# word #213: flora
# attempt: 3
# word #214: stock
# attempt: 4
# word #215: march
# attempt: 4
# word #216: every
# attempt: 5
# word #217: bread
# attempt: 4
# word #218: beset
# attempt: 2
# word #219: hurry
# attempt: 5
# word #220: guano
# attempt: 3
# word #221: untie
# attempt: 2
# word #222: voter
# attempt: 4
# word #223: grout
# attempt: 3
# word #224: staid
# attempt: 3
# word #225: duvet
# attempt: 3
# word #226: tough
# attempt: 5
# word #227: glove
# attempt: 5
# word #228: credo
# attempt: 4
# word #229: yacht
# attempt: 4
# word #230: mealy
# attempt: 5
# word #231: cider
# attempt: 5
# word #232: sweep
# attempt: 4
# word #233: surly
# attempt: 4
# word #234: blame
# attempt: 7
# word #235: birth
# attempt: 4
# word #236: email
# attempt: 4
# word #237: revel
# attempt: 5
# word #238: where
# attempt: 4
# word #239: regal
# attempt: 6
# word #240: horse
# attempt: 3
# word #241: pinky
# attempt: 2
# word #242: toxic
# attempt: 4
# word #243: trend
# attempt: 3
# word #244: squat
# attempt: 4
# word #245: above
# attempt: 4
# word #246: moose
# attempt: 4
# word #247: polka
# attempt: 5
# word #248: worse
# attempt: 5
# word #249: syrup
# attempt: 3
# word #250: fifty
# attempt: 4
# word #251: arbor
# attempt: 3
# word #252: vague
# attempt: 5
# word #253: riper
# attempt: 6
# word #254: ruddy
# attempt: 4
# word #255: sweat
# attempt: 4
# word #256: kiosk
# attempt: 5
# word #257: avail
# attempt: 4
# word #258: cache
# attempt: 5
# word #259: magic
# attempt: 4
# word #260: salsa
# attempt: 4
# word #261: sound
# attempt: 7
# word #262: usage
# attempt: 5
# word #263: giant
# attempt: 3
# word #264: debug
# attempt: 5
# word #265: heady
# attempt: 6
# word #266: stage
# attempt: 5
# word #267: flail
# attempt: 4
# word #268: apple
# attempt: 4
# word #269: ninth
# attempt: 3
# word #270: dance
# attempt: 3
# word #271: unlit
# attempt: 2
# word #272: tasty
# attempt: 5
# word #273: shirk
# attempt: 3
# word #274: scold
# attempt: 4
# word #275: cross
# attempt: 5
# word #276: crave
# attempt: 6
# word #277: fishy
# attempt: 3
# word #278: flirt
# attempt: 3
# word #279: worry
# attempt: 4
# word #280: beefy
# attempt: 3
# word #281: maize
# attempt: 5
# word #282: count
# attempt: 2
# word #283: elude
# attempt: 4
# word #284: matey
# attempt: 3
# word #285: blurb
# attempt: 4
# word #286: alter
# attempt: 2
# word #287: mucky
# attempt: 4
# word #288: chard
# attempt: 4
# word #289: adopt
# attempt: 3
# word #290: frock
# attempt: 5
# word #291: spire
# attempt: 7
# word #292: koala
# attempt: 5
# word #293: human
# attempt: 3
# word #294: leapt
# attempt: 4
# word #295: sedan
# attempt: 3
# word #296: grimy
# attempt: 3
# word #297: pixie
# attempt: 4
# word #298: opera
# attempt: 3
# word #299: lemon
# attempt: 3
# word #300: belie
# attempt: 4
# word #301: sleek
# attempt: 4
# word #302: layer
# attempt: 5
# word #303: antic
# attempt: 2
# word #304: skirt
# attempt: 4
# word #305: whine
# attempt: 3
# word #306: manly
# attempt: 5
# word #307: molar
# attempt: 5
# word #308: havoc
# attempt: 4
# word #309: impel
# attempt: 4
# word #310: condo
# attempt: 4
# word #311: judge
# attempt: 5
# word #312: extra
# attempt: 3
# word #313: poise
# attempt: 4
# word #314: aorta
# attempt: 4
# word #315: excel
# attempt: 4
# word #316: lunar
# attempt: 3
# word #317: third
# attempt: 4
# word #318: slate
# attempt: 3
# word #319: taper
# attempt: 4
# word #320: chord
# attempt: 4
# word #321: probe
# attempt: 4
# word #322: rival
# attempt: 4
# word #323: usual
# attempt: 4
# word #324: spoke
# attempt: 6
# word #325: apply
# attempt: 4
# word #326: naive
# attempt: 3
# word #327: knock
# attempt: 4
# word #328: braid
# attempt: 5
# word #329: infer
# attempt: 3
# word #330: joust
# attempt: 5
# word #331: amber
# attempt: 4
# word #332: woken
# attempt: 5
# word #333: adore
# attempt: 4
# word #334: torso
# attempt: 3
# word #335: chafe
# attempt: 3
# word #336: eject
# attempt: 4
# word #337: study
# attempt: 4
# word #338: undue
# attempt: 5
# word #339: tepid
# attempt: 5
# word #340: happy
# attempt: 4
# word #341: clean
# attempt: 3
# word #342: itchy
# attempt: 4
# word #343: feast
# attempt: 3
# word #344: drive
# attempt: 6
# word #345: prime
# attempt: 4
# word #346: axiom
# attempt: 4
# word #347: brave
# attempt: 4
# word #348: avert
# attempt: 3
# word #349: glyph
# attempt: 4
# word #350: there
# attempt: 4
# word #351: baker
# attempt: 7
# word #352: snarl
# attempt: 3
# word #353: maple
# attempt: 4
# word #354: inane
# attempt: 4
# word #355: valet
# attempt: 4
# word #356: medal
# attempt: 5
# word #357: unite
# attempt: 3
# word #358: rainy
# attempt: 3
# word #359: spell
# attempt: 5
# word #360: begin
# attempt: 4
# word #361: stale
# attempt: 6
# word #362: dream
# attempt: 4
# word #363: photo
# attempt: 3
# word #364: aloud
# attempt: 4
# word #365: inept
# attempt: 4
# word #366: piney
# attempt: 3
# word #367: aptly
# attempt: 4
# word #368: waltz
# attempt: 5
# word #369: libel
# attempt: 4
# word #370: sneak
# attempt: 4
# word #371: carry
# attempt: 4
# word #372: flout
# attempt: 4
# word #373: foggy
# attempt: 3
# word #374: fault
# attempt: 3
# word #375: mummy
# attempt: 5
# word #376: spiel
# attempt: 4
# word #377: grove
# attempt: 3
# word #378: denim
# attempt: 3
# word #379: quirk
# attempt: 4
# word #380: exist
# attempt: 4
# word #381: stein
# attempt: 2
# word #382: spade
# attempt: 5
# word #383: catch
# attempt: 3
# word #384: floor
# attempt: 6
# word #385: equal
# attempt: 4
# word #386: ionic
# attempt: 3
# word #387: valid
# attempt: 5
# word #388: enjoy
# attempt: 4
# word #389: howdy
# attempt: 4
# word #390: vigor
# attempt: 4
# word #391: dandy
# attempt: 6
# word #392: sloth
# attempt: 3
# word #393: marsh
# attempt: 5
# word #394: bough
# attempt: 5
# word #395: sting
# attempt: 3
# word #396: twine
# attempt: 3
# word #397: leave
# attempt: 4
# word #398: scorn
# attempt: 4
# word #399: scald
# attempt: 4
# word #400: usurp
# attempt: 4
# word #401: soggy
# attempt: 4
# word #402: brisk
# attempt: 3
# word #403: admit
# attempt: 4
# word #404: grate
# attempt: 7
# word #405: glory
# attempt: 4
# word #406: saint
# attempt: 3
# word #407: recap
# attempt: 4
# word #408: alike
# attempt: 4
# word #409: trice
# attempt: 6
# word #410: stick
# attempt: 4
# word #411: chute
# attempt: 3
# word #412: parer
# attempt: 3
# word #413: doubt
# attempt: 4
# word #414: thyme
# attempt: 4
# word #415: alpha
# attempt: 5
# word #416: booze
# attempt: 4
# word #417: tibia
# attempt: 5
# word #418: lofty
# attempt: 3
# word #419: theme
# attempt: 4
# word #420: class
# attempt: 5
# word #421: leery
# attempt: 4
# word #422: taunt
# attempt: 4
# word #423: whoop
# attempt: 5
# word #424: inter
# attempt: 3
# word #425: gully
# attempt: 4
# word #426: charm
# attempt: 4
# word #427: fungi
# attempt: 3
# word #428: prize
# attempt: 6
# word #429: onset
# attempt: 2
# word #430: chief
# attempt: 3
# word #431: gauze
# attempt: 5
# word #432: ruder
# attempt: 4
# word #433: irony
# attempt: 3
# word #434: clown
# attempt: 3
# word #435: needy
# attempt: 3
# word #436: woven
# attempt: 4
# word #437: merit
# attempt: 6
# word #438: waste
# attempt: 7
# word #439: treat
# attempt: 4
# word #440: shrug
# attempt: 3
# word #441: twang
# attempt: 4
# word #442: twice
# attempt: 4
# word #443: gruel
# attempt: 4
# word #444: poker
# attempt: 4
# word #445: khaki
# attempt: 3
# word #446: hunky
# attempt: 4
# word #447: label
# attempt: 6
# word #448: glean
# attempt: 2
# word #449: cling
# attempt: 4
# word #450: patty
# attempt: 3
# word #451: unfit
# attempt: 3
# word #452: smear
# attempt: 5
# word #453: alien
# attempt: 4
# word #454: buggy
# attempt: 6
# word #455: rhyme
# attempt: 5
# word #456: youth
# attempt: 3
# word #457: coyly
# attempt: 4
# word #458: quart
# attempt: 4
# word #459: cramp
# attempt: 6
# word #460: bluff
# attempt: 4
# word #461: upset
# attempt: 2
# word #462: stomp
# attempt: 4
# word #463: motto
# attempt: 3
# word #464: cinch
# attempt: 4
# word #465: elope
# attempt: 5
# word #466: power
# attempt: 4
# word #467: midge
# attempt: 4
# word #468: tryst
# attempt: 4
# word #469: aphid
# attempt: 5
# word #470: trite
# attempt: 5
# word #471: angry
# attempt: 4
# word #472: flock
# attempt: 3
# word #473: wacky
# attempt: 5
# word #474: roomy
# attempt: 5
# word #475: wedge
# attempt: 6
# word #476: liver
# attempt: 5
# word #477: bland
# attempt: 3
# word #478: night
# attempt: 2
# word #479: madam
# attempt: 4
# word #480: berth
# attempt: 4
# word #481: stead
# attempt: 5
# word #482: voice
# attempt: 4
# word #483: agape
# attempt: 5
# word #484: fluff
# attempt: 3
# word #485: field
# attempt: 3
# word #486: sever
# attempt: 4
# word #487: lilac
# attempt: 5
# word #488: egret
# attempt: 5
# word #489: pinto
# attempt: 4
# word #490: hutch
# attempt: 5
# word #491: gawky
# attempt: 5
# word #492: droll
# attempt: 5
# word #493: retro
# attempt: 2
# word #494: rusty
# attempt: 3
# word #495: beady
# attempt: 3
# word #496: smite
# attempt: 3
# word #497: brink
# attempt: 5
# word #498: awful
# attempt: 4
# word #499: gloat
# attempt: 3
# word #500: input
# attempt: 3
# word #501: loser
# attempt: 4
# word #502: cacao
# attempt: 4
# word #503: blown
# attempt: 3
# word #504: apron
# attempt: 4
# word #505: primo
# attempt: 4
# word #506: atone
# attempt: 2
# word #507: donor
# attempt: 3
# word #508: float
# attempt: 3
# word #509: goose
# attempt: 5
# word #510: piety
# attempt: 4
# word #511: girth
# attempt: 4
# word #512: trait
# attempt: 5
# word #513: flood
# attempt: 5
# word #514: gloom
# attempt: 3
# word #515: depth
# attempt: 3
# word #516: froth
# attempt: 3
# word #517: phase
# attempt: 5
# word #518: showy
# attempt: 3
# word #519: creak
# attempt: 4
# word #520: manor
# attempt: 3
# word #521: atoll
# attempt: 3
# word #522: bayou
# attempt: 3
# word #523: crept
# attempt: 5
# word #524: tiara
# attempt: 4
# word #525: asset
# attempt: 3
# word #526: vouch
# attempt: 4
# word #527: album
# attempt: 4
# word #528: hinge
# attempt: 3
# word #529: money
# attempt: 3
# word #530: scrap
# attempt: 4
# word #531: gamer
# attempt: 2
# word #532: glass
# attempt: 4
# word #533: scour
# attempt: 3
# word #534: being
# attempt: 3
# word #535: delve
# attempt: 5
# word #536: yield
# attempt: 4
# word #537: metal
# attempt: 4
# word #538: tipsy
# attempt: 3
# word #539: slung
# attempt: 4
# word #540: farce
# attempt: 3
# word #541: gecko
# attempt: 4
# word #542: fetus
# attempt: 4
# word #543: shine
# attempt: 6
# word #544: canny
# attempt: 3
# word #545: midst
# attempt: 4
# word #546: badge
# attempt: 4
# word #547: homer
# attempt: 3
# word #548: train
# attempt: 3
# word #549: hairy
# attempt: 3
# word #550: story
# attempt: 4
# word #551: forgo
# attempt: 3
# word #552: larva
# attempt: 5
# word #553: trash
# attempt: 4
# word #554: zesty
# attempt: 6
# word #555: shown
# attempt: 5
# word #556: heist
# attempt: 4
# word #557: askew
# attempt: 5
# word #558: inert
# attempt: 4
# word #559: olive
# attempt: 4
# word #560: plant
# attempt: 2
# word #561: oxide
# attempt: 3
# word #562: cargo
# attempt: 4
# word #563: foyer
# attempt: 2
# word #564: flair
# attempt: 3
# word #565: ample
# attempt: 5
# word #566: cheek
# attempt: 5
# word #567: shame
# attempt: 9
# word #568: mince
# attempt: 3
# word #569: chunk
# attempt: 3
# word #570: royal
# attempt: 4
# word #571: squad
# attempt: 4
# word #572: black
# attempt: 4
# word #573: stair
# attempt: 3
# word #574: scare
# attempt: 6
# word #575: foray
# attempt: 4
# word #576: comma
# attempt: 4
# word #577: natal
# attempt: 3
# word #578: shawl
# attempt: 5
# word #579: fewer
# attempt: 5
# word #580: trope
# attempt: 3
# word #581: snout
# attempt: 4
# word #582: lowly
# attempt: 5
# word #583: stove
# attempt: 4
# word #584: shall
# attempt: 5
# word #585: found
# attempt: 2
# word #586: nymph
# attempt: 4
# word #587: epoxy
# attempt: 4
# word #588: depot
# attempt: 3
# word #589: chest
# attempt: 4
# word #590: purge
# attempt: 5
# word #591: their
# attempt: 3
# word #592: slosh
# attempt: 3
# word #593: renew
# attempt: 3
# word #594: allow
# attempt: 5
# word #595: saute
# attempt: 4
# word #596: movie
# attempt: 4
# word #597: cater
# attempt: 7
# word #598: tease
# attempt: 3
# word #599: smelt
# attempt: 4
# word #600: focus
# attempt: 3
# word #601: today
# attempt: 3
# word #602: watch
# attempt: 7
# word #603: lapse
# attempt: 5
# word #604: month
# attempt: 5
# word #605: sweet
# attempt: 3
# word #606: hoard
# attempt: 3
# word #607: cloth
# attempt: 4
# word #608: brine
# attempt: 5
# word #609: ahead
# attempt: 4
# word #610: mourn
# attempt: 4
# word #611: nasty
# attempt: 3
# word #612: rupee
# attempt: 3
# word #613: choke
# attempt: 4
# word #614: chant
# attempt: 3
# word #615: spill
# attempt: 4
# word #616: vivid
# attempt: 4
# word #617: bloke
# attempt: 4
# word #618: trove
# attempt: 5
# word #619: thorn
# attempt: 4
# word #620: other
# attempt: 2
# word #621: tacit
# attempt: 3
# word #622: swill
# attempt: 4
# word #623: dodge
# attempt: 4
# word #624: shake
# attempt: 4
# word #625: caulk
# attempt: 3
# word #626: agora
# attempt: 4
# word #627: aroma
# attempt: 5
# word #628: cynic
# attempt: 4
# word #629: robin
# attempt: 4
# word #630: ultra
# attempt: 3
# word #631: ulcer
# attempt: 4
# word #632: pause
# attempt: 5
# word #633: humor
# attempt: 5
# word #634: frame
# attempt: 3
# word #635: elder
# attempt: 3
# word #636: skill
# attempt: 4
# word #637: aloft
# attempt: 3
# word #638: pleat
# attempt: 3
# word #639: shard
# attempt: 5
# word #640: moist
# attempt: 4
# word #641: those
# attempt: 3
# word #642: light
# attempt: 4
# word #643: wrung
# attempt: 3
# word #644: could
# attempt: 5
# word #645: perky
# attempt: 5
# word #646: mount
# attempt: 3
# word #647: whack
# attempt: 4
# word #648: sugar
# attempt: 5
# word #649: knoll
# attempt: 5
# word #650: crimp
# attempt: 5
# word #651: wince
# attempt: 4
# word #652: prick
# attempt: 5
# word #653: robot
# attempt: 3
# word #654: point
# attempt: 3
# word #655: proxy
# attempt: 5
# word #656: shire
# attempt: 4
# word #657: solar
# attempt: 5
# word #658: panic
# attempt: 4
# word #659: tangy
# attempt: 3
# word #660: abbey
# attempt: 2
# word #661: favor
# attempt: 3
# word #662: drink
# attempt: 5
# word #663: query
# attempt: 3
# word #664: gorge
# attempt: 4
# word #665: crank
# attempt: 3
# word #666: slump
# attempt: 4
# word #667: banal
# attempt: 4
# word #668: tiger
# attempt: 4
# word #669: siege
# attempt: 5
# word #670: truss
# attempt: 5
# word #671: boost
# attempt: 4
# word #672: rebus
# attempt: 5
# word #673: unify
# attempt: 4
# word #674: troll
# attempt: 4
# word #675: tapir
# attempt: 4
# word #676: aside
# attempt: 4
# word #677: ferry
# attempt: 4
# word #678: acute
# attempt: 4
# word #679: picky
# attempt: 4
# word #680: weary
# attempt: 5
# word #681: gripe
# attempt: 4
# word #682: craze
# attempt: 4
# word #683: pluck
# attempt: 4
# word #684: brake
# attempt: 4
# word #685: baton
# attempt: 2
# word #686: champ
# attempt: 4
# word #687: peach
# attempt: 4
# word #688: using
# attempt: 5
# word #689: trace
# attempt: 5
# word #690: vital
# attempt: 4
# word #691: sonic
# attempt: 3
# word #692: masse
# attempt: 5
# word #693: conic
# attempt: 5
# word #694: viral
# attempt: 4
# word #695: rhino
# attempt: 5
# word #696: break
# attempt: 4
# word #697: triad
# attempt: 5
# word #698: epoch
# attempt: 4
# word #699: usher
# attempt: 4
# word #700: exult
# attempt: 4
# word #701: grime
# attempt: 5
# word #702: cheat
# attempt: 4
# word #703: solve
# attempt: 3
# word #704: bring
# attempt: 4
# word #705: prove
# attempt: 6
# word #706: store
# attempt: 3
# word #707: tilde
# attempt: 3
# word #708: clock
# attempt: 4
# word #709: wrote
# attempt: 4
# word #710: retch
# attempt: 3
# word #711: perch
# attempt: 4
# word #712: rouge
# attempt: 4
# word #713: radio
# attempt: 4
# word #714: surer
# attempt: 3
# word #715: finer
# attempt: 3
# word #716: vodka
# attempt: 4
# word #717: heron
# attempt: 3
# word #718: chill
# attempt: 4
# word #719: gaudy
# attempt: 4
# word #720: pithy
# attempt: 3
# word #721: smart
# attempt: 4
# word #722: badly
# attempt: 6
# word #723: rogue
# attempt: 4
# word #724: group
# attempt: 4
# word #725: fixer
# attempt: 2
# word #726: groin
# attempt: 4
# word #727: duchy
# attempt: 5
# word #728: coast
# attempt: 4
# word #729: blurt
# attempt: 3
# word #730: pulpy
# attempt: 3
# word #731: altar
# attempt: 5
# word #732: great
# attempt: 5
# word #733: briar
# attempt: 4
# word #734: click
# attempt: 6
# word #735: gouge
# attempt: 3
# word #736: world
# attempt: 4
# word #737: erode
# attempt: 4
# word #738: boozy
# attempt: 4
# word #739: dozen
# attempt: 4
# word #740: fling
# attempt: 3
# word #741: growl
# attempt: 4
# word #742: abyss
# attempt: 4
# word #743: steed
# attempt: 4
# word #744: enema
# attempt: 3
# word #745: jaunt
# attempt: 4
# word #746: comet
# attempt: 3
# word #747: tweed
# attempt: 3
# word #748: pilot
# attempt: 3
# word #749: dutch
# attempt: 4
# word #750: belch
# attempt: 4
# word #751: ought
# attempt: 3
# word #752: dowry
# attempt: 4
# word #753: thumb
# attempt: 4
# word #754: hyper
# attempt: 4
# word #755: hatch
# attempt: 8
# word #756: alone
# attempt: 3
# word #757: motor
# attempt: 4
# word #758: aback
# attempt: 5
# word #759: guild
# attempt: 5
# word #760: kebab
# attempt: 4
# word #761: spend
# attempt: 3
# word #762: fjord
# attempt: 5
# word #763: essay
# attempt: 4
# word #764: spray
# attempt: 5
# word #765: spicy
# attempt: 5
# word #766: agate
# attempt: 4
# word #767: salad
# attempt: 3
# word #768: basic
# attempt: 4
# word #769: moult
# attempt: 6
# word #770: corny
# attempt: 4
# word #771: forge
# attempt: 3
# word #772: civic
# attempt: 4
# word #773: islet
# attempt: 4
# word #774: labor
# attempt: 5
# word #775: gamma
# attempt: 4
# word #776: lying
# attempt: 4
# word #777: audit
# attempt: 4
# word #778: round
# attempt: 6
# word #779: loopy
# attempt: 4
# word #780: lusty
# attempt: 6
# word #781: golem
# attempt: 4
# word #782: goner
# attempt: 3
# word #783: greet
# attempt: 3
# word #784: start
# attempt: 6
# word #785: lapel
# attempt: 4
# word #786: biome
# attempt: 4
# word #787: parry
# attempt: 5
# word #788: shrub
# attempt: 4
# word #789: front
# attempt: 2
# word #790: wooer
# attempt: 2
# word #791: totem
# attempt: 3
# word #792: flick
# attempt: 4
# word #793: delta
# attempt: 4
# word #794: bleed
# attempt: 5
# word #795: argue
# attempt: 4
# word #796: swirl
# attempt: 3
# word #797: error
# attempt: 4
# word #798: agree
# attempt: 4
# word #799: offal
# attempt: 2
# word #800: flume
# attempt: 3
# word #801: crass
# attempt: 5
# word #802: panel
# attempt: 4
# word #803: stout
# attempt: 4
# word #804: bribe
# attempt: 7
# word #805: drain
# attempt: 5
# word #806: yearn
# attempt: 4
# word #807: print
# attempt: 4
# word #808: seedy
# attempt: 4
# word #809: ivory
# attempt: 4
# word #810: belly
# attempt: 5
# word #811: stand
# attempt: 4
# word #812: first
# attempt: 5
# word #813: forth
# attempt: 3
# word #814: booby
# attempt: 4
# word #815: flesh
# attempt: 4
# word #816: unmet
# attempt: 2
# word #817: linen
# attempt: 5
# word #818: maxim
# attempt: 4
# word #819: pound
# attempt: 6
# word #820: mimic
# attempt: 5
# word #821: spike
# attempt: 5
# word #822: cluck
# attempt: 6
# word #823: crate
# attempt: 4
# word #824: digit
# attempt: 5
# word #825: repay
# attempt: 4
# word #826: sower
# attempt: 4
# word #827: crazy
# attempt: 7
# word #828: adobe
# attempt: 3
# word #829: outdo
# attempt: 2
# word #830: trawl
# attempt: 4
# word #831: whelp
# attempt: 5
# word #832: unfed
# attempt: 3
# word #833: paper
# attempt: 5
# word #834: staff
# attempt: 4
# word #835: croak
# attempt: 5
# word #836: helix
# attempt: 4
# word #837: floss
# attempt: 4
# word #838: pride
# attempt: 6
# word #839: batty
# attempt: 6
# word #840: react
# attempt: 4
# word #841: marry
# attempt: 4
# word #842: abase
# attempt: 4
# word #843: colon
# attempt: 4
# word #844: stool
# attempt: 6
# word #845: crust
# attempt: 4
# word #846: fresh
# attempt: 4
# word #847: death
# attempt: 5
# word #848: major
# attempt: 6
# word #849: feign
# attempt: 2
# word #850: abate
# attempt: 7
# word #851: bench
# attempt: 4
# word #852: quiet
# attempt: 3
# word #853: grade
# attempt: 4
# word #854: stink
# attempt: 3
# word #855: karma
# attempt: 5
# word #856: model
# attempt: 4
# word #857: dwarf
# attempt: 4
# word #858: heath
# attempt: 5
# word #859: serve
# attempt: 5
# word #860: naval
# attempt: 4
# word #861: evade
# attempt: 5
# word #862: focal
# attempt: 4
# word #863: blush
# attempt: 3
# word #864: awake
# attempt: 7
# word #865: humph
# attempt: 3
# word #866: sissy
# attempt: 4
# word #867: rebut
# attempt: 4
# word #868: cigar
# attempt: 4

# %%
# Print average attempts for training and testing
avg_training_attempts = sum(training_attempts) / len(training_attempts)
avg_testing_attempts = sum(testing_attempts) / len(testing_attempts)

print(f"Average attempts during training: {avg_training_attempts:.2f}")
print(f"Average attempts during testing: {avg_testing_attempts:.2f}")
# Out:
# Average attempts during training: 4.02
# Average attempts during testing: 4.00

# %%
import matplotlib.pyplot as plt

unique_elements, counts = [], []

for item in set(training_attempts):
    unique_elements.append(item)
    counts.append(training_attempts.count(item))

# Create a bar graph
bars = plt.bar(unique_elements, counts, color='#ec443c')
for i, bar in enumerate(bars):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, f'{yval}', ha='center', va='bottom', fontsize=8)

# Add data labels
# for i, count in enumerate(counts):
#     plt.text(unique_elements[i], count + 0.1, str(count), ha='center', va='bottom')

# Add labels and title
plt.xlabel('Elements')
plt.ylabel('Frequency')
plt.title('Frequency of Attempts in Training')

# Show the plot
plt.show()

unique_elements, counts = [], []

for item in set(testing_attempts):
    unique_elements.append(item)
    counts.append(testing_attempts.count(item))

# Create a bar graph
bars = plt.bar(unique_elements, counts, color='#ec443c')
for i, bar in enumerate(bars):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, f'{yval}', ha='center', va='bottom', fontsize=8)

# Add data labels
# for i, count in enumerate(counts):
#     plt.text(unique_elements[i], count + 0.1, str(count), ha='center', va='bottom')

# Add labels and title
plt.xlabel('Elements')
plt.ylabel('Frequency')
plt.title('Frequency of Attempts in Testing')

# Show the plot
plt.show()

# %%
# Main game loop
attempts = 0
previous_guesses = []

print("Let's Play Wordle!")
print("Please think of a word and provide feedback as follows:")
print("0 for MISS, 1 for MISPLACED, and 2 for EXACT.")

while True:
    attempts += 1
    guess = bayesian_choose_word(possible_words, previous_guesses)
    
    # First step to set the first word
    if attempts == 1: guess = random.choice(great_starting_word)
    
    feedback = []
    while True:
        try:
            feedback_input = input(f"Attempt {attempts}: {guess} - Enter feedback (0/1/2): ")
            feedback_input = [int(f) for f in feedback_input]
            if all(f in [0, 1, 2] for f in feedback_input) and len(feedback_input) == 5:
                for i in range(len(feedback_input)):
                    if feedback_input[i] == 0:
                        feedback.append("⬛")
                    elif feedback_input[i] == 1:
                        feedback.append("🟨")
                    elif feedback_input[i] == 2:
                        feedback.append("🟩")
            else:
                print("Invalid feedback. Please provide feedback as 0, 1, or 2.")
        except ValueError:
            print("Invalid feedback. Please provide feedback as 0, 1, or 2.")
        if len(feedback) == len(feedback_input):
            feedback = "".join(feedback)
            break
    previous_guesses.append((guess, feedback))
    print(feedback)

    if feedback.count("🟩") == 5:
        print(f"Congratulations! The word was '{guess}'. It took {attempts} attempts to guess.")
        break
# Out:
# Let's Play Wordle!
# Please think of a word and provide feedback as follows:
# 0 for MISS, 1 for MISPLACED, and 2 for EXACT.
# Invalid feedback. Please provide feedback as 0, 1, or 2.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\jiunk\Desktop\UTK\Semesters\Fall 2023\Courses\COSC 425\Wordle-Solver\Models\play_wordle_fixed_first_word.ipynb Cell 11 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/jiunk/Desktop/UTK/Semesters/Fall%202023/Courses/COSC%20425/Wordle-Solver/Models/play_wordle_fixed_first_word.ipynb#X13sZmlsZQ%3D%3D?line=8'>9</a> while True:
#      <a href='vscode-notebook-cell:/c%3A/Users/jiunk/Desktop/UTK/Semesters/Fall%202023/Courses/COSC%20425/Wordle-Solver/Models/play_wordle_fixed_first_word.ipynb#X13sZmlsZQ%3D%3D?line=9'>10</a>     attempts += 1
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jiunk/Desktop/UTK/Semesters/Fall%202023/Courses/COSC%20425/Wordle-Solver/Models/play_wordle_fixed_first_word.ipynb#X13sZmlsZQ%3D%3D?line=10'>11</a>     guess = bayesian_choose_word(possible_words, previous_guesses)
#      <a href='vscode-notebook-cell:/c%3A/Users/jiunk/Desktop/UTK/Semesters/Fall%202023/Courses/COSC%20425/Wordle-Solver/Models/play_wordle_fixed_first_word.ipynb#X13sZmlsZQ%3D%3D?line=12'>13</a>     # First step to set the first word
#      <a href='vscode-notebook-cell:/c%3A/Users/jiunk/Desktop/UTK/Semesters/Fall%202023/Courses/COSC%20425/Wordle-Solver/Models/play_wordle_fixed_first_word.ipynb#X13sZmlsZQ%3D%3D?line=13'>14</a>     if attempts == 1: guess = random.choice(great_starting_word)
#
# c:\Users\jiunk\Desktop\UTK\Semesters\Fall 2023\Courses\COSC 425\Wordle-Solver\Models\play_wordle_fixed_first_word.ipynb Cell 11 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/jiunk/Desktop/UTK/Semesters/Fall%202023/Courses/COSC%20425/Wordle-Solver/Models/play_wordle_fixed_first_word.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> for word in possible_words:
#       <a href='vscode-notebook-cell:/c%3A/Users/jiunk/Desktop/UTK/Semesters/Fall%202023/Courses/COSC%20425/Wordle-Solver/Models/play_wordle_fixed_first_word.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a>     for guess, feedback in previous_guesses:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jiunk/Desktop/UTK/Semesters/Fall%202023/Courses/COSC%20425/Wordle-Solver/Models/play_wordle_fixed_first_word.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a>         guess_feedback = evaluate_guess(word, guess)
#       <a href='vscode-notebook-cell:/c%3A/Users/jiunk/Desktop/UTK/Semesters/Fall%202023/Courses/COSC%20425/Wordle-Solver/Models/play_wordle_fixed_first_word.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a>         if guess_feedback == feedback:
#       <a href='vscode-notebook-cell:/c%3A/Users/jiunk/Desktop/UTK/Semesters/Fall%202023/Courses/COSC%20425/Wordle-Solver/Models/play_wordle_fixed_first_word.ipynb#X13sZmlsZQ%3D%3D?line=7'>8</a>             scores[word] += 1
#
# c:\Users\jiunk\Desktop\UTK\Semesters\Fall 2023\Courses\COSC 425\Wordle-Solver\Models\play_wordle_fixed_first_word.ipynb Cell 11 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/jiunk/Desktop/UTK/Semesters/Fall%202023/Courses/COSC%20425/Wordle-Solver/Models/play_wordle_fixed_first_word.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a> remaining_secret_letters = list(secret_word)
#       <a href='vscode-notebook-cell:/c%3A/Users/jiunk/Desktop/UTK/Semesters/Fall%202023/Courses/COSC%20425/Wordle-Solver/Models/play_wordle_fixed_first_word.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> # First, check exact matches (greens)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jiunk/Desktop/UTK/Semesters/Fall%202023/Courses/COSC%20425/Wordle-Solver/Models/play_wordle_fixed_first_word.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a> for i, (g1, g2) in enumerate(zip(secret_word, guess_copy)):
#       <a href='vscode-notebook-cell:/c%3A/Users/jiunk/Desktop/UTK/Semesters/Fall%202023/Courses/COSC%20425/Wordle-Solver/Models/play_wordle_fixed_first_word.ipynb#X13sZmlsZQ%3D%3D?line=7'>8</a>     if g1 == g2:
#       <a href='vscode-notebook-cell:/c%3A/Users/jiunk/Desktop/UTK/Semesters/Fall%202023/Courses/COSC%20425/Wordle-Solver/Models/play_wordle_fixed_first_word.ipynb#X13sZmlsZQ%3D%3D?line=8'>9</a>         feedback.append("🟩")
#
# TypeError: 'NoneType' object is not iterable
