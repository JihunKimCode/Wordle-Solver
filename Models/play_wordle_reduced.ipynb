# %%
import random
import matplotlib.pyplot as plt
from collections import Counter

# %%
# Load the list of possible words from the file
with open('../Dataset/reduced_possible_words.txt', 'r') as file:
    possible_words = [line.strip() for line in file]

# Load the list of words for testing from the file
with open('../Dataset/prev_words_chr.txt', 'r') as file:
    testing_set = [line.strip() for line in file]

# %%
# Define feedback symbols
MISS = "⬛"
MISPLACED = "🟨"
EXACT = "🟩"

# %%
# Function to evaluate a guess based on feedback
def evaluate_guess(secret_word, guess):
    guess_copy = guess
    feedback = []
    remaining_secret_letters = list(secret_word)
    # First, check exact matches (greens)
    for i, (g1, g2) in enumerate(zip(secret_word, guess_copy)):
        if g1 == g2:
            feedback.append("🟩")
            remaining_secret_letters.remove(g1)
            guess_copy = guess_copy[:i] + "🟩" + guess_copy[i+1:]
        else:
            feedback.append("⬛")
    feedback_str = "".join(feedback)
    # Then, check letters but not in location (yellows)
    for i, g2 in enumerate(guess_copy):
        if g2 in remaining_secret_letters:
            feedback_str = feedback_str[:i] + "🟨" + feedback_str[i+1:]
            remaining_secret_letters.remove(g2)
    feedback = feedback_str
    return "".join(feedback)

# %%
# Function to generate a random word from the list of possible words
def choose_random_word(list):
    word = random.choice(possible_words)
    while word in list: word = random.choice(possible_words)
    return word

# %%
# Bayesian algorithm for word selection
def bayesian_choose_word(possible_words, previous_guesses):
    scores = {word: 0 for word in possible_words}
    for word in possible_words:
        for guess, feedback in previous_guesses:
            guess_feedback = evaluate_guess(word, guess)
            if guess_feedback == feedback:
                scores[word] += 1
    best_words = [word for word, score in scores.items() if score == max(scores.values())]
    return random.choice(best_words)

# %%
# Training phase
training_set_size = 1000  # Adjust as needed
training_set = []
training_set = [choose_random_word(training_set) for _ in range(training_set_size)]
training_attempts = []

great_starting_word = []
great_starting_word_attempts = float('inf')

word = 0
the_word = None

for target_word in training_set:
    attempts = 0
    previous_guesses = []
    word += 1
    print(f"word #{word}: {target_word}")
    
    while True:
        attempts += 1
        guess = bayesian_choose_word(possible_words, previous_guesses)
        
        if attempts == 1:
            the_word = guess
        # elif attempts == 2:
        #     the_word = guess
        
        feedback = evaluate_guess(target_word, guess)
        previous_guesses.append((guess, feedback))
        if target_word == guess:
            print(f"attempt: {attempts}")
            training_attempts.append(attempts)
            
            if attempts < 3:
                great_starting_word.append(the_word)
                # great_starting_word_attempts = attempts
            break
# Out:
# word #1: gauze
# attempt: 3
# word #2: tango
# attempt: 5
# word #3: hoist
# attempt: 4
# word #4: fable
# attempt: 3
# word #5: login
# attempt: 4
# word #6: trace
# attempt: 4
# word #7: pagan
# attempt: 3
# word #8: foamy
# attempt: 3
# word #9: offer
# attempt: 4
# word #10: flake
# attempt: 4
# word #11: grunt
# attempt: 5
# word #12: blank
# attempt: 4
# word #13: lance
# attempt: 3
# word #14: godly
# attempt: 4
# word #15: flunk
# attempt: 3
# word #16: pooch
# attempt: 5
# word #17: talon
# attempt: 4
# word #18: depot
# attempt: 4
# word #19: apart
# attempt: 3
# word #20: drawn
# attempt: 4
# word #21: sauna
# attempt: 4
# word #22: crony
# attempt: 4
# word #23: clown
# attempt: 4
# word #24: ferry
# attempt: 4
# word #25: papal
# attempt: 5
# word #26: taper
# attempt: 4
# word #27: swear
# attempt: 4
# word #28: dairy
# attempt: 4
# word #29: bawdy
# attempt: 4
# word #30: spike
# attempt: 4
# word #31: dried
# attempt: 7
# word #32: chide
# attempt: 5
# word #33: grunt
# attempt: 6
# word #34: abyss
# attempt: 4
# word #35: outgo
# attempt: 4
# word #36: twine
# attempt: 4
# word #37: chore
# attempt: 3
# word #38: apply
# attempt: 5
# word #39: large
# attempt: 4
# word #40: remit
# attempt: 5
# word #41: agile
# attempt: 3
# word #42: taboo
# attempt: 3
# word #43: arose
# attempt: 4
# word #44: ankle
# attempt: 4
# word #45: prune
# attempt: 5
# word #46: natal
# attempt: 2
# word #47: guano
# attempt: 3
# word #48: given
# attempt: 5
# word #49: aware
# attempt: 4
# word #50: depth
# attempt: 6
# word #51: belie
# attempt: 6
# word #52: lyric
# attempt: 5
# word #53: dogma
# attempt: 5
# word #54: label
# attempt: 6
# word #55: share
# attempt: 6
# word #56: rebut
# attempt: 5
# word #57: knead
# attempt: 4
# word #58: juicy
# attempt: 5
# word #59: prize
# attempt: 3
# word #60: abhor
# attempt: 3
# word #61: stage
# attempt: 5
# word #62: union
# attempt: 3
# word #63: twang
# attempt: 4
# word #64: tease
# attempt: 3
# word #65: duchy
# attempt: 3
# word #66: usage
# attempt: 2
# word #67: dealt
# attempt: 4
# word #68: limit
# attempt: 4
# word #69: apple
# attempt: 4
# word #70: crown
# attempt: 4
# word #71: barge
# attempt: 4
# word #72: score
# attempt: 4
# word #73: plier
# attempt: 4
# word #74: idiom
# attempt: 4
# word #75: burly
# attempt: 4
# word #76: geese
# attempt: 4
# word #77: sower
# attempt: 8
# word #78: shirk
# attempt: 4
# word #79: zesty
# attempt: 5
# word #80: smock
# attempt: 4
# word #81: depot
# attempt: 4
# word #82: silky
# attempt: 4
# word #83: until
# attempt: 5
# word #84: large
# attempt: 4
# word #85: snort
# attempt: 5
# word #86: usher
# attempt: 4
# word #87: taboo
# attempt: 5
# word #88: modal
# attempt: 6
# word #89: harsh
# attempt: 2
# word #90: cleft
# attempt: 4
# word #91: shoot
# attempt: 4
# word #92: hussy
# attempt: 3
# word #93: tread
# attempt: 2
# word #94: mafia
# attempt: 5
# word #95: quilt
# attempt: 5
# word #96: stain
# attempt: 5
# word #97: mercy
# attempt: 4
# word #98: troll
# attempt: 3
# word #99: kiosk
# attempt: 5
# word #100: spoke
# attempt: 3
# word #101: rally
# attempt: 4
# word #102: baton
# attempt: 4
# word #103: snuff
# attempt: 4
# word #104: crick
# attempt: 6
# word #105: spare
# attempt: 5
# word #106: allay
# attempt: 6
# word #107: fecal
# attempt: 4
# word #108: thigh
# attempt: 2
# word #109: froth
# attempt: 3
# word #110: bilge
# attempt: 4
# word #111: putty
# attempt: 4
# word #112: shard
# attempt: 4
# word #113: shove
# attempt: 2
# word #114: notch
# attempt: 3
# word #115: woken
# attempt: 3
# word #116: dusky
# attempt: 4
# word #117: amend
# attempt: 3
# word #118: birth
# attempt: 5
# word #119: shuck
# attempt: 3
# word #120: newer
# attempt: 5
# word #121: wafer
# attempt: 4
# word #122: poesy
# attempt: 3
# word #123: amity
# attempt: 3
# word #124: began
# attempt: 3
# word #125: tacit
# attempt: 3
# word #126: slope
# attempt: 4
# word #127: lanky
# attempt: 4
# word #128: fable
# attempt: 4
# word #129: await
# attempt: 4
# word #130: unzip
# attempt: 4
# word #131: raspy
# attempt: 3
# word #132: poppy
# attempt: 4
# word #133: sleek
# attempt: 4
# word #134: hyper
# attempt: 3
# word #135: donut
# attempt: 4
# word #136: sperm
# attempt: 4
# word #137: graft
# attempt: 5
# word #138: sinew
# attempt: 3
# word #139: aider
# attempt: 4
# word #140: inlay
# attempt: 4
# word #141: verso
# attempt: 2
# word #142: clank
# attempt: 3
# word #143: album
# attempt: 4
# word #144: roger
# attempt: 5
# word #145: fetal
# attempt: 5
# word #146: tibia
# attempt: 4
# word #147: hence
# attempt: 6
# word #148: ether
# attempt: 4
# word #149: dream
# attempt: 5
# word #150: vocal
# attempt: 8
# word #151: icily
# attempt: 4
# word #152: nanny
# attempt: 6
# word #153: stead
# attempt: 3
# word #154: gulch
# attempt: 3
# word #155: radar
# attempt: 5
# word #156: grail
# attempt: 2
# word #157: phase
# attempt: 3
# word #158: hence
# attempt: 3
# word #159: ombre
# attempt: 3
# word #160: tibia
# attempt: 2
# word #161: juror
# attempt: 4
# word #162: scowl
# attempt: 3
# word #163: trout
# attempt: 5
# word #164: sigma
# attempt: 3
# word #165: prick
# attempt: 5
# word #166: rowdy
# attempt: 3
# word #167: flaky
# attempt: 3
# word #168: ruddy
# attempt: 5
# word #169: clamp
# attempt: 4
# word #170: photo
# attempt: 4
# word #171: comic
# attempt: 4
# word #172: pause
# attempt: 4
# word #173: puree
# attempt: 4
# word #174: often
# attempt: 4
# word #175: piper
# attempt: 3
# word #176: stalk
# attempt: 6
# word #177: shorn
# attempt: 3
# word #178: tibia
# attempt: 5
# word #179: witch
# attempt: 4
# word #180: erase
# attempt: 3
# word #181: attic
# attempt: 3
# word #182: grove
# attempt: 5
# word #183: draft
# attempt: 5
# word #184: ample
# attempt: 5
# word #185: beech
# attempt: 4
# word #186: snack
# attempt: 4
# word #187: booty
# attempt: 4
# word #188: plaid
# attempt: 4
# word #189: stalk
# attempt: 5
# word #190: rajah
# attempt: 4
# word #191: cargo
# attempt: 4
# word #192: ethos
# attempt: 4
# word #193: reedy
# attempt: 3
# word #194: stuff
# attempt: 6
# word #195: piano
# attempt: 4
# word #196: musty
# attempt: 4
# word #197: eying
# attempt: 5
# word #198: rocky
# attempt: 5
# word #199: lumen
# attempt: 5
# word #200: thumb
# attempt: 4
# word #201: cloth
# attempt: 3
# word #202: shark
# attempt: 5
# word #203: apart
# attempt: 3
# word #204: penal
# attempt: 3
# word #205: libel
# attempt: 6
# word #206: edify
# attempt: 4
# word #207: nymph
# attempt: 3
# word #208: spray
# attempt: 2
# word #209: twang
# attempt: 4
# word #210: corny
# attempt: 3
# word #211: gleam
# attempt: 2
# word #212: rabbi
# attempt: 4
# word #213: suing
# attempt: 4
# word #214: axion
# attempt: 4
# word #215: idler
# attempt: 6
# word #216: emcee
# attempt: 3
# word #217: adobe
# attempt: 4
# word #218: birth
# attempt: 3
# word #219: wrest
# attempt: 3
# word #220: sneer
# attempt: 4
# word #221: knave
# attempt: 3
# word #222: stein
# attempt: 4
# word #223: ledge
# attempt: 5
# word #224: graft
# attempt: 4
# word #225: bunny
# attempt: 7
# word #226: trash
# attempt: 4
# word #227: bound
# attempt: 5
# word #228: snail
# attempt: 5
# word #229: posse
# attempt: 3
# word #230: shook
# attempt: 5
# word #231: clung
# attempt: 3
# word #232: agape
# attempt: 5
# word #233: masse
# attempt: 4
# word #234: filly
# attempt: 7
# word #235: wagon
# attempt: 4
# word #236: fecal
# attempt: 4
# word #237: girth
# attempt: 4
# word #238: chief
# attempt: 2
# word #239: plate
# attempt: 4
# word #240: shame
# attempt: 4
# word #241: islet
# attempt: 4
# word #242: depot
# attempt: 4
# word #243: media
# attempt: 4
# word #244: pedal
# attempt: 4
# word #245: alien
# attempt: 4
# word #246: poesy
# attempt: 4
# word #247: stash
# attempt: 6
# word #248: vault
# attempt: 3
# word #249: stove
# attempt: 5
# word #250: skirt
# attempt: 2
# word #251: oxide
# attempt: 4
# word #252: green
# attempt: 3
# word #253: aging
# attempt: 6
# word #254: broke
# attempt: 5
# word #255: basin
# attempt: 4
# word #256: gazer
# attempt: 5
# word #257: aloft
# attempt: 2
# word #258: flunk
# attempt: 4
# word #259: rough
# attempt: 3
# word #260: giver
# attempt: 5
# word #261: weedy
# attempt: 4
# word #262: unfed
# attempt: 5
# word #263: about
# attempt: 4
# word #264: nerve
# attempt: 5
# word #265: stink
# attempt: 6
# word #266: early
# attempt: 3
# word #267: flour
# attempt: 5
# word #268: smoky
# attempt: 4
# word #269: stale
# attempt: 3
# word #270: parry
# attempt: 4
# word #271: smite
# attempt: 4
# word #272: going
# attempt: 4
# word #273: lobby
# attempt: 6
# word #274: qualm
# attempt: 2
# word #275: bring
# attempt: 3
# word #276: shove
# attempt: 4
# word #277: drone
# attempt: 5
# word #278: lowly
# attempt: 4
# word #279: trope
# attempt: 5
# word #280: smile
# attempt: 6
# word #281: prime
# attempt: 5
# word #282: lobby
# attempt: 5
# word #283: whiff
# attempt: 5
# word #284: joker
# attempt: 5
# word #285: golly
# attempt: 4
# word #286: aider
# attempt: 2
# word #287: brand
# attempt: 4
# word #288: smash
# attempt: 5
# word #289: gawky
# attempt: 5
# word #290: fleck
# attempt: 3
# word #291: afoot
# attempt: 2
# word #292: edict
# attempt: 5
# word #293: trash
# attempt: 4
# word #294: curvy
# attempt: 6
# word #295: fluke
# attempt: 5
# word #296: phase
# attempt: 5
# word #297: fleck
# attempt: 4
# word #298: fetch
# attempt: 4
# word #299: magic
# attempt: 4
# word #300: after
# attempt: 5
# word #301: belly
# attempt: 4
# word #302: known
# attempt: 3
# word #303: elegy
# attempt: 2
# word #304: angry
# attempt: 3
# word #305: batch
# attempt: 4
# word #306: froth
# attempt: 5
# word #307: relic
# attempt: 4
# word #308: karma
# attempt: 5
# word #309: music
# attempt: 4
# word #310: shaky
# attempt: 6
# word #311: solve
# attempt: 4
# word #312: bulge
# attempt: 5
# word #313: scant
# attempt: 3
# word #314: flack
# attempt: 5
# word #315: cabal
# attempt: 4
# word #316: angry
# attempt: 4
# word #317: teeth
# attempt: 4
# word #318: teeth
# attempt: 4
# word #319: droll
# attempt: 5
# word #320: elide
# attempt: 4
# word #321: algae
# attempt: 3
# word #322: power
# attempt: 7
# word #323: limit
# attempt: 5
# word #324: aphid
# attempt: 4
# word #325: crush
# attempt: 3
# word #326: axial
# attempt: 6
# word #327: crush
# attempt: 4
# word #328: dowdy
# attempt: 4
# word #329: sinew
# attempt: 3
# word #330: after
# attempt: 4
# word #331: chafe
# attempt: 4
# word #332: juicy
# attempt: 4
# word #333: older
# attempt: 4
# word #334: madam
# attempt: 4
# word #335: dopey
# attempt: 5
# word #336: heady
# attempt: 4
# word #337: outgo
# attempt: 3
# word #338: flame
# attempt: 6
# word #339: minty
# attempt: 4
# word #340: sword
# attempt: 4
# word #341: night
# attempt: 6
# word #342: impel
# attempt: 5
# word #343: gauze
# attempt: 3
# word #344: knave
# attempt: 4
# word #345: frisk
# attempt: 4
# word #346: buddy
# attempt: 6
# word #347: elfin
# attempt: 4
# word #348: spilt
# attempt: 3
# word #349: brash
# attempt: 5
# word #350: gayer
# attempt: 4
# word #351: aphid
# attempt: 4
# word #352: sigma
# attempt: 4
# word #353: welsh
# attempt: 3
# word #354: enact
# attempt: 3
# word #355: chunk
# attempt: 5
# word #356: bongo
# attempt: 4
# word #357: geese
# attempt: 4
# word #358: sumac
# attempt: 3
# word #359: fuzzy
# attempt: 4
# word #360: blond
# attempt: 3
# word #361: doing
# attempt: 4
# word #362: lumpy
# attempt: 4
# word #363: crowd
# attempt: 5
# word #364: issue
# attempt: 4
# word #365: dream
# attempt: 5
# word #366: given
# attempt: 4
# word #367: rumba
# attempt: 4
# word #368: issue
# attempt: 4
# word #369: fruit
# attempt: 5
# word #370: bluff
# attempt: 5
# word #371: vicar
# attempt: 5
# word #372: scamp
# attempt: 3
# word #373: probe
# attempt: 6
# word #374: shoot
# attempt: 4
# word #375: piano
# attempt: 5
# word #376: fight
# attempt: 4
# word #377: range
# attempt: 3
# word #378: stake
# attempt: 4
# word #379: midst
# attempt: 3
# word #380: taper
# attempt: 4
# word #381: prove
# attempt: 3
# word #382: conic
# attempt: 5
# word #383: stake
# attempt: 3
# word #384: queue
# attempt: 4
# word #385: stuck
# attempt: 4
# word #386: wider
# attempt: 4
# word #387: eking
# attempt: 5
# word #388: adobe
# attempt: 4
# word #389: style
# attempt: 4
# word #390: story
# attempt: 4
# word #391: pesto
# attempt: 4
# word #392: rerun
# attempt: 5
# word #393: cream
# attempt: 3
# word #394: umbra
# attempt: 3
# word #395: badge
# attempt: 5
# word #396: scant
# attempt: 4
# word #397: earth
# attempt: 4
# word #398: choke
# attempt: 4
# word #399: theft
# attempt: 6
# word #400: boost
# attempt: 4
# word #401: kneed
# attempt: 3
# word #402: basic
# attempt: 4
# word #403: muddy
# attempt: 5
# word #404: quest
# attempt: 4
# word #405: wreck
# attempt: 5
# word #406: titan
# attempt: 4
# word #407: haunt
# attempt: 7
# word #408: thyme
# attempt: 4
# word #409: witty
# attempt: 4
# word #410: yearn
# attempt: 2
# word #411: truss
# attempt: 4
# word #412: cagey
# attempt: 4
# word #413: tepid
# attempt: 5
# word #414: parka
# attempt: 4
# word #415: unify
# attempt: 5
# word #416: fungi
# attempt: 3
# word #417: sweet
# attempt: 3
# word #418: tenth
# attempt: 6
# word #419: foyer
# attempt: 5
# word #420: blown
# attempt: 4
# word #421: tonic
# attempt: 5
# word #422: poise
# attempt: 5
# word #423: civil
# attempt: 3
# word #424: testy
# attempt: 4
# word #425: aloud
# attempt: 4
# word #426: winch
# attempt: 2
# word #427: union
# attempt: 4
# word #428: theft
# attempt: 3
# word #429: agate
# attempt: 5
# word #430: brave
# attempt: 5
# word #431: story
# attempt: 3
# word #432: axial
# attempt: 4
# word #433: whale
# attempt: 3
# word #434: junta
# attempt: 5
# word #435: spilt
# attempt: 4
# word #436: quill
# attempt: 5
# word #437: joust
# attempt: 3
# word #438: blitz
# attempt: 4
# word #439: corer
# attempt: 4
# word #440: leave
# attempt: 5
# word #441: ideal
# attempt: 4
# word #442: shaky
# attempt: 4
# word #443: stage
# attempt: 4
# word #444: slimy
# attempt: 4
# word #445: pagan
# attempt: 4
# word #446: pouch
# attempt: 4
# word #447: valor
# attempt: 4
# word #448: easel
# attempt: 5
# word #449: aorta
# attempt: 6
# word #450: croup
# attempt: 5
# word #451: farce
# attempt: 3
# word #452: abide
# attempt: 2
# word #453: hippy
# attempt: 5
# word #454: vicar
# attempt: 4
# word #455: magic
# attempt: 4
# word #456: angry
# attempt: 4
# word #457: buggy
# attempt: 4
# word #458: grade
# attempt: 5
# word #459: attic
# attempt: 2
# word #460: sinew
# attempt: 5
# word #461: siren
# attempt: 3
# word #462: polar
# attempt: 4
# word #463: photo
# attempt: 3
# word #464: fugue
# attempt: 4
# word #465: jaunt
# attempt: 3
# word #466: tango
# attempt: 3
# word #467: amiss
# attempt: 4
# word #468: spout
# attempt: 4
# word #469: pique
# attempt: 3
# word #470: fatty
# attempt: 3
# word #471: eagle
# attempt: 3
# word #472: tryst
# attempt: 4
# word #473: lousy
# attempt: 5
# word #474: broth
# attempt: 2
# word #475: inept
# attempt: 4
# word #476: gauge
# attempt: 3
# word #477: niece
# attempt: 4
# word #478: spire
# attempt: 5
# word #479: boxer
# attempt: 4
# word #480: among
# attempt: 5
# word #481: apple
# attempt: 4
# word #482: clasp
# attempt: 4
# word #483: billy
# attempt: 7
# word #484: topic
# attempt: 5
# word #485: bough
# attempt: 5
# word #486: havoc
# attempt: 4
# word #487: goody
# attempt: 4
# word #488: shown
# attempt: 5
# word #489: crone
# attempt: 3
# word #490: karma
# attempt: 4
# word #491: chide
# attempt: 2
# word #492: obese
# attempt: 3
# word #493: junto
# attempt: 3
# word #494: black
# attempt: 3
# word #495: chalk
# attempt: 6
# word #496: slime
# attempt: 4
# word #497: chord
# attempt: 4
# word #498: happy
# attempt: 4
# word #499: groin
# attempt: 5
# word #500: coral
# attempt: 4
# word #501: trade
# attempt: 3
# word #502: candy
# attempt: 4
# word #503: snarl
# attempt: 4
# word #504: fleet
# attempt: 4
# word #505: label
# attempt: 4
# word #506: spell
# attempt: 5
# word #507: curvy
# attempt: 5
# word #508: knead
# attempt: 4
# word #509: cocoa
# attempt: 5
# word #510: never
# attempt: 5
# word #511: ounce
# attempt: 5
# word #512: burly
# attempt: 4
# word #513: spilt
# attempt: 3
# word #514: slunk
# attempt: 5
# word #515: vivid
# attempt: 5
# word #516: fleet
# attempt: 4
# word #517: drink
# attempt: 5
# word #518: odder
# attempt: 6
# word #519: pound
# attempt: 3
# word #520: alpha
# attempt: 5
# word #521: droop
# attempt: 4
# word #522: chaff
# attempt: 4
# word #523: unfed
# attempt: 4
# word #524: gypsy
# attempt: 4
# word #525: cause
# attempt: 4
# word #526: utter
# attempt: 4
# word #527: pleat
# attempt: 4
# word #528: break
# attempt: 5
# word #529: circa
# attempt: 5
# word #530: drier
# attempt: 4
# word #531: riser
# attempt: 7
# word #532: skate
# attempt: 3
# word #533: thief
# attempt: 2
# word #534: nymph
# attempt: 3
# word #535: prowl
# attempt: 5
# word #536: vigor
# attempt: 5
# word #537: bully
# attempt: 4
# word #538: allow
# attempt: 4
# word #539: coach
# attempt: 3
# word #540: steal
# attempt: 5
# word #541: facet
# attempt: 3
# word #542: spiel
# attempt: 2
# word #543: stole
# attempt: 4
# word #544: aside
# attempt: 4
# word #545: fight
# attempt: 3
# word #546: drink
# attempt: 5
# word #547: refit
# attempt: 4
# word #548: power
# attempt: 4
# word #549: gamma
# attempt: 5
# word #550: canoe
# attempt: 4
# word #551: quake
# attempt: 5
# word #552: lance
# attempt: 4
# word #553: rouge
# attempt: 4
# word #554: atoll
# attempt: 4
# word #555: denim
# attempt: 5
# word #556: steam
# attempt: 5
# word #557: noisy
# attempt: 4
# word #558: rebar
# attempt: 4
# word #559: rouge
# attempt: 5
# word #560: maxim
# attempt: 5
# word #561: minim
# attempt: 4
# word #562: angry
# attempt: 4
# word #563: space
# attempt: 5
# word #564: hairy
# attempt: 4
# word #565: mange
# attempt: 2
# word #566: mania
# attempt: 4
# word #567: abled
# attempt: 4
# word #568: pitch
# attempt: 4
# word #569: dimly
# attempt: 4
# word #570: moral
# attempt: 6
# word #571: burly
# attempt: 6
# word #572: spare
# attempt: 4
# word #573: hussy
# attempt: 2
# word #574: matey
# attempt: 2
# word #575: start
# attempt: 6
# word #576: annul
# attempt: 4
# word #577: guard
# attempt: 3
# word #578: champ
# attempt: 4
# word #579: clown
# attempt: 4
# word #580: mafia
# attempt: 3
# word #581: delve
# attempt: 4
# word #582: dance
# attempt: 4
# word #583: scrap
# attempt: 4
# word #584: mercy
# attempt: 4
# word #585: canoe
# attempt: 5
# word #586: brass
# attempt: 3
# word #587: idler
# attempt: 4
# word #588: house
# attempt: 4
# word #589: raspy
# attempt: 4
# word #590: point
# attempt: 3
# word #591: throw
# attempt: 4
# word #592: beset
# attempt: 3
# word #593: grind
# attempt: 3
# word #594: stoke
# attempt: 3
# word #595: focal
# attempt: 3
# word #596: opium
# attempt: 4
# word #597: binge
# attempt: 6
# word #598: wrath
# attempt: 3
# word #599: denim
# attempt: 2
# word #600: siren
# attempt: 3
# word #601: older
# attempt: 5
# word #602: joust
# attempt: 4
# word #603: slant
# attempt: 5
# word #604: parka
# attempt: 4
# word #605: cheek
# attempt: 2
# word #606: after
# attempt: 4
# word #607: lyric
# attempt: 3
# word #608: elate
# attempt: 4
# word #609: tilde
# attempt: 4
# word #610: otter
# attempt: 2
# word #611: thigh
# attempt: 5
# word #612: wispy
# attempt: 4
# word #613: jerky
# attempt: 3
# word #614: skull
# attempt: 4
# word #615: glean
# attempt: 4
# word #616: quill
# attempt: 4
# word #617: scope
# attempt: 5
# word #618: farce
# attempt: 4
# word #619: prowl
# attempt: 2
# word #620: trial
# attempt: 3
# word #621: drawl
# attempt: 5
# word #622: ardor
# attempt: 5
# word #623: eight
# attempt: 4
# word #624: steal
# attempt: 3
# word #625: diver
# attempt: 3
# word #626: juicy
# attempt: 4
# word #627: gruel
# attempt: 3
# word #628: elder
# attempt: 4
# word #629: tumor
# attempt: 4
# word #630: armor
# attempt: 3
# word #631: mogul
# attempt: 3
# word #632: tribe
# attempt: 3
# word #633: wacky
# attempt: 4
# word #634: ninja
# attempt: 4
# word #635: shade
# attempt: 3
# word #636: value
# attempt: 4
# word #637: dowdy
# attempt: 5
# word #638: obese
# attempt: 4
# word #639: wreck
# attempt: 4
# word #640: creak
# attempt: 5
# word #641: surge
# attempt: 3
# word #642: sissy
# attempt: 5
# word #643: scarf
# attempt: 5
# word #644: diver
# attempt: 5
# word #645: clang
# attempt: 3
# word #646: queue
# attempt: 4
# word #647: rower
# attempt: 7
# word #648: death
# attempt: 5
# word #649: stalk
# attempt: 5
# word #650: delay
# attempt: 4
# word #651: impel
# attempt: 4
# word #652: blink
# attempt: 4
# word #653: scone
# attempt: 3
# word #654: couch
# attempt: 4
# word #655: stout
# attempt: 6
# word #656: blank
# attempt: 3
# word #657: chest
# attempt: 5
# word #658: glade
# attempt: 6
# word #659: drain
# attempt: 4
# word #660: aider
# attempt: 5
# word #661: plumb
# attempt: 3
# word #662: quell
# attempt: 4
# word #663: birch
# attempt: 4
# word #664: hilly
# attempt: 5
# word #665: chafe
# attempt: 5
# word #666: bison
# attempt: 4
# word #667: spill
# attempt: 5
# word #668: neigh
# attempt: 4
# word #669: tutor
# attempt: 4
# word #670: clone
# attempt: 3
# word #671: spark
# attempt: 3
# word #672: beast
# attempt: 5
# word #673: widen
# attempt: 5
# word #674: splat
# attempt: 5
# word #675: puppy
# attempt: 4
# word #676: blond
# attempt: 3
# word #677: grunt
# attempt: 4
# word #678: poise
# attempt: 3
# word #679: cigar
# attempt: 5
# word #680: riper
# attempt: 2
# word #681: small
# attempt: 4
# word #682: throw
# attempt: 6
# word #683: shrug
# attempt: 5
# word #684: bound
# attempt: 3
# word #685: lurch
# attempt: 5
# word #686: scant
# attempt: 4
# word #687: synod
# attempt: 4
# word #688: ratio
# attempt: 4
# word #689: clang
# attempt: 4
# word #690: drunk
# attempt: 3
# word #691: witch
# attempt: 4
# word #692: seize
# attempt: 5
# word #693: macro
# attempt: 5
# word #694: askew
# attempt: 5
# word #695: unify
# attempt: 4
# word #696: bicep
# attempt: 4
# word #697: condo
# attempt: 3
# word #698: sleet
# attempt: 6
# word #699: sassy
# attempt: 6
# word #700: swear
# attempt: 4
# word #701: civic
# attempt: 4
# word #702: cache
# attempt: 4
# word #703: polyp
# attempt: 5
# word #704: order
# attempt: 3
# word #705: mount
# attempt: 4
# word #706: tease
# attempt: 4
# word #707: sweep
# attempt: 4
# word #708: force
# attempt: 5
# word #709: wedge
# attempt: 4
# word #710: daily
# attempt: 4
# word #711: shift
# attempt: 3
# word #712: pecan
# attempt: 4
# word #713: guppy
# attempt: 3
# word #714: wrong
# attempt: 4
# word #715: noise
# attempt: 4
# word #716: suave
# attempt: 4
# word #717: tubal
# attempt: 5
# word #718: treat
# attempt: 4
# word #719: irony
# attempt: 5
# word #720: amiss
# attempt: 2
# word #721: drove
# attempt: 3
# word #722: tiara
# attempt: 3
# word #723: navel
# attempt: 5
# word #724: flick
# attempt: 6
# word #725: email
# attempt: 3
# word #726: woken
# attempt: 3
# word #727: sixth
# attempt: 3
# word #728: snake
# attempt: 4
# word #729: jerky
# attempt: 6
# word #730: speak
# attempt: 4
# word #731: curse
# attempt: 3
# word #732: lingo
# attempt: 3
# word #733: exult
# attempt: 5
# word #734: ahead
# attempt: 4
# word #735: altar
# attempt: 3
# word #736: slung
# attempt: 5
# word #737: level
# attempt: 3
# word #738: rower
# attempt: 6
# word #739: split
# attempt: 5
# word #740: greet
# attempt: 4
# word #741: chose
# attempt: 6
# word #742: ethos
# attempt: 4
# word #743: crest
# attempt: 4
# word #744: stalk
# attempt: 4
# word #745: tabby
# attempt: 5
# word #746: moldy
# attempt: 4
# word #747: shuck
# attempt: 3
# word #748: amend
# attempt: 5
# word #749: dowry
# attempt: 4
# word #750: other
# attempt: 4
# word #751: shark
# attempt: 5
# word #752: cried
# attempt: 4
# word #753: pygmy
# attempt: 4
# word #754: basin
# attempt: 4
# word #755: taunt
# attempt: 7
# word #756: ninny
# attempt: 3
# word #757: grove
# attempt: 6
# word #758: limit
# attempt: 4
# word #759: feign
# attempt: 3
# word #760: react
# attempt: 3
# word #761: match
# attempt: 5
# word #762: rigor
# attempt: 3
# word #763: trick
# attempt: 3
# word #764: reign
# attempt: 3
# word #765: cheek
# attempt: 2
# word #766: cease
# attempt: 5
# word #767: tribe
# attempt: 4
# word #768: copse
# attempt: 5
# word #769: crack
# attempt: 6
# word #770: sissy
# attempt: 4
# word #771: grand
# attempt: 3
# word #772: snide
# attempt: 3
# word #773: awoke
# attempt: 4
# word #774: wispy
# attempt: 4
# word #775: amply
# attempt: 3
# word #776: drake
# attempt: 3
# word #777: octet
# attempt: 3
# word #778: stash
# attempt: 7
# word #779: gumbo
# attempt: 4
# word #780: cress
# attempt: 5
# word #781: hussy
# attempt: 3
# word #782: quell
# attempt: 4
# word #783: shore
# attempt: 3
# word #784: chess
# attempt: 4
# word #785: hater
# attempt: 3
# word #786: bland
# attempt: 4
# word #787: diary
# attempt: 4
# word #788: rival
# attempt: 4
# word #789: false
# attempt: 5
# word #790: apple
# attempt: 4
# word #791: atone
# attempt: 5
# word #792: canoe
# attempt: 3
# word #793: boule
# attempt: 4
# word #794: wrote
# attempt: 4
# word #795: villa
# attempt: 5
# word #796: goofy
# attempt: 5
# word #797: press
# attempt: 4
# word #798: mocha
# attempt: 4
# word #799: urban
# attempt: 4
# word #800: evict
# attempt: 2
# word #801: chute
# attempt: 4
# word #802: swish
# attempt: 4
# word #803: fritz
# attempt: 4
# word #804: birth
# attempt: 6
# word #805: frock
# attempt: 3
# word #806: sleet
# attempt: 4
# word #807: etude
# attempt: 3
# word #808: ratty
# attempt: 5
# word #809: copse
# attempt: 5
# word #810: beret
# attempt: 5
# word #811: abhor
# attempt: 3
# word #812: tardy
# attempt: 5
# word #813: piney
# attempt: 4
# word #814: stump
# attempt: 3
# word #815: dealt
# attempt: 5
# word #816: gamut
# attempt: 4
# word #817: array
# attempt: 5
# word #818: chard
# attempt: 3
# word #819: witty
# attempt: 6
# word #820: flake
# attempt: 6
# word #821: plied
# attempt: 3
# word #822: pouch
# attempt: 3
# word #823: eerie
# attempt: 5
# word #824: trunk
# attempt: 5
# word #825: house
# attempt: 5
# word #826: daddy
# attempt: 5
# word #827: attic
# attempt: 4
# word #828: razor
# attempt: 4
# word #829: cloud
# attempt: 4
# word #830: steel
# attempt: 3
# word #831: pupil
# attempt: 3
# word #832: vigil
# attempt: 5
# word #833: sally
# attempt: 3
# word #834: unwed
# attempt: 5
# word #835: whoop
# attempt: 4
# word #836: unmet
# attempt: 5
# word #837: gland
# attempt: 5
# word #838: wrest
# attempt: 4
# word #839: usage
# attempt: 5
# word #840: skirt
# attempt: 5
# word #841: diver
# attempt: 3
# word #842: stalk
# attempt: 4
# word #843: impel
# attempt: 3
# word #844: widow
# attempt: 6
# word #845: hymen
# attempt: 4
# word #846: unwed
# attempt: 5
# word #847: piper
# attempt: 6
# word #848: worry
# attempt: 5
# word #849: maxim
# attempt: 5
# word #850: spite
# attempt: 6
# word #851: shady
# attempt: 4
# word #852: brush
# attempt: 5
# word #853: quart
# attempt: 4
# word #854: foyer
# attempt: 4
# word #855: matey
# attempt: 3
# word #856: grate
# attempt: 6
# word #857: entry
# attempt: 5
# word #858: leach
# attempt: 3
# word #859: modem
# attempt: 4
# word #860: tiger
# attempt: 7
# word #861: stoke
# attempt: 6
# word #862: joust
# attempt: 4
# word #863: verge
# attempt: 4
# word #864: badly
# attempt: 5
# word #865: rouse
# attempt: 6
# word #866: salvo
# attempt: 4
# word #867: brace
# attempt: 4
# word #868: zonal
# attempt: 4
# word #869: swamp
# attempt: 4
# word #870: timer
# attempt: 5
# word #871: dogma
# attempt: 5
# word #872: cough
# attempt: 3
# word #873: urine
# attempt: 2
# word #874: rhyme
# attempt: 5
# word #875: tryst
# attempt: 5
# word #876: melee
# attempt: 4
# word #877: wight
# attempt: 4
# word #878: onset
# attempt: 2
# word #879: heron
# attempt: 4
# word #880: click
# attempt: 5
# word #881: ankle
# attempt: 4
# word #882: awoke
# attempt: 6
# word #883: fetal
# attempt: 5
# word #884: click
# attempt: 4
# word #885: guano
# attempt: 3
# word #886: after
# attempt: 4
# word #887: spare
# attempt: 4
# word #888: macaw
# attempt: 5
# word #889: envoy
# attempt: 3
# word #890: parka
# attempt: 5
# word #891: lever
# attempt: 4
# word #892: cloak
# attempt: 5
# word #893: fault
# attempt: 5
# word #894: credo
# attempt: 3
# word #895: incur
# attempt: 3
# word #896: erase
# attempt: 4
# word #897: usage
# attempt: 2
# word #898: broth
# attempt: 4
# word #899: wispy
# attempt: 6
# word #900: polyp
# attempt: 3
# word #901: waste
# attempt: 4
# word #902: peril
# attempt: 4
# word #903: enact
# attempt: 3
# word #904: nudge
# attempt: 7
# word #905: bicep
# attempt: 5
# word #906: yacht
# attempt: 3
# word #907: croak
# attempt: 4
# word #908: melon
# attempt: 3
# word #909: allay
# attempt: 5
# word #910: crony
# attempt: 3
# word #911: thief
# attempt: 4
# word #912: cloud
# attempt: 4
# word #913: tiger
# attempt: 6
# word #914: upper
# attempt: 4
# word #915: mince
# attempt: 4
# word #916: quick
# attempt: 5
# word #917: tryst
# attempt: 3
# word #918: soapy
# attempt: 5
# word #919: mural
# attempt: 4
# word #920: imbue
# attempt: 4
# word #921: prime
# attempt: 5
# word #922: heady
# attempt: 5
# word #923: inept
# attempt: 5
# word #924: about
# attempt: 4
# word #925: scent
# attempt: 4
# word #926: point
# attempt: 4
# word #927: spray
# attempt: 4
# word #928: shank
# attempt: 4
# word #929: media
# attempt: 5
# word #930: tango
# attempt: 4
# word #931: vying
# attempt: 2
# word #932: stick
# attempt: 4
# word #933: realm
# attempt: 4
# word #934: every
# attempt: 4
# word #935: heart
# attempt: 4
# word #936: cabal
# attempt: 4
# word #937: comfy
# attempt: 4
# word #938: parka
# attempt: 3
# word #939: banjo
# attempt: 3
# word #940: sushi
# attempt: 4
# word #941: barge
# attempt: 3
# word #942: genre
# attempt: 3
# word #943: razor
# attempt: 3
# word #944: taffy
# attempt: 5
# word #945: kebab
# attempt: 5
# word #946: fatty
# attempt: 4
# word #947: circa
# attempt: 4
# word #948: pesto
# attempt: 3
# word #949: cider
# attempt: 4
# word #950: porch
# attempt: 3
# word #951: empty
# attempt: 3
# word #952: donut
# attempt: 4
# word #953: could
# attempt: 4
# word #954: crush
# attempt: 3
# word #955: scorn
# attempt: 4
# word #956: abbot
# attempt: 5
# word #957: befit
# attempt: 3
# word #958: white
# attempt: 4
# word #959: jumpy
# attempt: 6
# word #960: shove
# attempt: 6
# word #961: tulip
# attempt: 4
# word #962: foray
# attempt: 6
# word #963: scold
# attempt: 3
# word #964: brick
# attempt: 4
# word #965: those
# attempt: 4
# word #966: zebra
# attempt: 3
# word #967: stump
# attempt: 4
# word #968: dirty
# attempt: 4
# word #969: close
# attempt: 4
# word #970: pluck
# attempt: 3
# word #971: tuber
# attempt: 3
# word #972: alibi
# attempt: 3
# word #973: vying
# attempt: 3
# word #974: scene
# attempt: 4
# word #975: knife
# attempt: 5
# word #976: crock
# attempt: 4
# word #977: groom
# attempt: 4
# word #978: dunce
# attempt: 5
# word #979: fight
# attempt: 4
# word #980: eclat
# attempt: 3
# word #981: trope
# attempt: 4
# word #982: cater
# attempt: 5
# word #983: cynic
# attempt: 3
# word #984: apnea
# attempt: 4
# word #985: miser
# attempt: 4
# word #986: reach
# attempt: 3
# word #987: pithy
# attempt: 4
# word #988: buyer
# attempt: 5
# word #989: paint
# attempt: 5
# word #990: scuba
# attempt: 3
# word #991: binge
# attempt: 4
# word #992: theta
# attempt: 4
# word #993: venue
# attempt: 4
# word #994: outdo
# attempt: 3
# word #995: leaky
# attempt: 6
# word #996: saute
# attempt: 3
# word #997: dried
# attempt: 5
# word #998: rural
# attempt: 6
# word #999: hound
# attempt: 6
# word #1000: ovine
# attempt: 4

# %%
# Training Data Graph
unique_elements, counts = [], []

for item in set(training_attempts):
    unique_elements.append(item)
    counts.append(training_attempts.count(item))

plt.bar(unique_elements, counts, color='#57b5dc')

for i, count in enumerate(counts):
    plt.text(unique_elements[i], count + 0.1, str(count), ha='center', va='bottom')

plt.xlabel('Attempts')
plt.ylabel('Frequency')
plt.title('Frequency of Attempts in Training')

plt.show()

# %%
top_ten_words = []
word_count = 0

def load_letter_frequencies(csv_path):
    letter_frequencies = {}
    with open(csv_path, 'r') as csvfile:
        next(csvfile)
        for row in csvfile:
            letter, frequency = row.strip().split(',')
            letter_frequencies[letter.lower()] = float(frequency)
    return letter_frequencies

def evaluate_word(word, letter_frequencies, repeat_penalty=5):
    # Calculate the frequency of each letter in the given word
    word_frequencies = Counter(word.lower())
    
    # Calculate the score for the word based on letter frequencies
    score = 0
    for letter in word_frequencies:
        score += letter_frequencies[letter] * word_frequencies[letter]
        
        # Apply penalty for repeated letters
        if word_frequencies[letter] > 1:
            score -= repeat_penalty * (word_frequencies[letter] - 1) * letter_frequencies[letter]
    return score

english_letter_frequencies = load_letter_frequencies('../Dataset/letter_frequency.csv')

scores = {word: evaluate_word(word, english_letter_frequencies) for word in great_starting_word}
# best_word = max(scores, key=scores.get)

# Sort the words based on their scores in descending order
sorted_words = sorted(scores.items(), key=lambda x: x[1], reverse=True)

# Display the results
print("Word Scores:")
for word, score in sorted_words:
    print(f"{word}: {score}")
    word_count+=1
    if word_count<=10:
        top_ten_words.append(word)

# print("\nBest Word for the First Word in Wordle:")
# print(sorted_words[0][0])
# Out:
# Word Scores:
# store: 41.579
# raise: 40.149
# often: 38.242
# unite: 38.230999999999995
# heard: 37.203
# stove: 36.57
# haven: 34.69
# raven: 34.583
# poser: 34.452
# reign: 34.419000000000004
# style: 34.083999999999996
# angle: 33.658
# glare: 32.896
# cream: 32.044
# quiet: 31.576999999999998
# frame: 31.489999999999995
# worst: 31.236999999999995
# maize: 30.315000000000005
# latch: 30.124
# cover: 29.956000000000003
# maple: 29.229
# spilt: 28.302999999999997
# stack: 28.103999999999996
# spoil: 26.753999999999998
# derby: 26.408
# quart: 26.062999999999995
# wreck: 25.602999999999998
# scarf: 25.491
# vault: 24.983999999999998
# built: 24.297
# brush: 22.658
# balmy: 18.064
# usual: 10.245000000000001
# rower: 4.607999999999997
# ninth: 1.8690000000000007
# otter: -0.9719999999999942
# taint: -5.285999999999997
# booth: -5.878999999999997
# every: -29.16699999999999
# sassy: -34.147999999999996

# %%
# Testing phase
avg_attempts = []
testing_set_size = 500  # Adjust as needed
testing_set = []
testing_set = [choose_random_word(testing_set) for _ in range(testing_set_size)]

for best_word in top_ten_words:
    testing_attempts = []
    word = 0
    the_word = None

    best_starting_word = []
    best_starting_word_attempts = float('inf')

    for target_word in testing_set:
        attempts = 0
        previous_guesses = []
        word += 1
        print(f"list #{top_ten_words.index(best_word)} word #{word}: {target_word}")

        while True:
            attempts += 1
            guess = bayesian_choose_word(possible_words, previous_guesses)
            
            if attempts == 1:
                guess = best_word
                the_word = guess
            # elif attempts == 2:
            #     the_word = guess
            
            feedback = evaluate_guess(target_word, guess)
            previous_guesses.append((guess, feedback))
            if target_word == guess:
                print(f"attempt: {attempts}")
                testing_attempts.append(attempts)
                if attempts < 3:
                    best_starting_word.append(the_word)
                    # best_starting_word_attempts = attempts
                break
    avg_testing_attempts = sum(testing_attempts) / len(testing_attempts)
    avg_attempts.append(avg_testing_attempts)

    # Testing Data Graph
    unique_elements, counts = [], []

    for item in set(testing_attempts):
        unique_elements.append(item)
        counts.append(testing_attempts.count(item))

    plt.bar(unique_elements, counts, color='#57b5dc')

    for i, count in enumerate(counts):
        plt.text(unique_elements[i], count + 0.1, str(count), ha='center', va='bottom')

    plt.xlabel('Attempts')
    plt.ylabel('Frequency')
    plt.title(f'Frequency of Attempts in Testing with {best_word}')

    plt.show()
# Out:
# list #0 word #1: condo
# attempt: 4
# list #0 word #2: tilde
# attempt: 4
# list #0 word #3: flown
# attempt: 6
# list #0 word #4: voice
# attempt: 3
# list #0 word #5: prime
# attempt: 4
# list #0 word #6: mange
# attempt: 4
# list #0 word #7: false
# attempt: 4
# list #0 word #8: batch
# attempt: 3
# list #0 word #9: spawn
# attempt: 5
# list #0 word #10: loose
# attempt: 6
# list #0 word #11: fiber
# attempt: 6
# list #0 word #12: prime
# attempt: 5
# list #0 word #13: offal
# attempt: 3
# list #0 word #14: facet
# attempt: 4
# list #0 word #15: plump
# attempt: 4
# list #0 word #16: nomad
# attempt: 4
# list #0 word #17: vixen
# attempt: 4
# list #0 word #18: froth
# attempt: 4
# list #0 word #19: gamma
# attempt: 4
# list #0 word #20: squat
# attempt: 3
# list #0 word #21: coven
# attempt: 4
# list #0 word #22: bacon
# attempt: 4
# list #0 word #23: flash
# attempt: 5
# list #0 word #24: quack
# attempt: 4
# list #0 word #25: golly
# attempt: 6
# list #0 word #26: catch
# attempt: 8
# list #0 word #27: tried
# attempt: 4
# list #0 word #28: villa
# attempt: 4
# list #0 word #29: dodgy
# attempt: 5
# list #0 word #30: tasty
# attempt: 3
# list #0 word #31: lowly
# attempt: 4
# list #0 word #32: house
# attempt: 4
# list #0 word #33: matey
# attempt: 3
# list #0 word #34: stand
# attempt: 4
# list #0 word #35: wedge
# attempt: 4
# list #0 word #36: rower
# attempt: 5
# list #0 word #37: liken
# attempt: 3
# list #0 word #38: guess
# attempt: 4
# list #0 word #39: bully
# attempt: 6
# list #0 word #40: godly
# attempt: 3
# list #0 word #41: clout
# attempt: 4
# list #0 word #42: koala
# attempt: 4
# list #0 word #43: sorry
# attempt: 2
# list #0 word #44: drain
# attempt: 3
# list #0 word #45: debar
# attempt: 4
# list #0 word #46: delay
# attempt: 4
# list #0 word #47: might
# attempt: 3
# list #0 word #48: crimp
# attempt: 4
# list #0 word #49: crack
# attempt: 5
# list #0 word #50: mount
# attempt: 5
# list #0 word #51: gamut
# attempt: 4
# list #0 word #52: unity
# attempt: 4
# list #0 word #53: sauna
# attempt: 4
# list #0 word #54: alive
# attempt: 5
# list #0 word #55: rhino
# attempt: 4
# list #0 word #56: harem
# attempt: 4
# list #0 word #57: actor
# attempt: 3
# list #0 word #58: scent
# attempt: 4
# list #0 word #59: token
# attempt: 3
# list #0 word #60: cynic
# attempt: 4
# list #0 word #61: boxer
# attempt: 7
# list #0 word #62: boost
# attempt: 3
# list #0 word #63: quark
# attempt: 5
# list #0 word #64: pilot
# attempt: 3
# list #0 word #65: truce
# attempt: 4
# list #0 word #66: serum
# attempt: 3
# list #0 word #67: freed
# attempt: 4
# list #0 word #68: pasty
# attempt: 5
# list #0 word #69: trove
# attempt: 2
# list #0 word #70: chime
# attempt: 4
# list #0 word #71: pasty
# attempt: 4
# list #0 word #72: woody
# attempt: 3
# list #0 word #73: belch
# attempt: 3
# list #0 word #74: frame
# attempt: 5
# list #0 word #75: pushy
# attempt: 3
# list #0 word #76: elegy
# attempt: 4
# list #0 word #77: rebus
# attempt: 4
# list #0 word #78: clamp
# attempt: 4
# list #0 word #79: juror
# attempt: 2
# list #0 word #80: cloak
# attempt: 4
# list #0 word #81: teddy
# attempt: 5
# list #0 word #82: wrest
# attempt: 3
# list #0 word #83: vying
# attempt: 4
# list #0 word #84: goner
# attempt: 6
# list #0 word #85: spunk
# attempt: 4
# list #0 word #86: blond
# attempt: 4
# list #0 word #87: snack
# attempt: 6
# list #0 word #88: beast
# attempt: 4
# list #0 word #89: brook
# attempt: 3
# list #0 word #90: morph
# attempt: 3
# list #0 word #91: title
# attempt: 4
# list #0 word #92: sneak
# attempt: 5
# list #0 word #93: basil
# attempt: 4
# list #0 word #94: liner
# attempt: 5
# list #0 word #95: wispy
# attempt: 4
# list #0 word #96: acrid
# attempt: 5
# list #0 word #97: briny
# attempt: 5
# list #0 word #98: truck
# attempt: 5
# list #0 word #99: mammy
# attempt: 5
# list #0 word #100: fatty
# attempt: 5
# list #0 word #101: spend
# attempt: 3
# list #0 word #102: batch
# attempt: 6
# list #0 word #103: knife
# attempt: 4
# list #0 word #104: until
# attempt: 3
# list #0 word #105: sting
# attempt: 5
# list #0 word #106: blood
# attempt: 4
# list #0 word #107: briny
# attempt: 6
# list #0 word #108: ditto
# attempt: 4
# list #0 word #109: lever
# attempt: 5
# list #0 word #110: suave
# attempt: 5
# list #0 word #111: polar
# attempt: 4
# list #0 word #112: semen
# attempt: 4
# list #0 word #113: viola
# attempt: 4
# list #0 word #114: shore
# attempt: 5
# list #0 word #115: sonar
# attempt: 2
# list #0 word #116: matey
# attempt: 4
# list #0 word #117: trade
# attempt: 4
# list #0 word #118: tonal
# attempt: 5
# list #0 word #119: bleep
# attempt: 4
# list #0 word #120: handy
# attempt: 5
# list #0 word #121: usher
# attempt: 3
# list #0 word #122: manly
# attempt: 4
# list #0 word #123: havoc
# attempt: 4
# list #0 word #124: index
# attempt: 2
# list #0 word #125: bleep
# attempt: 4
# list #0 word #126: billy
# attempt: 6
# list #0 word #127: flood
# attempt: 3
# list #0 word #128: punch
# attempt: 5
# list #0 word #129: eking
# attempt: 4
# list #0 word #130: clank
# attempt: 6
# list #0 word #131: aptly
# attempt: 3
# list #0 word #132: crowd
# attempt: 6
# list #0 word #133: slept
# attempt: 4
# list #0 word #134: which
# attempt: 5
# list #0 word #135: ovary
# attempt: 2
# list #0 word #136: baste
# attempt: 6
# list #0 word #137: arrow
# attempt: 4
# list #0 word #138: shunt
# attempt: 3
# list #0 word #139: since
# attempt: 3
# list #0 word #140: bully
# attempt: 4
# list #0 word #141: ample
# attempt: 4
# list #0 word #142: knoll
# attempt: 2
# list #0 word #143: decry
# attempt: 3
# list #0 word #144: ounce
# attempt: 3
# list #0 word #145: kneel
# attempt: 4
# list #0 word #146: knave
# attempt: 5
# list #0 word #147: elite
# attempt: 3
# list #0 word #148: taste
# attempt: 3
# list #0 word #149: stack
# attempt: 4
# list #0 word #150: scoff
# attempt: 4
# list #0 word #151: trait
# attempt: 5
# list #0 word #152: chock
# attempt: 3
# list #0 word #153: fatty
# attempt: 6
# list #0 word #154: click
# attempt: 5
# list #0 word #155: petal
# attempt: 5
# list #0 word #156: birth
# attempt: 4
# list #0 word #157: terra
# attempt: 2
# list #0 word #158: shaft
# attempt: 4
# list #0 word #159: fetus
# attempt: 3
# list #0 word #160: abbot
# attempt: 4
# list #0 word #161: polka
# attempt: 5
# list #0 word #162: dumpy
# attempt: 5
# list #0 word #163: dolly
# attempt: 6
# list #0 word #164: grimy
# attempt: 4
# list #0 word #165: virus
# attempt: 3
# list #0 word #166: trick
# attempt: 3
# list #0 word #167: feral
# attempt: 5
# list #0 word #168: train
# attempt: 5
# list #0 word #169: torch
# attempt: 3
# list #0 word #170: amply
# attempt: 3
# list #0 word #171: aorta
# attempt: 3
# list #0 word #172: slush
# attempt: 4
# list #0 word #173: abort
# attempt: 3
# list #0 word #174: woman
# attempt: 3
# list #0 word #175: freak
# attempt: 3
# list #0 word #176: earth
# attempt: 4
# list #0 word #177: slink
# attempt: 4
# list #0 word #178: ninny
# attempt: 5
# list #0 word #179: spare
# attempt: 5
# list #0 word #180: parka
# attempt: 3
# list #0 word #181: awake
# attempt: 4
# list #0 word #182: quash
# attempt: 5
# list #0 word #183: binge
# attempt: 3
# list #0 word #184: amuse
# attempt: 5
# list #0 word #185: golem
# attempt: 3
# list #0 word #186: flesh
# attempt: 4
# list #0 word #187: biddy
# attempt: 5
# list #0 word #188: ethos
# attempt: 2
# list #0 word #189: tenth
# attempt: 2
# list #0 word #190: chant
# attempt: 4
# list #0 word #191: troop
# attempt: 4
# list #0 word #192: riser
# attempt: 5
# list #0 word #193: sunny
# attempt: 5
# list #0 word #194: helix
# attempt: 5
# list #0 word #195: icing
# attempt: 3
# list #0 word #196: enemy
# attempt: 4
# list #0 word #197: crest
# attempt: 4
# list #0 word #198: scant
# attempt: 3
# list #0 word #199: chirp
# attempt: 5
# list #0 word #200: flash
# attempt: 2
# list #0 word #201: groin
# attempt: 3
# list #0 word #202: jumpy
# attempt: 4
# list #0 word #203: screw
# attempt: 4
# list #0 word #204: chest
# attempt: 4
# list #0 word #205: wound
# attempt: 3
# list #0 word #206: leach
# attempt: 5
# list #0 word #207: store
# attempt: 1
# list #0 word #208: scone
# attempt: 5
# list #0 word #209: moose
# attempt: 5
# list #0 word #210: beget
# attempt: 4
# list #0 word #211: zonal
# attempt: 5
# list #0 word #212: gecko
# attempt: 3
# list #0 word #213: flood
# attempt: 3
# list #0 word #214: segue
# attempt: 4
# list #0 word #215: seize
# attempt: 4
# list #0 word #216: dryly
# attempt: 5
# list #0 word #217: undid
# attempt: 4
# list #0 word #218: risky
# attempt: 2
# list #0 word #219: tweet
# attempt: 4
# list #0 word #220: blind
# attempt: 3
# list #0 word #221: shape
# attempt: 2
# list #0 word #222: happy
# attempt: 4
# list #0 word #223: using
# attempt: 4
# list #0 word #224: lithe
# attempt: 3
# list #0 word #225: petty
# attempt: 4
# list #0 word #226: revel
# attempt: 5
# list #0 word #227: sally
# attempt: 5
# list #0 word #228: taker
# attempt: 4
# list #0 word #229: scale
# attempt: 4
# list #0 word #230: thrum
# attempt: 3
# list #0 word #231: claim
# attempt: 4
# list #0 word #232: azure
# attempt: 3
# list #0 word #233: gusto
# attempt: 3
# list #0 word #234: dodge
# attempt: 4
# list #0 word #235: spawn
# attempt: 5
# list #0 word #236: bused
# attempt: 4
# list #0 word #237: ionic
# attempt: 4
# list #0 word #238: gaffe
# attempt: 5
# list #0 word #239: decor
# attempt: 3
# list #0 word #240: incur
# attempt: 4
# list #0 word #241: exist
# attempt: 5
# list #0 word #242: lemur
# attempt: 4
# list #0 word #243: scuba
# attempt: 4
# list #0 word #244: rally
# attempt: 5
# list #0 word #245: floor
# attempt: 3
# list #0 word #246: woven
# attempt: 4
# list #0 word #247: count
# attempt: 4
# list #0 word #248: shone
# attempt: 3
# list #0 word #249: spoke
# attempt: 3
# list #0 word #250: pause
# attempt: 3
# list #0 word #251: petty
# attempt: 3
# list #0 word #252: flume
# attempt: 5
# list #0 word #253: mango
# attempt: 3
# list #0 word #254: giver
# attempt: 5
# list #0 word #255: tweed
# attempt: 5
# list #0 word #256: marry
# attempt: 3
# list #0 word #257: shine
# attempt: 3
# list #0 word #258: smack
# attempt: 3
# list #0 word #259: smith
# attempt: 3
# list #0 word #260: squad
# attempt: 5
# list #0 word #261: rabbi
# attempt: 4
# list #0 word #262: dried
# attempt: 5
# list #0 word #263: twirl
# attempt: 3
# list #0 word #264: caddy
# attempt: 4
# list #0 word #265: ovate
# attempt: 2
# list #0 word #266: leech
# attempt: 4
# list #0 word #267: heist
# attempt: 3
# list #0 word #268: catty
# attempt: 6
# list #0 word #269: chess
# attempt: 3
# list #0 word #270: budge
# attempt: 7
# list #0 word #271: throb
# attempt: 2
# list #0 word #272: dryly
# attempt: 4
# list #0 word #273: hover
# attempt: 5
# list #0 word #274: ninja
# attempt: 4
# list #0 word #275: baker
# attempt: 3
# list #0 word #276: wiser
# attempt: 2
# list #0 word #277: prize
# attempt: 3
# list #0 word #278: twang
# attempt: 4
# list #0 word #279: prank
# attempt: 5
# list #0 word #280: fraud
# attempt: 5
# list #0 word #281: petal
# attempt: 3
# list #0 word #282: lowly
# attempt: 5
# list #0 word #283: exact
# attempt: 6
# list #0 word #284: merit
# attempt: 4
# list #0 word #285: sunny
# attempt: 5
# list #0 word #286: midst
# attempt: 3
# list #0 word #287: borne
# attempt: 5
# list #0 word #288: graph
# attempt: 4
# list #0 word #289: cloak
# attempt: 3
# list #0 word #290: fraud
# attempt: 3
# list #0 word #291: dirge
# attempt: 3
# list #0 word #292: turbo
# attempt: 3
# list #0 word #293: chaos
# attempt: 3
# list #0 word #294: bloke
# attempt: 4
# list #0 word #295: wafer
# attempt: 7
# list #0 word #296: mouse
# attempt: 6
# list #0 word #297: spiny
# attempt: 4
# list #0 word #298: olive
# attempt: 4
# list #0 word #299: budge
# attempt: 4
# list #0 word #300: reedy
# attempt: 4
# list #0 word #301: roast
# attempt: 3
# list #0 word #302: grade
# attempt: 6
# list #0 word #303: fauna
# attempt: 4
# list #0 word #304: afoul
# attempt: 5
# list #0 word #305: trust
# attempt: 4
# list #0 word #306: crone
# attempt: 5
# list #0 word #307: ranch
# attempt: 3
# list #0 word #308: fully
# attempt: 5
# list #0 word #309: batch
# attempt: 4
# list #0 word #310: alloy
# attempt: 5
# list #0 word #311: tamer
# attempt: 7
# list #0 word #312: eying
# attempt: 4
# list #0 word #313: beset
# attempt: 4
# list #0 word #314: eject
# attempt: 5
# list #0 word #315: mulch
# attempt: 4
# list #0 word #316: horny
# attempt: 4
# list #0 word #317: annul
# attempt: 4
# list #0 word #318: grade
# attempt: 3
# list #0 word #319: slash
# attempt: 6
# list #0 word #320: finch
# attempt: 3
# list #0 word #321: lease
# attempt: 4
# list #0 word #322: donut
# attempt: 4
# list #0 word #323: marsh
# attempt: 5
# list #0 word #324: fleet
# attempt: 4
# list #0 word #325: abbot
# attempt: 4
# list #0 word #326: crone
# attempt: 6
# list #0 word #327: llama
# attempt: 4
# list #0 word #328: gruel
# attempt: 5
# list #0 word #329: scarf
# attempt: 3
# list #0 word #330: micro
# attempt: 3
# list #0 word #331: disco
# attempt: 2
# list #0 word #332: horde
# attempt: 3
# list #0 word #333: quest
# attempt: 3
# list #0 word #334: folly
# attempt: 4
# list #0 word #335: abase
# attempt: 4
# list #0 word #336: poesy
# attempt: 2
# list #0 word #337: afoul
# attempt: 4
# list #0 word #338: tweet
# attempt: 4
# list #0 word #339: fleck
# attempt: 4
# list #0 word #340: bluff
# attempt: 5
# list #0 word #341: dogma
# attempt: 5
# list #0 word #342: thief
# attempt: 4
# list #0 word #343: arose
# attempt: 2
# list #0 word #344: these
# attempt: 4
# list #0 word #345: bilge
# attempt: 5
# list #0 word #346: trash
# attempt: 3
# list #0 word #347: siren
# attempt: 4
# list #0 word #348: brink
# attempt: 3
# list #0 word #349: lusty
# attempt: 4
# list #0 word #350: salsa
# attempt: 3
# list #0 word #351: trail
# attempt: 3
# list #0 word #352: spilt
# attempt: 3
# list #0 word #353: sword
# attempt: 2
# list #0 word #354: awake
# attempt: 4
# list #0 word #355: flyer
# attempt: 5
# list #0 word #356: aging
# attempt: 5
# list #0 word #357: erase
# attempt: 3
# list #0 word #358: mania
# attempt: 4
# list #0 word #359: arise
# attempt: 4
# list #0 word #360: maple
# attempt: 4
# list #0 word #361: taken
# attempt: 5
# list #0 word #362: ether
# attempt: 3
# list #0 word #363: fatty
# attempt: 5
# list #0 word #364: screw
# attempt: 3
# list #0 word #365: nosey
# attempt: 3
# list #0 word #366: bused
# attempt: 4
# list #0 word #367: swami
# attempt: 5
# list #0 word #368: treat
# attempt: 4
# list #0 word #369: forte
# attempt: 3
# list #0 word #370: motto
# attempt: 4
# list #0 word #371: order
# attempt: 3
# list #0 word #372: unity
# attempt: 3
# list #0 word #373: mason
# attempt: 4
# list #0 word #374: trawl
# attempt: 3
# list #0 word #375: flank
# attempt: 3
# list #0 word #376: decal
# attempt: 4
# list #0 word #377: truss
# attempt: 4
# list #0 word #378: lobby
# attempt: 3
# list #0 word #379: scrum
# attempt: 4
# list #0 word #380: cumin
# attempt: 4
# list #0 word #381: boney
# attempt: 5
# list #0 word #382: snuff
# attempt: 2
# list #0 word #383: filer
# attempt: 6
# list #0 word #384: covet
# attempt: 4
# list #0 word #385: aping
# attempt: 5
# list #0 word #386: women
# attempt: 3
# list #0 word #387: filet
# attempt: 4
# list #0 word #388: rodeo
# attempt: 3
# list #0 word #389: alive
# attempt: 3
# list #0 word #390: teach
# attempt: 3
# list #0 word #391: refer
# attempt: 4
# list #0 word #392: folio
# attempt: 4
# list #0 word #393: sulky
# attempt: 4
# list #0 word #394: snail
# attempt: 3
# list #0 word #395: peach
# attempt: 5
# list #0 word #396: sworn
# attempt: 2
# list #0 word #397: spilt
# attempt: 3
# list #0 word #398: cough
# attempt: 4
# list #0 word #399: water
# attempt: 4
# list #0 word #400: awoke
# attempt: 5
# list #0 word #401: shirk
# attempt: 5
# list #0 word #402: clamp
# attempt: 4
# list #0 word #403: trout
# attempt: 2
# list #0 word #404: tract
# attempt: 4
# list #0 word #405: anime
# attempt: 3
# list #0 word #406: panic
# attempt: 4
# list #0 word #407: ashen
# attempt: 4
# list #0 word #408: bylaw
# attempt: 3
# list #0 word #409: lance
# attempt: 4
# list #0 word #410: troll
# attempt: 3
# list #0 word #411: smash
# attempt: 4
# list #0 word #412: swami
# attempt: 4
# list #0 word #413: alien
# attempt: 4
# list #0 word #414: whack
# attempt: 4
# list #0 word #415: twine
# attempt: 2
# list #0 word #416: frost
# attempt: 2
# list #0 word #417: goner
# attempt: 4
# list #0 word #418: quilt
# attempt: 5
# list #0 word #419: brick
# attempt: 5
# list #0 word #420: dally
# attempt: 4
# list #0 word #421: canon
# attempt: 4
# list #0 word #422: cutie
# attempt: 3
# list #0 word #423: puree
# attempt: 4
# list #0 word #424: vomit
# attempt: 4
# list #0 word #425: chaos
# attempt: 3
# list #0 word #426: ideal
# attempt: 3
# list #0 word #427: trite
# attempt: 3
# list #0 word #428: crest
# attempt: 3
# list #0 word #429: basal
# attempt: 3
# list #0 word #430: lapel
# attempt: 4
# list #0 word #431: knave
# attempt: 5
# list #0 word #432: stiff
# attempt: 3
# list #0 word #433: lowly
# attempt: 5
# list #0 word #434: tulle
# attempt: 3
# list #0 word #435: berry
# attempt: 4
# list #0 word #436: elope
# attempt: 4
# list #0 word #437: decoy
# attempt: 3
# list #0 word #438: lasso
# attempt: 3
# list #0 word #439: blurt
# attempt: 3
# list #0 word #440: crack
# attempt: 4
# list #0 word #441: mucus
# attempt: 4
# list #0 word #442: silky
# attempt: 4
# list #0 word #443: pause
# attempt: 4
# list #0 word #444: spelt
# attempt: 4
# list #0 word #445: rotor
# attempt: 3
# list #0 word #446: blend
# attempt: 5
# list #0 word #447: snout
# attempt: 2
# list #0 word #448: friar
# attempt: 4
# list #0 word #449: quota
# attempt: 2
# list #0 word #450: probe
# attempt: 5
# list #0 word #451: crept
# attempt: 4
# list #0 word #452: where
# attempt: 3
# list #0 word #453: brisk
# attempt: 3
# list #0 word #454: squad
# attempt: 3
# list #0 word #455: stall
# attempt: 4
# list #0 word #456: totem
# attempt: 4
# list #0 word #457: pinto
# attempt: 4
# list #0 word #458: swoop
# attempt: 2
# list #0 word #459: drown
# attempt: 4
# list #0 word #460: slimy
# attempt: 4
# list #0 word #461: towel
# attempt: 4
# list #0 word #462: truth
# attempt: 6
# list #0 word #463: gayly
# attempt: 3
# list #0 word #464: beret
# attempt: 4
# list #0 word #465: error
# attempt: 3
# list #0 word #466: lathe
# attempt: 3
# list #0 word #467: magic
# attempt: 5
# list #0 word #468: showy
# attempt: 4
# list #0 word #469: leach
# attempt: 3
# list #0 word #470: level
# attempt: 3
# list #0 word #471: basis
# attempt: 4
# list #0 word #472: whine
# attempt: 3
# list #0 word #473: extol
# attempt: 3
# list #0 word #474: bulky
# attempt: 5
# list #0 word #475: spice
# attempt: 3
# list #0 word #476: unlit
# attempt: 3
# list #0 word #477: sepia
# attempt: 3
# list #0 word #478: tonic
# attempt: 4
# list #0 word #479: nudge
# attempt: 3
# list #0 word #480: amass
# attempt: 4
# list #0 word #481: stool
# attempt: 5
# list #0 word #482: worry
# attempt: 4
# list #0 word #483: waste
# attempt: 6
# list #0 word #484: plead
# attempt: 3
# list #0 word #485: lunge
# attempt: 4
# list #0 word #486: fight
# attempt: 4
# list #0 word #487: white
# attempt: 3
# list #0 word #488: grime
# attempt: 4
# list #0 word #489: swept
# attempt: 5
# list #0 word #490: ingot
# attempt: 4
# list #0 word #491: merry
# attempt: 4
# list #0 word #492: cream
# attempt: 4
# list #0 word #493: gripe
# attempt: 6
# list #0 word #494: mouse
# attempt: 6
# list #0 word #495: ledge
# attempt: 5
# list #0 word #496: until
# attempt: 4
# list #0 word #497: hefty
# attempt: 5
# list #0 word #498: hunky
# attempt: 2
# list #0 word #499: lunge
# attempt: 4
# list #0 word #500: crick
# attempt: 5
# list #1 word #1: condo
# attempt: 3
# list #1 word #2: tilde
# attempt: 5
# list #1 word #3: flown
# attempt: 4
# list #1 word #4: voice
# attempt: 4
# list #1 word #5: prime
# attempt: 5
# list #1 word #6: mange
# attempt: 4
# list #1 word #7: false
# attempt: 3
# list #1 word #8: batch
# attempt: 7
# list #1 word #9: spawn
# attempt: 3
# list #1 word #10: loose
# attempt: 3
# list #1 word #11: fiber
# attempt: 4
# list #1 word #12: prime
# attempt: 3
# list #1 word #13: offal
# attempt: 4
# list #1 word #14: facet
# attempt: 4
# list #1 word #15: plump
# attempt: 4
# list #1 word #16: nomad
# attempt: 5
# list #1 word #17: vixen
# attempt: 3
# list #1 word #18: froth
# attempt: 3
# list #1 word #19: gamma
# attempt: 5
# list #1 word #20: squat
# attempt: 4
# list #1 word #21: coven
# attempt: 4
# list #1 word #22: bacon
# attempt: 5
# list #1 word #23: flash
# attempt: 5
# list #1 word #24: quack
# attempt: 5
# list #1 word #25: golly
# attempt: 4
# list #1 word #26: catch
# attempt: 10
# list #1 word #27: tried
# attempt: 6
# list #1 word #28: villa
# attempt: 4
# list #1 word #29: dodgy
# attempt: 4
# list #1 word #30: tasty
# attempt: 4
# list #1 word #31: lowly
# attempt: 5
# list #1 word #32: house
# attempt: 3
# list #1 word #33: matey
# attempt: 3
# list #1 word #34: stand
# attempt: 6
# list #1 word #35: wedge
# attempt: 5
# list #1 word #36: rower
# attempt: 3
# list #1 word #37: liken
# attempt: 5
# list #1 word #38: guess
# attempt: 2
# list #1 word #39: bully
# attempt: 4
# list #1 word #40: godly
# attempt: 4
# list #1 word #41: clout
# attempt: 4
# list #1 word #42: koala
# attempt: 3
# list #1 word #43: sorry
# attempt: 3
# list #1 word #44: drain
# attempt: 4
# list #1 word #45: debar
# attempt: 4
# list #1 word #46: delay
# attempt: 4
# list #1 word #47: might
# attempt: 5
# list #1 word #48: crimp
# attempt: 3
# list #1 word #49: crack
# attempt: 5
# list #1 word #50: mount
# attempt: 4
# list #1 word #51: gamut
# attempt: 4
# list #1 word #52: unity
# attempt: 3
# list #1 word #53: sauna
# attempt: 4
# list #1 word #54: alive
# attempt: 4
# list #1 word #55: rhino
# attempt: 2
# list #1 word #56: harem
# attempt: 3
# list #1 word #57: actor
# attempt: 5
# list #1 word #58: scent
# attempt: 4
# list #1 word #59: token
# attempt: 4
# list #1 word #60: cynic
# attempt: 3
# list #1 word #61: boxer
# attempt: 8
# list #1 word #62: boost
# attempt: 3
# list #1 word #63: quark
# attempt: 5
# list #1 word #64: pilot
# attempt: 4
# list #1 word #65: truce
# attempt: 4
# list #1 word #66: serum
# attempt: 3
# list #1 word #67: freed
# attempt: 6
# list #1 word #68: pasty
# attempt: 2
# list #1 word #69: trove
# attempt: 5
# list #1 word #70: chime
# attempt: 5
# list #1 word #71: pasty
# attempt: 5
# list #1 word #72: woody
# attempt: 5
# list #1 word #73: belch
# attempt: 4
# list #1 word #74: frame
# attempt: 3
# list #1 word #75: pushy
# attempt: 3
# list #1 word #76: elegy
# attempt: 5
# list #1 word #77: rebus
# attempt: 2
# list #1 word #78: clamp
# attempt: 4
# list #1 word #79: juror
# attempt: 4
# list #1 word #80: cloak
# attempt: 2
# list #1 word #81: teddy
# attempt: 4
# list #1 word #82: wrest
# attempt: 4
# list #1 word #83: vying
# attempt: 5
# list #1 word #84: goner
# attempt: 5
# list #1 word #85: spunk
# attempt: 5
# list #1 word #86: blond
# attempt: 3
# list #1 word #87: snack
# attempt: 5
# list #1 word #88: beast
# attempt: 4
# list #1 word #89: brook
# attempt: 4
# list #1 word #90: morph
# attempt: 3
# list #1 word #91: title
# attempt: 4
# list #1 word #92: sneak
# attempt: 2
# list #1 word #93: basil
# attempt: 3
# list #1 word #94: liner
# attempt: 5
# list #1 word #95: wispy
# attempt: 4
# list #1 word #96: acrid
# attempt: 2
# list #1 word #97: briny
# attempt: 2
# list #1 word #98: truck
# attempt: 5
# list #1 word #99: mammy
# attempt: 4
# list #1 word #100: fatty
# attempt: 6
# list #1 word #101: spend
# attempt: 3
# list #1 word #102: batch
# attempt: 5
# list #1 word #103: knife
# attempt: 4
# list #1 word #104: until
# attempt: 4
# list #1 word #105: sting
# attempt: 6
# list #1 word #106: blood
# attempt: 5
# list #1 word #107: briny
# attempt: 5
# list #1 word #108: ditto
# attempt: 3
# list #1 word #109: lever
# attempt: 4
# list #1 word #110: suave
# attempt: 4
# list #1 word #111: polar
# attempt: 4
# list #1 word #112: semen
# attempt: 4
# list #1 word #113: viola
# attempt: 3
# list #1 word #114: shore
# attempt: 3
# list #1 word #115: sonar
# attempt: 4
# list #1 word #116: matey
# attempt: 4
# list #1 word #117: trade
# attempt: 3
# list #1 word #118: tonal
# attempt: 3
# list #1 word #119: bleep
# attempt: 4
# list #1 word #120: handy
# attempt: 5
# list #1 word #121: usher
# attempt: 2
# list #1 word #122: manly
# attempt: 4
# list #1 word #123: havoc
# attempt: 4
# list #1 word #124: index
# attempt: 3
# list #1 word #125: bleep
# attempt: 3
# list #1 word #126: billy
# attempt: 6
# list #1 word #127: flood
# attempt: 4
# list #1 word #128: punch
# attempt: 4
# list #1 word #129: eking
# attempt: 4
# list #1 word #130: clank
# attempt: 4
# list #1 word #131: aptly
# attempt: 3
# list #1 word #132: crowd
# attempt: 6
# list #1 word #133: slept
# attempt: 3
# list #1 word #134: which
# attempt: 4
# list #1 word #135: ovary
# attempt: 4
# list #1 word #136: baste
# attempt: 7
# list #1 word #137: arrow
# attempt: 4
# list #1 word #138: shunt
# attempt: 5
# list #1 word #139: since
# attempt: 4
# list #1 word #140: bully
# attempt: 5
# list #1 word #141: ample
# attempt: 4
# list #1 word #142: knoll
# attempt: 4
# list #1 word #143: decry
# attempt: 5
# list #1 word #144: ounce
# attempt: 4
# list #1 word #145: kneel
# attempt: 5
# list #1 word #146: knave
# attempt: 5
# list #1 word #147: elite
# attempt: 3
# list #1 word #148: taste
# attempt: 4
# list #1 word #149: stack
# attempt: 5
# list #1 word #150: scoff
# attempt: 4
# list #1 word #151: trait
# attempt: 2
# list #1 word #152: chock
# attempt: 3
# list #1 word #153: fatty
# attempt: 5
# list #1 word #154: click
# attempt: 4
# list #1 word #155: petal
# attempt: 5
# list #1 word #156: birth
# attempt: 4
# list #1 word #157: terra
# attempt: 5
# list #1 word #158: shaft
# attempt: 3
# list #1 word #159: fetus
# attempt: 3
# list #1 word #160: abbot
# attempt: 5
# list #1 word #161: polka
# attempt: 4
# list #1 word #162: dumpy
# attempt: 5
# list #1 word #163: dolly
# attempt: 3
# list #1 word #164: grimy
# attempt: 4
# list #1 word #165: virus
# attempt: 3
# list #1 word #166: trick
# attempt: 5
# list #1 word #167: feral
# attempt: 3
# list #1 word #168: train
# attempt: 6
# list #1 word #169: torch
# attempt: 5
# list #1 word #170: amply
# attempt: 4
# list #1 word #171: aorta
# attempt: 4
# list #1 word #172: slush
# attempt: 4
# list #1 word #173: abort
# attempt: 3
# list #1 word #174: woman
# attempt: 4
# list #1 word #175: freak
# attempt: 6
# list #1 word #176: earth
# attempt: 4
# list #1 word #177: slink
# attempt: 3
# list #1 word #178: ninny
# attempt: 3
# list #1 word #179: spare
# attempt: 2
# list #1 word #180: parka
# attempt: 6
# list #1 word #181: awake
# attempt: 5
# list #1 word #182: quash
# attempt: 5
# list #1 word #183: binge
# attempt: 4
# list #1 word #184: amuse
# attempt: 4
# list #1 word #185: golem
# attempt: 4
# list #1 word #186: flesh
# attempt: 5
# list #1 word #187: biddy
# attempt: 3
# list #1 word #188: ethos
# attempt: 4
# list #1 word #189: tenth
# attempt: 4
# list #1 word #190: chant
# attempt: 3
# list #1 word #191: troop
# attempt: 3
# list #1 word #192: riser
# attempt: 2
# list #1 word #193: sunny
# attempt: 3
# list #1 word #194: helix
# attempt: 3
# list #1 word #195: icing
# attempt: 5
# list #1 word #196: enemy
# attempt: 3
# list #1 word #197: crest
# attempt: 3
# list #1 word #198: scant
# attempt: 3
# list #1 word #199: chirp
# attempt: 3
# list #1 word #200: flash
# attempt: 5
# list #1 word #201: groin
# attempt: 3
# list #1 word #202: jumpy
# attempt: 5
# list #1 word #203: screw
# attempt: 4
# list #1 word #204: chest
# attempt: 4
# list #1 word #205: wound
# attempt: 7
# list #1 word #206: leach
# attempt: 4
# list #1 word #207: store
# attempt: 7
# list #1 word #208: scone
# attempt: 4
# list #1 word #209: moose
# attempt: 3
# list #1 word #210: beget
# attempt: 3
# list #1 word #211: zonal
# attempt: 3
# list #1 word #212: gecko
# attempt: 5
# list #1 word #213: flood
# attempt: 4
# list #1 word #214: segue
# attempt: 5
# list #1 word #215: seize
# attempt: 5
# list #1 word #216: dryly
# attempt: 4
# list #1 word #217: undid
# attempt: 5
# list #1 word #218: risky
# attempt: 2
# list #1 word #219: tweet
# attempt: 3
# list #1 word #220: blind
# attempt: 4
# list #1 word #221: shape
# attempt: 6
# list #1 word #222: happy
# attempt: 4
# list #1 word #223: using
# attempt: 3
# list #1 word #224: lithe
# attempt: 4
# list #1 word #225: petty
# attempt: 5
# list #1 word #226: revel
# attempt: 6
# list #1 word #227: sally
# attempt: 4
# list #1 word #228: taker
# attempt: 4
# list #1 word #229: scale
# attempt: 6
# list #1 word #230: thrum
# attempt: 3
# list #1 word #231: claim
# attempt: 3
# list #1 word #232: azure
# attempt: 3
# list #1 word #233: gusto
# attempt: 3
# list #1 word #234: dodge
# attempt: 4
# list #1 word #235: spawn
# attempt: 4
# list #1 word #236: bused
# attempt: 4
# list #1 word #237: ionic
# attempt: 5
# list #1 word #238: gaffe
# attempt: 4
# list #1 word #239: decor
# attempt: 5
# list #1 word #240: incur
# attempt: 3
# list #1 word #241: exist
# attempt: 3
# list #1 word #242: lemur
# attempt: 5
# list #1 word #243: scuba
# attempt: 3
# list #1 word #244: rally
# attempt: 4
# list #1 word #245: floor
# attempt: 4
# list #1 word #246: woven
# attempt: 5
# list #1 word #247: count
# attempt: 4
# list #1 word #248: shone
# attempt: 3
# list #1 word #249: spoke
# attempt: 3
# list #1 word #250: pause
# attempt: 4
# list #1 word #251: petty
# attempt: 4
# list #1 word #252: flume
# attempt: 3
# list #1 word #253: mango
# attempt: 4
# list #1 word #254: giver
# attempt: 3
# list #1 word #255: tweed
# attempt: 3
# list #1 word #256: marry
# attempt: 4
# list #1 word #257: shine
# attempt: 6
# list #1 word #258: smack
# attempt: 3
# list #1 word #259: smith
# attempt: 5
# list #1 word #260: squad
# attempt: 4
# list #1 word #261: rabbi
# attempt: 3
# list #1 word #262: dried
# attempt: 4
# list #1 word #263: twirl
# attempt: 6
# list #1 word #264: caddy
# attempt: 5
# list #1 word #265: ovate
# attempt: 3
# list #1 word #266: leech
# attempt: 4
# list #1 word #267: heist
# attempt: 3
# list #1 word #268: catty
# attempt: 4
# list #1 word #269: chess
# attempt: 2
# list #1 word #270: budge
# attempt: 4
# list #1 word #271: throb
# attempt: 4
# list #1 word #272: dryly
# attempt: 4
# list #1 word #273: hover
# attempt: 6
# list #1 word #274: ninja
# attempt: 5
# list #1 word #275: baker
# attempt: 5
# list #1 word #276: wiser
# attempt: 3
# list #1 word #277: prize
# attempt: 7
# list #1 word #278: twang
# attempt: 4
# list #1 word #279: prank
# attempt: 6
# list #1 word #280: fraud
# attempt: 5
# list #1 word #281: petal
# attempt: 3
# list #1 word #282: lowly
# attempt: 6
# list #1 word #283: exact
# attempt: 4
# list #1 word #284: merit
# attempt: 3
# list #1 word #285: sunny
# attempt: 4
# list #1 word #286: midst
# attempt: 2
# list #1 word #287: borne
# attempt: 5
# list #1 word #288: graph
# attempt: 5
# list #1 word #289: cloak
# attempt: 3
# list #1 word #290: fraud
# attempt: 4
# list #1 word #291: dirge
# attempt: 3
# list #1 word #292: turbo
# attempt: 4
# list #1 word #293: chaos
# attempt: 3
# list #1 word #294: bloke
# attempt: 5
# list #1 word #295: wafer
# attempt: 7
# list #1 word #296: mouse
# attempt: 5
# list #1 word #297: spiny
# attempt: 4
# list #1 word #298: olive
# attempt: 3
# list #1 word #299: budge
# attempt: 5
# list #1 word #300: reedy
# attempt: 3
# list #1 word #301: roast
# attempt: 2
# list #1 word #302: grade
# attempt: 6
# list #1 word #303: fauna
# attempt: 5
# list #1 word #304: afoul
# attempt: 3
# list #1 word #305: trust
# attempt: 3
# list #1 word #306: crone
# attempt: 3
# list #1 word #307: ranch
# attempt: 4
# list #1 word #308: fully
# attempt: 7
# list #1 word #309: batch
# attempt: 4
# list #1 word #310: alloy
# attempt: 5
# list #1 word #311: tamer
# attempt: 4
# list #1 word #312: eying
# attempt: 3
# list #1 word #313: beset
# attempt: 3
# list #1 word #314: eject
# attempt: 4
# list #1 word #315: mulch
# attempt: 4
# list #1 word #316: horny
# attempt: 3
# list #1 word #317: annul
# attempt: 4
# list #1 word #318: grade
# attempt: 4
# list #1 word #319: slash
# attempt: 4
# list #1 word #320: finch
# attempt: 4
# list #1 word #321: lease
# attempt: 3
# list #1 word #322: donut
# attempt: 4
# list #1 word #323: marsh
# attempt: 2
# list #1 word #324: fleet
# attempt: 4
# list #1 word #325: abbot
# attempt: 5
# list #1 word #326: crone
# attempt: 4
# list #1 word #327: llama
# attempt: 4
# list #1 word #328: gruel
# attempt: 5
# list #1 word #329: scarf
# attempt: 3
# list #1 word #330: micro
# attempt: 3
# list #1 word #331: disco
# attempt: 4
# list #1 word #332: horde
# attempt: 5
# list #1 word #333: quest
# attempt: 3
# list #1 word #334: folly
# attempt: 7
# list #1 word #335: abase
# attempt: 3
# list #1 word #336: poesy
# attempt: 4
# list #1 word #337: afoul
# attempt: 3
# list #1 word #338: tweet
# attempt: 3
# list #1 word #339: fleck
# attempt: 3
# list #1 word #340: bluff
# attempt: 3
# list #1 word #341: dogma
# attempt: 5
# list #1 word #342: thief
# attempt: 2
# list #1 word #343: arose
# attempt: 3
# list #1 word #344: these
# attempt: 3
# list #1 word #345: bilge
# attempt: 4
# list #1 word #346: trash
# attempt: 3
# list #1 word #347: siren
# attempt: 3
# list #1 word #348: brink
# attempt: 3
# list #1 word #349: lusty
# attempt: 4
# list #1 word #350: salsa
# attempt: 3
# list #1 word #351: trail
# attempt: 5
# list #1 word #352: spilt
# attempt: 3
# list #1 word #353: sword
# attempt: 4
# list #1 word #354: awake
# attempt: 6
# list #1 word #355: flyer
# attempt: 3
# list #1 word #356: aging
# attempt: 4
# list #1 word #357: erase
# attempt: 2
# list #1 word #358: mania
# attempt: 3
# list #1 word #359: arise
# attempt: 2
# list #1 word #360: maple
# attempt: 5
# list #1 word #361: taken
# attempt: 5
# list #1 word #362: ether
# attempt: 4
# list #1 word #363: fatty
# attempt: 7
# list #1 word #364: screw
# attempt: 4
# list #1 word #365: nosey
# attempt: 3
# list #1 word #366: bused
# attempt: 5
# list #1 word #367: swami
# attempt: 3
# list #1 word #368: treat
# attempt: 5
# list #1 word #369: forte
# attempt: 6
# list #1 word #370: motto
# attempt: 3
# list #1 word #371: order
# attempt: 6
# list #1 word #372: unity
# attempt: 5
# list #1 word #373: mason
# attempt: 4
# list #1 word #374: trawl
# attempt: 5
# list #1 word #375: flank
# attempt: 5
# list #1 word #376: decal
# attempt: 4
# list #1 word #377: truss
# attempt: 3
# list #1 word #378: lobby
# attempt: 4
# list #1 word #379: scrum
# attempt: 5
# list #1 word #380: cumin
# attempt: 2
# list #1 word #381: boney
# attempt: 3
# list #1 word #382: snuff
# attempt: 3
# list #1 word #383: filer
# attempt: 6
# list #1 word #384: covet
# attempt: 5
# list #1 word #385: aping
# attempt: 3
# list #1 word #386: women
# attempt: 4
# list #1 word #387: filet
# attempt: 3
# list #1 word #388: rodeo
# attempt: 3
# list #1 word #389: alive
# attempt: 5
# list #1 word #390: teach
# attempt: 5
# list #1 word #391: refer
# attempt: 5
# list #1 word #392: folio
# attempt: 3
# list #1 word #393: sulky
# attempt: 3
# list #1 word #394: snail
# attempt: 3
# list #1 word #395: peach
# attempt: 4
# list #1 word #396: sworn
# attempt: 2
# list #1 word #397: spilt
# attempt: 4
# list #1 word #398: cough
# attempt: 3
# list #1 word #399: water
# attempt: 4
# list #1 word #400: awoke
# attempt: 4
# list #1 word #401: shirk
# attempt: 4
# list #1 word #402: clamp
# attempt: 3
# list #1 word #403: trout
# attempt: 6
# list #1 word #404: tract
# attempt: 6
# list #1 word #405: anime
# attempt: 4
# list #1 word #406: panic
# attempt: 3
# list #1 word #407: ashen
# attempt: 4
# list #1 word #408: bylaw
# attempt: 4
# list #1 word #409: lance
# attempt: 5
# list #1 word #410: troll
# attempt: 5
# list #1 word #411: smash
# attempt: 4
# list #1 word #412: swami
# attempt: 3
# list #1 word #413: alien
# attempt: 2
# list #1 word #414: whack
# attempt: 4
# list #1 word #415: twine
# attempt: 3
# list #1 word #416: frost
# attempt: 4
# list #1 word #417: goner
# attempt: 8
# list #1 word #418: quilt
# attempt: 3
# list #1 word #419: brick
# attempt: 3
# list #1 word #420: dally
# attempt: 4
# list #1 word #421: canon
# attempt: 5
# list #1 word #422: cutie
# attempt: 3
# list #1 word #423: puree
# attempt: 3
# list #1 word #424: vomit
# attempt: 4
# list #1 word #425: chaos
# attempt: 4
# list #1 word #426: ideal
# attempt: 3
# list #1 word #427: trite
# attempt: 3
# list #1 word #428: crest
# attempt: 5
# list #1 word #429: basal
# attempt: 4
# list #1 word #430: lapel
# attempt: 2
# list #1 word #431: knave
# attempt: 4
# list #1 word #432: stiff
# attempt: 5
# list #1 word #433: lowly
# attempt: 5
# list #1 word #434: tulle
# attempt: 4
# list #1 word #435: berry
# attempt: 4
# list #1 word #436: elope
# attempt: 4
# list #1 word #437: decoy
# attempt: 4
# list #1 word #438: lasso
# attempt: 3
# list #1 word #439: blurt
# attempt: 3
# list #1 word #440: crack
# attempt: 3
# list #1 word #441: mucus
# attempt: 4
# list #1 word #442: silky
# attempt: 4
# list #1 word #443: pause
# attempt: 3
# list #1 word #444: spelt
# attempt: 3
# list #1 word #445: rotor
# attempt: 3
# list #1 word #446: blend
# attempt: 3
# list #1 word #447: snout
# attempt: 4
# list #1 word #448: friar
# attempt: 4
# list #1 word #449: quota
# attempt: 5
# list #1 word #450: probe
# attempt: 5
# list #1 word #451: crept
# attempt: 4
# list #1 word #452: where
# attempt: 5
# list #1 word #453: brisk
# attempt: 2
# list #1 word #454: squad
# attempt: 3
# list #1 word #455: stall
# attempt: 6
# list #1 word #456: totem
# attempt: 3
# list #1 word #457: pinto
# attempt: 4
# list #1 word #458: swoop
# attempt: 4
# list #1 word #459: drown
# attempt: 6
# list #1 word #460: slimy
# attempt: 3
# list #1 word #461: towel
# attempt: 4
# list #1 word #462: truth
# attempt: 6
# list #1 word #463: gayly
# attempt: 5
# list #1 word #464: beret
# attempt: 4
# list #1 word #465: error
# attempt: 4
# list #1 word #466: lathe
# attempt: 5
# list #1 word #467: magic
# attempt: 4
# list #1 word #468: showy
# attempt: 5
# list #1 word #469: leach
# attempt: 4
# list #1 word #470: level
# attempt: 5
# list #1 word #471: basis
# attempt: 3
# list #1 word #472: whine
# attempt: 4
# list #1 word #473: extol
# attempt: 5
# list #1 word #474: bulky
# attempt: 6
# list #1 word #475: spice
# attempt: 5
# list #1 word #476: unlit
# attempt: 4
# list #1 word #477: sepia
# attempt: 2
# list #1 word #478: tonic
# attempt: 4
# list #1 word #479: nudge
# attempt: 6
# list #1 word #480: amass
# attempt: 3
# list #1 word #481: stool
# attempt: 3
# list #1 word #482: worry
# attempt: 5
# list #1 word #483: waste
# attempt: 6
# list #1 word #484: plead
# attempt: 4
# list #1 word #485: lunge
# attempt: 3
# list #1 word #486: fight
# attempt: 3
# list #1 word #487: white
# attempt: 3
# list #1 word #488: grime
# attempt: 7
# list #1 word #489: swept
# attempt: 4
# list #1 word #490: ingot
# attempt: 4
# list #1 word #491: merry
# attempt: 5
# list #1 word #492: cream
# attempt: 6
# list #1 word #493: gripe
# attempt: 4
# list #1 word #494: mouse
# attempt: 5
# list #1 word #495: ledge
# attempt: 6
# list #1 word #496: until
# attempt: 5
# list #1 word #497: hefty
# attempt: 4
# list #1 word #498: hunky
# attempt: 3
# list #1 word #499: lunge
# attempt: 5
# list #1 word #500: crick
# attempt: 2
# list #2 word #1: condo
# attempt: 3
# list #2 word #2: tilde
# attempt: 3
# list #2 word #3: flown
# attempt: 2
# list #2 word #4: voice
# attempt: 3
# list #2 word #5: prime
# attempt: 6
# list #2 word #6: mange
# attempt: 4
# list #2 word #7: false
# attempt: 3
# list #2 word #8: batch
# attempt: 5
# list #2 word #9: spawn
# attempt: 3
# list #2 word #10: loose
# attempt: 6
# list #2 word #11: fiber
# attempt: 4
# list #2 word #12: prime
# attempt: 4
# list #2 word #13: offal
# attempt: 2
# list #2 word #14: facet
# attempt: 2
# list #2 word #15: plump
# attempt: 5
# list #2 word #16: nomad
# attempt: 3
# list #2 word #17: vixen
# attempt: 4
# list #2 word #18: froth
# attempt: 2
# list #2 word #19: gamma
# attempt: 4
# list #2 word #20: squat
# attempt: 4
# list #2 word #21: coven
# attempt: 3
# list #2 word #22: bacon
# attempt: 6
# list #2 word #23: flash
# attempt: 3
# list #2 word #24: quack
# attempt: 5
# list #2 word #25: golly
# attempt: 7
# list #2 word #26: catch
# attempt: 3
# list #2 word #27: tried
# attempt: 3
# list #2 word #28: villa
# attempt: 3
# list #2 word #29: dodgy
# attempt: 4
# list #2 word #30: tasty
# attempt: 5
# list #2 word #31: lowly
# attempt: 3
# list #2 word #32: house
# attempt: 6
# list #2 word #33: matey
# attempt: 3
# list #2 word #34: stand
# attempt: 5
# list #2 word #35: wedge
# attempt: 5
# list #2 word #36: rower
# attempt: 4
# list #2 word #37: liken
# attempt: 4
# list #2 word #38: guess
# attempt: 4
# list #2 word #39: bully
# attempt: 6
# list #2 word #40: godly
# attempt: 3
# list #2 word #41: clout
# attempt: 4
# list #2 word #42: koala
# attempt: 4
# list #2 word #43: sorry
# attempt: 4
# list #2 word #44: drain
# attempt: 3
# list #2 word #45: debar
# attempt: 3
# list #2 word #46: delay
# attempt: 5
# list #2 word #47: might
# attempt: 4
# list #2 word #48: crimp
# attempt: 5
# list #2 word #49: crack
# attempt: 5
# list #2 word #50: mount
# attempt: 3
# list #2 word #51: gamut
# attempt: 3
# list #2 word #52: unity
# attempt: 3
# list #2 word #53: sauna
# attempt: 5
# list #2 word #54: alive
# attempt: 4
# list #2 word #55: rhino
# attempt: 3
# list #2 word #56: harem
# attempt: 3
# list #2 word #57: actor
# attempt: 4
# list #2 word #58: scent
# attempt: 4
# list #2 word #59: token
# attempt: 2
# list #2 word #60: cynic
# attempt: 3
# list #2 word #61: boxer
# attempt: 4
# list #2 word #62: boost
# attempt: 5
# list #2 word #63: quark
# attempt: 4
# list #2 word #64: pilot
# attempt: 4
# list #2 word #65: truce
# attempt: 5
# list #2 word #66: serum
# attempt: 4
# list #2 word #67: freed
# attempt: 3
# list #2 word #68: pasty
# attempt: 5
# list #2 word #69: trove
# attempt: 3
# list #2 word #70: chime
# attempt: 4
# list #2 word #71: pasty
# attempt: 4
# list #2 word #72: woody
# attempt: 4
# list #2 word #73: belch
# attempt: 3
# list #2 word #74: frame
# attempt: 3
# list #2 word #75: pushy
# attempt: 4
# list #2 word #76: elegy
# attempt: 3
# list #2 word #77: rebus
# attempt: 4
# list #2 word #78: clamp
# attempt: 4
# list #2 word #79: juror
# attempt: 4
# list #2 word #80: cloak
# attempt: 5
# list #2 word #81: teddy
# attempt: 4
# list #2 word #82: wrest
# attempt: 4
# list #2 word #83: vying
# attempt: 3
# list #2 word #84: goner
# attempt: 2
# list #2 word #85: spunk
# attempt: 5
# list #2 word #86: blond
# attempt: 4
# list #2 word #87: snack
# attempt: 4
# list #2 word #88: beast
# attempt: 3
# list #2 word #89: brook
# attempt: 6
# list #2 word #90: morph
# attempt: 4
# list #2 word #91: title
# attempt: 4
# list #2 word #92: sneak
# attempt: 3
# list #2 word #93: basil
# attempt: 4
# list #2 word #94: liner
# attempt: 5
# list #2 word #95: wispy
# attempt: 4
# list #2 word #96: acrid
# attempt: 4
# list #2 word #97: briny
# attempt: 4
# list #2 word #98: truck
# attempt: 5
# list #2 word #99: mammy
# attempt: 3
# list #2 word #100: fatty
# attempt: 3
# list #2 word #101: spend
# attempt: 6
# list #2 word #102: batch
# attempt: 5
# list #2 word #103: knife
# attempt: 3
# list #2 word #104: until
# attempt: 2
# list #2 word #105: sting
# attempt: 4
# list #2 word #106: blood
# attempt: 4
# list #2 word #107: briny
# attempt: 5
# list #2 word #108: ditto
# attempt: 3
# list #2 word #109: lever
# attempt: 5
# list #2 word #110: suave
# attempt: 3
# list #2 word #111: polar
# attempt: 4
# list #2 word #112: semen
# attempt: 5
# list #2 word #113: viola
# attempt: 4
# list #2 word #114: shore
# attempt: 5
# list #2 word #115: sonar
# attempt: 3
# list #2 word #116: matey
# attempt: 4
# list #2 word #117: trade
# attempt: 5
# list #2 word #118: tonal
# attempt: 5
# list #2 word #119: bleep
# attempt: 3
# list #2 word #120: handy
# attempt: 3
# list #2 word #121: usher
# attempt: 3
# list #2 word #122: manly
# attempt: 5
# list #2 word #123: havoc
# attempt: 5
# list #2 word #124: index
# attempt: 4
# list #2 word #125: bleep
# attempt: 3
# list #2 word #126: billy
# attempt: 5
# list #2 word #127: flood
# attempt: 4
# list #2 word #128: punch
# attempt: 4
# list #2 word #129: eking
# attempt: 4
# list #2 word #130: clank
# attempt: 5
# list #2 word #131: aptly
# attempt: 3
# list #2 word #132: crowd
# attempt: 4
# list #2 word #133: slept
# attempt: 5
# list #2 word #134: which
# attempt: 3
# list #2 word #135: ovary
# attempt: 3
# list #2 word #136: baste
# attempt: 7
# list #2 word #137: arrow
# attempt: 4
# list #2 word #138: shunt
# attempt: 3
# list #2 word #139: since
# attempt: 3
# list #2 word #140: bully
# attempt: 6
# list #2 word #141: ample
# attempt: 4
# list #2 word #142: knoll
# attempt: 4
# list #2 word #143: decry
# attempt: 5
# list #2 word #144: ounce
# attempt: 3
# list #2 word #145: kneel
# attempt: 4
# list #2 word #146: knave
# attempt: 4
# list #2 word #147: elite
# attempt: 5
# list #2 word #148: taste
# attempt: 5
# list #2 word #149: stack
# attempt: 4
# list #2 word #150: scoff
# attempt: 3
# list #2 word #151: trait
# attempt: 4
# list #2 word #152: chock
# attempt: 3
# list #2 word #153: fatty
# attempt: 3
# list #2 word #154: click
# attempt: 4
# list #2 word #155: petal
# attempt: 3
# list #2 word #156: birth
# attempt: 6
# list #2 word #157: terra
# attempt: 4
# list #2 word #158: shaft
# attempt: 4
# list #2 word #159: fetus
# attempt: 3
# list #2 word #160: abbot
# attempt: 4
# list #2 word #161: polka
# attempt: 3
# list #2 word #162: dumpy
# attempt: 4
# list #2 word #163: dolly
# attempt: 4
# list #2 word #164: grimy
# attempt: 4
# list #2 word #165: virus
# attempt: 3
# list #2 word #166: trick
# attempt: 5
# list #2 word #167: feral
# attempt: 3
# list #2 word #168: train
# attempt: 2
# list #2 word #169: torch
# attempt: 3
# list #2 word #170: amply
# attempt: 4
# list #2 word #171: aorta
# attempt: 4
# list #2 word #172: slush
# attempt: 5
# list #2 word #173: abort
# attempt: 3
# list #2 word #174: woman
# attempt: 3
# list #2 word #175: freak
# attempt: 4
# list #2 word #176: earth
# attempt: 4
# list #2 word #177: slink
# attempt: 3
# list #2 word #178: ninny
# attempt: 4
# list #2 word #179: spare
# attempt: 3
# list #2 word #180: parka
# attempt: 3
# list #2 word #181: awake
# attempt: 6
# list #2 word #182: quash
# attempt: 4
# list #2 word #183: binge
# attempt: 4
# list #2 word #184: amuse
# attempt: 3
# list #2 word #185: golem
# attempt: 3
# list #2 word #186: flesh
# attempt: 4
# list #2 word #187: biddy
# attempt: 6
# list #2 word #188: ethos
# attempt: 4
# list #2 word #189: tenth
# attempt: 4
# list #2 word #190: chant
# attempt: 4
# list #2 word #191: troop
# attempt: 3
# list #2 word #192: riser
# attempt: 3
# list #2 word #193: sunny
# attempt: 5
# list #2 word #194: helix
# attempt: 4
# list #2 word #195: icing
# attempt: 4
# list #2 word #196: enemy
# attempt: 3
# list #2 word #197: crest
# attempt: 4
# list #2 word #198: scant
# attempt: 5
# list #2 word #199: chirp
# attempt: 6
# list #2 word #200: flash
# attempt: 4
# list #2 word #201: groin
# attempt: 5
# list #2 word #202: jumpy
# attempt: 4
# list #2 word #203: screw
# attempt: 4
# list #2 word #204: chest
# attempt: 4
# list #2 word #205: wound
# attempt: 5
# list #2 word #206: leach
# attempt: 5
# list #2 word #207: store
# attempt: 3
# list #2 word #208: scone
# attempt: 4
# list #2 word #209: moose
# attempt: 5
# list #2 word #210: beget
# attempt: 4
# list #2 word #211: zonal
# attempt: 3
# list #2 word #212: gecko
# attempt: 4
# list #2 word #213: flood
# attempt: 3
# list #2 word #214: segue
# attempt: 4
# list #2 word #215: seize
# attempt: 4
# list #2 word #216: dryly
# attempt: 4
# list #2 word #217: undid
# attempt: 4
# list #2 word #218: risky
# attempt: 5
# list #2 word #219: tweet
# attempt: 4
# list #2 word #220: blind
# attempt: 4
# list #2 word #221: shape
# attempt: 4
# list #2 word #222: happy
# attempt: 4
# list #2 word #223: using
# attempt: 4
# list #2 word #224: lithe
# attempt: 2
# list #2 word #225: petty
# attempt: 3
# list #2 word #226: revel
# attempt: 5
# list #2 word #227: sally
# attempt: 4
# list #2 word #228: taker
# attempt: 5
# list #2 word #229: scale
# attempt: 5
# list #2 word #230: thrum
# attempt: 4
# list #2 word #231: claim
# attempt: 4
# list #2 word #232: azure
# attempt: 5
# list #2 word #233: gusto
# attempt: 4
# list #2 word #234: dodge
# attempt: 3
# list #2 word #235: spawn
# attempt: 3
# list #2 word #236: bused
# attempt: 3
# list #2 word #237: ionic
# attempt: 4
# list #2 word #238: gaffe
# attempt: 3
# list #2 word #239: decor
# attempt: 5
# list #2 word #240: incur
# attempt: 4
# list #2 word #241: exist
# attempt: 4
# list #2 word #242: lemur
# attempt: 6
# list #2 word #243: scuba
# attempt: 4
# list #2 word #244: rally
# attempt: 4
# list #2 word #245: floor
# attempt: 4
# list #2 word #246: woven
# attempt: 4
# list #2 word #247: count
# attempt: 4
# list #2 word #248: shone
# attempt: 3
# list #2 word #249: spoke
# attempt: 4
# list #2 word #250: pause
# attempt: 5
# list #2 word #251: petty
# attempt: 4
# list #2 word #252: flume
# attempt: 3
# list #2 word #253: mango
# attempt: 4
# list #2 word #254: giver
# attempt: 5
# list #2 word #255: tweed
# attempt: 3
# list #2 word #256: marry
# attempt: 4
# list #2 word #257: shine
# attempt: 3
# list #2 word #258: smack
# attempt: 5
# list #2 word #259: smith
# attempt: 3
# list #2 word #260: squad
# attempt: 4
# list #2 word #261: rabbi
# attempt: 5
# list #2 word #262: dried
# attempt: 6
# list #2 word #263: twirl
# attempt: 4
# list #2 word #264: caddy
# attempt: 5
# list #2 word #265: ovate
# attempt: 2
# list #2 word #266: leech
# attempt: 4
# list #2 word #267: heist
# attempt: 4
# list #2 word #268: catty
# attempt: 2
# list #2 word #269: chess
# attempt: 3
# list #2 word #270: budge
# attempt: 4
# list #2 word #271: throb
# attempt: 3
# list #2 word #272: dryly
# attempt: 3
# list #2 word #273: hover
# attempt: 4
# list #2 word #274: ninja
# attempt: 4
# list #2 word #275: baker
# attempt: 3
# list #2 word #276: wiser
# attempt: 4
# list #2 word #277: prize
# attempt: 4
# list #2 word #278: twang
# attempt: 3
# list #2 word #279: prank
# attempt: 4
# list #2 word #280: fraud
# attempt: 4
# list #2 word #281: petal
# attempt: 3
# list #2 word #282: lowly
# attempt: 4
# list #2 word #283: exact
# attempt: 4
# list #2 word #284: merit
# attempt: 3
# list #2 word #285: sunny
# attempt: 4
# list #2 word #286: midst
# attempt: 5
# list #2 word #287: borne
# attempt: 3
# list #2 word #288: graph
# attempt: 4
# list #2 word #289: cloak
# attempt: 5
# list #2 word #290: fraud
# attempt: 3
# list #2 word #291: dirge
# attempt: 3
# list #2 word #292: turbo
# attempt: 3
# list #2 word #293: chaos
# attempt: 2
# list #2 word #294: bloke
# attempt: 7
# list #2 word #295: wafer
# attempt: 4
# list #2 word #296: mouse
# attempt: 3
# list #2 word #297: spiny
# attempt: 4
# list #2 word #298: olive
# attempt: 3
# list #2 word #299: budge
# attempt: 6
# list #2 word #300: reedy
# attempt: 5
# list #2 word #301: roast
# attempt: 5
# list #2 word #302: grade
# attempt: 3
# list #2 word #303: fauna
# attempt: 4
# list #2 word #304: afoul
# attempt: 2
# list #2 word #305: trust
# attempt: 4
# list #2 word #306: crone
# attempt: 4
# list #2 word #307: ranch
# attempt: 4
# list #2 word #308: fully
# attempt: 4
# list #2 word #309: batch
# attempt: 4
# list #2 word #310: alloy
# attempt: 3
# list #2 word #311: tamer
# attempt: 5
# list #2 word #312: eying
# attempt: 5
# list #2 word #313: beset
# attempt: 4
# list #2 word #314: eject
# attempt: 5
# list #2 word #315: mulch
# attempt: 5
# list #2 word #316: horny
# attempt: 2
# list #2 word #317: annul
# attempt: 4
# list #2 word #318: grade
# attempt: 5
# list #2 word #319: slash
# attempt: 2
# list #2 word #320: finch
# attempt: 3
# list #2 word #321: lease
# attempt: 5
# list #2 word #322: donut
# attempt: 4
# list #2 word #323: marsh
# attempt: 5
# list #2 word #324: fleet
# attempt: 3
# list #2 word #325: abbot
# attempt: 4
# list #2 word #326: crone
# attempt: 6
# list #2 word #327: llama
# attempt: 3
# list #2 word #328: gruel
# attempt: 4
# list #2 word #329: scarf
# attempt: 4
# list #2 word #330: micro
# attempt: 3
# list #2 word #331: disco
# attempt: 4
# list #2 word #332: horde
# attempt: 3
# list #2 word #333: quest
# attempt: 5
# list #2 word #334: folly
# attempt: 4
# list #2 word #335: abase
# attempt: 4
# list #2 word #336: poesy
# attempt: 4
# list #2 word #337: afoul
# attempt: 2
# list #2 word #338: tweet
# attempt: 3
# list #2 word #339: fleck
# attempt: 4
# list #2 word #340: bluff
# attempt: 3
# list #2 word #341: dogma
# attempt: 3
# list #2 word #342: thief
# attempt: 3
# ...
# attempt: 2
# list #9 word #56: harem
# attempt: 4
# list #9 word #57: actor
# attempt: 3
# list #9 word #58: scent
# attempt: 3
# list #9 word #59: token
# attempt: 3
# list #9 word #60: cynic
# attempt: 4
# list #9 word #61: boxer
# attempt: 5
# list #9 word #62: boost
# attempt: 3
# list #9 word #63: quark
# attempt: 5
# list #9 word #64: pilot
# attempt: 4
# list #9 word #65: truce
# attempt: 5
# list #9 word #66: serum
# attempt: 4
# list #9 word #67: freed
# attempt: 6
# list #9 word #68: pasty
# attempt: 6
# list #9 word #69: trove
# attempt: 5
# list #9 word #70: chime
# attempt: 5
# list #9 word #71: pasty
# attempt: 3
# list #9 word #72: woody
# attempt: 5
# list #9 word #73: belch
# attempt: 6
# list #9 word #74: frame
# attempt: 5
# list #9 word #75: pushy
# attempt: 5
# list #9 word #76: elegy
# attempt: 3
# list #9 word #77: rebus
# attempt: 4
# list #9 word #78: clamp
# attempt: 4
# list #9 word #79: juror
# attempt: 6
# list #9 word #80: cloak
# attempt: 4
# list #9 word #81: teddy
# attempt: 4
# list #9 word #82: wrest
# attempt: 4
# list #9 word #83: vying
# attempt: 5
# list #9 word #84: goner
# attempt: 2
# list #9 word #85: spunk
# attempt: 6
# list #9 word #86: blond
# attempt: 3
# list #9 word #87: snack
# attempt: 4
# list #9 word #88: beast
# attempt: 6
# list #9 word #89: brook
# attempt: 4
# list #9 word #90: morph
# attempt: 4
# list #9 word #91: title
# attempt: 4
# list #9 word #92: sneak
# attempt: 3
# list #9 word #93: basil
# attempt: 4
# list #9 word #94: liner
# attempt: 4
# list #9 word #95: wispy
# attempt: 5
# list #9 word #96: acrid
# attempt: 3
# list #9 word #97: briny
# attempt: 3
# list #9 word #98: truck
# attempt: 4
# list #9 word #99: mammy
# attempt: 8
# list #9 word #100: fatty
# attempt: 5
# list #9 word #101: spend
# attempt: 4
# list #9 word #102: batch
# attempt: 6
# list #9 word #103: knife
# attempt: 5
# list #9 word #104: until
# attempt: 3
# list #9 word #105: sting
# attempt: 5
# list #9 word #106: blood
# attempt: 4
# list #9 word #107: briny
# attempt: 3
# list #9 word #108: ditto
# attempt: 4
# list #9 word #109: lever
# attempt: 4
# list #9 word #110: suave
# attempt: 4
# list #9 word #111: polar
# attempt: 4
# list #9 word #112: semen
# attempt: 3
# list #9 word #113: viola
# attempt: 6
# list #9 word #114: shore
# attempt: 5
# list #9 word #115: sonar
# attempt: 4
# list #9 word #116: matey
# attempt: 5
# list #9 word #117: trade
# attempt: 4
# list #9 word #118: tonal
# attempt: 3
# list #9 word #119: bleep
# attempt: 4
# list #9 word #120: handy
# attempt: 3
# list #9 word #121: usher
# attempt: 5
# list #9 word #122: manly
# attempt: 5
# list #9 word #123: havoc
# attempt: 4
# list #9 word #124: index
# attempt: 3
# list #9 word #125: bleep
# attempt: 5
# list #9 word #126: billy
# attempt: 3
# list #9 word #127: flood
# attempt: 4
# list #9 word #128: punch
# attempt: 5
# list #9 word #129: eking
# attempt: 3
# list #9 word #130: clank
# attempt: 3
# list #9 word #131: aptly
# attempt: 4
# list #9 word #132: crowd
# attempt: 5
# list #9 word #133: slept
# attempt: 4
# list #9 word #134: which
# attempt: 3
# list #9 word #135: ovary
# attempt: 3
# list #9 word #136: baste
# attempt: 6
# list #9 word #137: arrow
# attempt: 4
# list #9 word #138: shunt
# attempt: 3
# list #9 word #139: since
# attempt: 3
# list #9 word #140: bully
# attempt: 5
# list #9 word #141: ample
# attempt: 5
# list #9 word #142: knoll
# attempt: 4
# list #9 word #143: decry
# attempt: 5
# list #9 word #144: ounce
# attempt: 4
# list #9 word #145: kneel
# attempt: 4
# list #9 word #146: knave
# attempt: 3
# list #9 word #147: elite
# attempt: 4
# list #9 word #148: taste
# attempt: 5
# list #9 word #149: stack
# attempt: 5
# list #9 word #150: scoff
# attempt: 4
# list #9 word #151: trait
# attempt: 2
# list #9 word #152: chock
# attempt: 4
# list #9 word #153: fatty
# attempt: 6
# list #9 word #154: click
# attempt: 5
# list #9 word #155: petal
# attempt: 3
# list #9 word #156: birth
# attempt: 4
# list #9 word #157: terra
# attempt: 4
# list #9 word #158: shaft
# attempt: 3
# list #9 word #159: fetus
# attempt: 4
# list #9 word #160: abbot
# attempt: 3
# list #9 word #161: polka
# attempt: 4
# list #9 word #162: dumpy
# attempt: 3
# list #9 word #163: dolly
# attempt: 3
# list #9 word #164: grimy
# attempt: 3
# list #9 word #165: virus
# attempt: 4
# list #9 word #166: trick
# attempt: 3
# list #9 word #167: feral
# attempt: 4
# list #9 word #168: train
# attempt: 2
# list #9 word #169: torch
# attempt: 5
# list #9 word #170: amply
# attempt: 4
# list #9 word #171: aorta
# attempt: 4
# list #9 word #172: slush
# attempt: 4
# list #9 word #173: abort
# attempt: 4
# list #9 word #174: woman
# attempt: 3
# list #9 word #175: freak
# attempt: 4
# list #9 word #176: earth
# attempt: 4
# list #9 word #177: slink
# attempt: 4
# list #9 word #178: ninny
# attempt: 3
# list #9 word #179: spare
# attempt: 6
# list #9 word #180: parka
# attempt: 4
# list #9 word #181: awake
# attempt: 5
# list #9 word #182: quash
# attempt: 6
# list #9 word #183: binge
# attempt: 3
# list #9 word #184: amuse
# attempt: 3
# list #9 word #185: golem
# attempt: 4
# list #9 word #186: flesh
# attempt: 4
# list #9 word #187: biddy
# attempt: 4
# list #9 word #188: ethos
# attempt: 3
# list #9 word #189: tenth
# attempt: 5
# list #9 word #190: chant
# attempt: 4
# list #9 word #191: troop
# attempt: 3
# list #9 word #192: riser
# attempt: 4
# list #9 word #193: sunny
# attempt: 4
# list #9 word #194: helix
# attempt: 5
# list #9 word #195: icing
# attempt: 7
# list #9 word #196: enemy
# attempt: 3
# list #9 word #197: crest
# attempt: 6
# list #9 word #198: scant
# attempt: 5
# list #9 word #199: chirp
# attempt: 4
# list #9 word #200: flash
# attempt: 5
# list #9 word #201: groin
# attempt: 2
# list #9 word #202: jumpy
# attempt: 5
# list #9 word #203: screw
# attempt: 4
# list #9 word #204: chest
# attempt: 3
# list #9 word #205: wound
# attempt: 3
# list #9 word #206: leach
# attempt: 3
# list #9 word #207: store
# attempt: 3
# list #9 word #208: scone
# attempt: 4
# list #9 word #209: moose
# attempt: 5
# list #9 word #210: beget
# attempt: 3
# list #9 word #211: zonal
# attempt: 4
# list #9 word #212: gecko
# attempt: 4
# list #9 word #213: flood
# attempt: 4
# list #9 word #214: segue
# attempt: 3
# list #9 word #215: seize
# attempt: 3
# list #9 word #216: dryly
# attempt: 5
# list #9 word #217: undid
# attempt: 3
# list #9 word #218: risky
# attempt: 3
# list #9 word #219: tweet
# attempt: 4
# list #9 word #220: blind
# attempt: 4
# list #9 word #221: shape
# attempt: 3
# list #9 word #222: happy
# attempt: 4
# list #9 word #223: using
# attempt: 5
# list #9 word #224: lithe
# attempt: 3
# list #9 word #225: petty
# attempt: 4
# list #9 word #226: revel
# attempt: 4
# list #9 word #227: sally
# attempt: 5
# list #9 word #228: taker
# attempt: 5
# list #9 word #229: scale
# attempt: 3
# list #9 word #230: thrum
# attempt: 4
# list #9 word #231: claim
# attempt: 4
# list #9 word #232: azure
# attempt: 4
# list #9 word #233: gusto
# attempt: 4
# list #9 word #234: dodge
# attempt: 3
# list #9 word #235: spawn
# attempt: 3
# list #9 word #236: bused
# attempt: 4
# list #9 word #237: ionic
# attempt: 5
# list #9 word #238: gaffe
# attempt: 5
# list #9 word #239: decor
# attempt: 5
# list #9 word #240: incur
# attempt: 3
# list #9 word #241: exist
# attempt: 3
# list #9 word #242: lemur
# attempt: 5
# list #9 word #243: scuba
# attempt: 4
# list #9 word #244: rally
# attempt: 4
# list #9 word #245: floor
# attempt: 3
# list #9 word #246: woven
# attempt: 4
# list #9 word #247: count
# attempt: 4
# list #9 word #248: shone
# attempt: 5
# list #9 word #249: spoke
# attempt: 5
# list #9 word #250: pause
# attempt: 6
# list #9 word #251: petty
# attempt: 4
# list #9 word #252: flume
# attempt: 4
# list #9 word #253: mango
# attempt: 3
# list #9 word #254: giver
# attempt: 3
# list #9 word #255: tweed
# attempt: 4
# list #9 word #256: marry
# attempt: 3
# list #9 word #257: shine
# attempt: 3
# list #9 word #258: smack
# attempt: 4
# list #9 word #259: smith
# attempt: 3
# list #9 word #260: squad
# attempt: 4
# list #9 word #261: rabbi
# attempt: 2
# list #9 word #262: dried
# attempt: 4
# list #9 word #263: twirl
# attempt: 5
# list #9 word #264: caddy
# attempt: 5
# list #9 word #265: ovate
# attempt: 4
# list #9 word #266: leech
# attempt: 3
# list #9 word #267: heist
# attempt: 2
# list #9 word #268: catty
# attempt: 5
# list #9 word #269: chess
# attempt: 3
# list #9 word #270: budge
# attempt: 3
# list #9 word #271: throb
# attempt: 4
# list #9 word #272: dryly
# attempt: 4
# list #9 word #273: hover
# attempt: 4
# list #9 word #274: ninja
# attempt: 3
# list #9 word #275: baker
# attempt: 5
# list #9 word #276: wiser
# attempt: 5
# list #9 word #277: prize
# attempt: 7
# list #9 word #278: twang
# attempt: 3
# list #9 word #279: prank
# attempt: 5
# list #9 word #280: fraud
# attempt: 3
# list #9 word #281: petal
# attempt: 4
# list #9 word #282: lowly
# attempt: 3
# list #9 word #283: exact
# attempt: 4
# list #9 word #284: merit
# attempt: 4
# list #9 word #285: sunny
# attempt: 4
# list #9 word #286: midst
# attempt: 4
# list #9 word #287: borne
# attempt: 3
# list #9 word #288: graph
# attempt: 4
# list #9 word #289: cloak
# attempt: 3
# list #9 word #290: fraud
# attempt: 6
# list #9 word #291: dirge
# attempt: 2
# list #9 word #292: turbo
# attempt: 4
# list #9 word #293: chaos
# attempt: 6
# list #9 word #294: bloke
# attempt: 5
# list #9 word #295: wafer
# attempt: 6
# list #9 word #296: mouse
# attempt: 4
# list #9 word #297: spiny
# attempt: 3
# list #9 word #298: olive
# attempt: 5
# list #9 word #299: budge
# attempt: 5
# list #9 word #300: reedy
# attempt: 5
# list #9 word #301: roast
# attempt: 4
# list #9 word #302: grade
# attempt: 3
# list #9 word #303: fauna
# attempt: 3
# list #9 word #304: afoul
# attempt: 3
# list #9 word #305: trust
# attempt: 4
# list #9 word #306: crone
# attempt: 4
# list #9 word #307: ranch
# attempt: 2
# list #9 word #308: fully
# attempt: 4
# list #9 word #309: batch
# attempt: 4
# list #9 word #310: alloy
# attempt: 4
# list #9 word #311: tamer
# attempt: 4
# list #9 word #312: eying
# attempt: 2
# list #9 word #313: beset
# attempt: 3
# list #9 word #314: eject
# attempt: 3
# list #9 word #315: mulch
# attempt: 4
# list #9 word #316: horny
# attempt: 4
# list #9 word #317: annul
# attempt: 4
# list #9 word #318: grade
# attempt: 5
# list #9 word #319: slash
# attempt: 4
# list #9 word #320: finch
# attempt: 6
# list #9 word #321: lease
# attempt: 4
# list #9 word #322: donut
# attempt: 3
# list #9 word #323: marsh
# attempt: 4
# list #9 word #324: fleet
# attempt: 4
# list #9 word #325: abbot
# attempt: 3
# list #9 word #326: crone
# attempt: 4
# list #9 word #327: llama
# attempt: 3
# list #9 word #328: gruel
# attempt: 3
# list #9 word #329: scarf
# attempt: 3
# list #9 word #330: micro
# attempt: 3
# list #9 word #331: disco
# attempt: 5
# list #9 word #332: horde
# attempt: 6
# list #9 word #333: quest
# attempt: 4
# list #9 word #334: folly
# attempt: 4
# list #9 word #335: abase
# attempt: 4
# list #9 word #336: poesy
# attempt: 3
# list #9 word #337: afoul
# attempt: 4
# list #9 word #338: tweet
# attempt: 5
# list #9 word #339: fleck
# attempt: 5
# list #9 word #340: bluff
# attempt: 4
# list #9 word #341: dogma
# attempt: 3
# list #9 word #342: thief
# attempt: 3
# list #9 word #343: arose
# attempt: 4
# list #9 word #344: these
# attempt: 4
# list #9 word #345: bilge
# attempt: 3
# list #9 word #346: trash
# attempt: 5
# list #9 word #347: siren
# attempt: 2
# list #9 word #348: brink
# attempt: 2
# list #9 word #349: lusty
# attempt: 3
# list #9 word #350: salsa
# attempt: 4
# list #9 word #351: trail
# attempt: 4
# list #9 word #352: spilt
# attempt: 4
# list #9 word #353: sword
# attempt: 3
# list #9 word #354: awake
# attempt: 5
# list #9 word #355: flyer
# attempt: 5
# list #9 word #356: aging
# attempt: 6
# list #9 word #357: erase
# attempt: 6
# list #9 word #358: mania
# attempt: 3
# list #9 word #359: arise
# attempt: 3
# list #9 word #360: maple
# attempt: 3
# list #9 word #361: taken
# attempt: 3
# list #9 word #362: ether
# attempt: 6
# list #9 word #363: fatty
# attempt: 7
# list #9 word #364: screw
# attempt: 5
# list #9 word #365: nosey
# attempt: 4
# list #9 word #366: bused
# attempt: 3
# list #9 word #367: swami
# attempt: 4
# list #9 word #368: treat
# attempt: 5
# list #9 word #369: forte
# attempt: 4
# list #9 word #370: motto
# attempt: 3
# list #9 word #371: order
# attempt: 4
# list #9 word #372: unity
# attempt: 3
# list #9 word #373: mason
# attempt: 3
# list #9 word #374: trawl
# attempt: 2
# list #9 word #375: flank
# attempt: 4
# list #9 word #376: decal
# attempt: 5
# list #9 word #377: truss
# attempt: 4
# list #9 word #378: lobby
# attempt: 4
# list #9 word #379: scrum
# attempt: 4
# list #9 word #380: cumin
# attempt: 3
# list #9 word #381: boney
# attempt: 5
# list #9 word #382: snuff
# attempt: 3
# list #9 word #383: filer
# attempt: 2
# list #9 word #384: covet
# attempt: 3
# list #9 word #385: aping
# attempt: 7
# list #9 word #386: women
# attempt: 4
# list #9 word #387: filet
# attempt: 3
# list #9 word #388: rodeo
# attempt: 3
# list #9 word #389: alive
# attempt: 5
# list #9 word #390: teach
# attempt: 5
# list #9 word #391: refer
# attempt: 5
# list #9 word #392: folio
# attempt: 4
# list #9 word #393: sulky
# attempt: 3
# list #9 word #394: snail
# attempt: 4
# list #9 word #395: peach
# attempt: 5
# list #9 word #396: sworn
# attempt: 5
# list #9 word #397: spilt
# attempt: 3
# list #9 word #398: cough
# attempt: 4
# list #9 word #399: water
# attempt: 7
# list #9 word #400: awoke
# attempt: 5
# list #9 word #401: shirk
# attempt: 3
# list #9 word #402: clamp
# attempt: 4
# list #9 word #403: trout
# attempt: 3
# list #9 word #404: tract
# attempt: 4
# list #9 word #405: anime
# attempt: 5
# list #9 word #406: panic
# attempt: 3
# list #9 word #407: ashen
# attempt: 4
# list #9 word #408: bylaw
# attempt: 3
# list #9 word #409: lance
# attempt: 3
# list #9 word #410: troll
# attempt: 4
# list #9 word #411: smash
# attempt: 4
# list #9 word #412: swami
# attempt: 4
# list #9 word #413: alien
# attempt: 2
# list #9 word #414: whack
# attempt: 5
# list #9 word #415: twine
# attempt: 5
# list #9 word #416: frost
# attempt: 3
# list #9 word #417: goner
# attempt: 3
# list #9 word #418: quilt
# attempt: 3
# list #9 word #419: brick
# attempt: 6
# list #9 word #420: dally
# attempt: 5
# list #9 word #421: canon
# attempt: 3
# list #9 word #422: cutie
# attempt: 4
# list #9 word #423: puree
# attempt: 5
# list #9 word #424: vomit
# attempt: 4
# list #9 word #425: chaos
# attempt: 5
# list #9 word #426: ideal
# attempt: 4
# list #9 word #427: trite
# attempt: 3
# list #9 word #428: crest
# attempt: 5
# list #9 word #429: basal
# attempt: 4
# list #9 word #430: lapel
# attempt: 4
# list #9 word #431: knave
# attempt: 4
# list #9 word #432: stiff
# attempt: 4
# list #9 word #433: lowly
# attempt: 5
# list #9 word #434: tulle
# attempt: 3
# list #9 word #435: berry
# attempt: 5
# list #9 word #436: elope
# attempt: 3
# list #9 word #437: decoy
# attempt: 5
# list #9 word #438: lasso
# attempt: 5
# list #9 word #439: blurt
# attempt: 4
# list #9 word #440: crack
# attempt: 5
# list #9 word #441: mucus
# attempt: 4
# list #9 word #442: silky
# attempt: 5
# list #9 word #443: pause
# attempt: 4
# list #9 word #444: spelt
# attempt: 5
# list #9 word #445: rotor
# attempt: 5
# list #9 word #446: blend
# attempt: 3
# list #9 word #447: snout
# attempt: 4
# list #9 word #448: friar
# attempt: 5
# list #9 word #449: quota
# attempt: 4
# list #9 word #450: probe
# attempt: 5
# list #9 word #451: crept
# attempt: 4
# list #9 word #452: where
# attempt: 3
# list #9 word #453: brisk
# attempt: 5
# list #9 word #454: squad
# attempt: 5
# list #9 word #455: stall
# attempt: 4
# list #9 word #456: totem
# attempt: 5
# list #9 word #457: pinto
# attempt: 4
# list #9 word #458: swoop
# attempt: 4
# list #9 word #459: drown
# attempt: 4
# list #9 word #460: slimy
# attempt: 4
# list #9 word #461: towel
# attempt: 3
# list #9 word #462: truth
# attempt: 4
# list #9 word #463: gayly
# attempt: 3
# list #9 word #464: beret
# attempt: 3
# list #9 word #465: error
# attempt: 3
# list #9 word #466: lathe
# attempt: 5
# list #9 word #467: magic
# attempt: 3
# list #9 word #468: showy
# attempt: 4
# list #9 word #469: leach
# attempt: 5
# list #9 word #470: level
# attempt: 4
# list #9 word #471: basis
# attempt: 4
# list #9 word #472: whine
# attempt: 3
# list #9 word #473: extol
# attempt: 4
# list #9 word #474: bulky
# attempt: 4
# list #9 word #475: spice
# attempt: 6
# list #9 word #476: unlit
# attempt: 3
# list #9 word #477: sepia
# attempt: 5
# list #9 word #478: tonic
# attempt: 5
# list #9 word #479: nudge
# attempt: 3
# list #9 word #480: amass
# attempt: 5
# list #9 word #481: stool
# attempt: 3
# list #9 word #482: worry
# attempt: 5
# list #9 word #483: waste
# attempt: 5
# list #9 word #484: plead
# attempt: 4
# list #9 word #485: lunge
# attempt: 3
# list #9 word #486: fight
# attempt: 7
# list #9 word #487: white
# attempt: 5
# list #9 word #488: grime
# attempt: 2
# list #9 word #489: swept
# attempt: 6
# list #9 word #490: ingot
# attempt: 3
# list #9 word #491: merry
# attempt: 6
# list #9 word #492: cream
# attempt: 5
# list #9 word #493: gripe
# attempt: 3
# list #9 word #494: mouse
# attempt: 5
# list #9 word #495: ledge
# attempt: 3
# list #9 word #496: until
# attempt: 3
# list #9 word #497: hefty
# attempt: 4
# list #9 word #498: hunky
# attempt: 4
# list #9 word #499: lunge
# attempt: 2
# list #9 word #500: crick
# attempt: 5

# %%
best_word = top_ten_words[int(avg_attempts.index(min(avg_attempts)))]

print(f"best_word: {best_word}")
print(f"avg_attempt for best_word: {min(avg_attempts)}")
# Out:
# best_word: poser
# avg_attempt for best_word: 3.924

# %%
# Print average attempts for training and testing
avg_training_attempts = sum(training_attempts) / len(training_attempts)
avg_testing_attempts = sum(testing_attempts) / len(testing_attempts)

print(f"Average attempts during training: {avg_training_attempts:.2f}")
print(f"Average attempts during testing: {min(avg_attempts):.2f}")
# Out:
# Average attempts during training: 4.10
# Average attempts during testing: 3.92

# %%
# Main game loop
attempts = 0
previous_guesses = []

print("Let's Play Wordle!")
print("Please think of a word and provide feedback as follows:")
print("0 for MISS, 1 for MISPLACED, and 2 for EXACT.")

while True:
    attempts += 1
    guess = bayesian_choose_word(possible_words, previous_guesses)
    
    # First step to set the first word
    if attempts == 1: guess = best_word
    
    feedback = []
    while True:
        try:
            feedback_input = input(f"Attempt {attempts}: {guess} - Enter feedback (0/1/2): ")
            feedback_input = [int(f) for f in feedback_input]
            if all(f in [0, 1, 2] for f in feedback_input) and len(feedback_input) == 5:
                for i in range(len(feedback_input)):
                    if feedback_input[i] == 0:
                        feedback.append("⬛")
                    elif feedback_input[i] == 1:
                        feedback.append("🟨")
                    elif feedback_input[i] == 2:
                        feedback.append("🟩")
            else:
                print("Invalid feedback. Please provide feedback as 0, 1, or 2.")
        except ValueError:
            print("Invalid feedback. Please provide feedback as 0, 1, or 2.")
        if len(feedback) == len(feedback_input):
            feedback = "".join(feedback)
            break
    previous_guesses.append((guess, feedback))
    print(feedback)

    if feedback.count("🟩") == 5:
        print(f"Congratulations! The word was '{guess}'. It took {attempts} attempts to guess.")
        break
# Out:
# Let's Play Wordle!
# Please think of a word and provide feedback as follows:
# 0 for MISS, 1 for MISPLACED, and 2 for EXACT.
# ⬛⬛🟩🟨🟨
# 🟩🟩🟩🟩🟩
# Congratulations! The word was 'resin'. It took 2 attempts to guess.
