# %%
import random

# %%
# Load the list of possible words from the file
with open('../Dataset/reduced_possible_words.txt', 'r') as file:
    possible_words = [line.strip() for line in file]

# Load the list of words for testing from the file
with open('../Dataset/prev_words_chr.txt', 'r') as file:
    testing_set = [line.strip() for line in file]

# %%
# Define feedback symbols
MISS = "⬛"
MISPLACED = "🟨"
EXACT = "🟩"

# %%
# Function to evaluate a guess based on feedback
def evaluate_guess(secret_word, guess):
    guess_copy = guess
    feedback = []
    remaining_secret_letters = list(secret_word)
    # First, check exact matches (greens)
    for i, (g1, g2) in enumerate(zip(secret_word, guess_copy)):
        if g1 == g2:
            feedback.append("🟩")
            remaining_secret_letters.remove(g1)
            guess_copy = guess_copy[:i] + "🟩" + guess_copy[i+1:]
        else:
            feedback.append("⬛")
    feedback_str = "".join(feedback)
    # Then, check letters but not in location (yellows)
    for i, g2 in enumerate(guess_copy):
        if g2 in remaining_secret_letters:
            feedback_str = feedback_str[:i] + "🟨" + feedback_str[i+1:]
            remaining_secret_letters.remove(g2)
    feedback = feedback_str
    return "".join(feedback)

# %%
# Function to generate a random word from the list of possible words
def choose_random_word(list):
    word = random.choice(possible_words)
    while word in list: word = random.choice(possible_words)
    return word

# %%
# Bayesian algorithm for word selection
def bayesian_choose_word(possible_words, previous_guesses):
    scores = {word: 0 for word in possible_words}
    for word in possible_words:
        for guess, feedback in previous_guesses:
            guess_feedback = evaluate_guess(word, guess)
            if guess_feedback == feedback:
                scores[word] += 1
    best_words = [word for word, score in scores.items() if score == max(scores.values())]
    return random.choice(best_words)

# %%
#  Training phase
training_set_size = 1000  # Adjust as needed
training_set = []
training_set = [choose_random_word(training_set) for _ in range(training_set_size)]
training_attempts = []

great_starting_word = []
great_starting_word_attempts = float('inf')

word = 0
the_word = None

# with open('best_words.txt', 'r') as file:
#     best_initial_words = [line.strip() for line in file]
best_initial_words = ['often']

counter = 0
for element in best_initial_words:    
    initial_guess = best_initial_words[counter]
    print(f"Initial Guess: {initial_guess}")
    for target_word in training_set:
        attempts = 1
        previous_guesses = [(initial_guess, evaluate_guess(target_word, initial_guess))]
        word += 1
        print(f"word #{word}: {target_word}")
        while True:
            guess = bayesian_choose_word(possible_words, previous_guesses)
            attempts += 1
            if attempts == 1:
                the_word = guess
            # elif attempts == 2:
            #     the_word = guess
            
            feedback = evaluate_guess(target_word, guess)
            previous_guesses.append((guess, feedback))
            if target_word == guess:
                print(f"attempt: {attempts}")
                training_attempts.append(attempts)
                
                if attempts < 3:
                    great_starting_word.append(the_word)
                    # great_starting_word_attempts = attempts
                break
    counter += 1
# Out:
# Initial Guess: often
# word #1: pulpy
# attempt: 5
# word #2: slosh
# attempt: 4
# word #3: vapor
# attempt: 4
# word #4: aglow
# attempt: 4
# word #5: ester
# attempt: 4
# word #6: after
# attempt: 2
# word #7: femme
# attempt: 3
# word #8: windy
# attempt: 6
# word #9: winch
# attempt: 4
# word #10: shave
# attempt: 4
# word #11: boule
# attempt: 4
# word #12: fizzy
# attempt: 5
# word #13: pesky
# attempt: 4
# word #14: ruler
# attempt: 5
# word #15: block
# attempt: 5
# word #16: chaos
# attempt: 4
# word #17: scoff
# attempt: 3
# word #18: cyber
# attempt: 5
# word #19: pecan
# attempt: 3
# word #20: juicy
# attempt: 5
# word #21: elbow
# attempt: 4
# word #22: squib
# attempt: 5
# word #23: flank
# attempt: 4
# word #24: swamp
# attempt: 5
# word #25: exert
# attempt: 4
# word #26: orbit
# attempt: 2
# word #27: tenet
# attempt: 3
# word #28: stout
# attempt: 4
# word #29: feign
# attempt: 3
# word #30: grasp
# attempt: 6
# word #31: score
# attempt: 5
# word #32: gonad
# attempt: 3
# word #33: shawl
# attempt: 4
# word #34: manic
# attempt: 4
# word #35: heave
# attempt: 4
# word #36: refit
# attempt: 3
# word #37: crisp
# attempt: 4
# word #38: steal
# attempt: 5
# word #39: tweet
# attempt: 3
# word #40: tangy
# attempt: 4
# word #41: plate
# attempt: 6
# word #42: smelt
# attempt: 5
# word #43: stake
# attempt: 5
# word #44: sober
# attempt: 5
# word #45: moron
# attempt: 4
# word #46: nadir
# attempt: 5
# word #47: filmy
# attempt: 5
# word #48: crank
# attempt: 4
# word #49: marry
# attempt: 6
# word #50: sixth
# attempt: 5
# word #51: stare
# attempt: 8
# word #52: cloth
# attempt: 5
# word #53: width
# attempt: 4
# word #54: drier
# attempt: 4
# word #55: raspy
# attempt: 4
# word #56: glaze
# attempt: 6
# word #57: cloak
# attempt: 4
# word #58: mason
# attempt: 3
# word #59: dirge
# attempt: 4
# word #60: screw
# attempt: 4
# word #61: sheet
# attempt: 3
# word #62: joint
# attempt: 4
# word #63: setup
# attempt: 3
# word #64: camel
# attempt: 5
# word #65: arose
# attempt: 4
# word #66: attic
# attempt: 3
# word #67: plate
# attempt: 4
# word #68: shine
# attempt: 5
# word #69: tonic
# attempt: 3
# word #70: waxen
# attempt: 3
# word #71: hasty
# attempt: 6
# word #72: pluck
# attempt: 4
# word #73: blade
# attempt: 5
# word #74: serum
# attempt: 4
# word #75: dummy
# attempt: 5
# word #76: endow
# attempt: 4
# word #77: flirt
# attempt: 3
# word #78: staid
# attempt: 4
# word #79: angle
# attempt: 4
# word #80: uncle
# attempt: 4
# word #81: cider
# attempt: 6
# word #82: inept
# attempt: 3
# word #83: chair
# attempt: 5
# word #84: dowry
# attempt: 4
# word #85: moody
# attempt: 5
# word #86: guile
# attempt: 4
# word #87: gnash
# attempt: 4
# word #88: smelt
# attempt: 4
# word #89: pesky
# attempt: 5
# word #90: downy
# attempt: 4
# word #91: stoke
# attempt: 3
# word #92: envoy
# attempt: 4
# word #93: shied
# attempt: 4
# word #94: vapor
# attempt: 4
# word #95: freed
# attempt: 3
# word #96: candy
# attempt: 4
# word #97: extra
# attempt: 3
# word #98: tipsy
# attempt: 4
# word #99: water
# attempt: 6
# word #100: gorge
# attempt: 5
# word #101: flora
# attempt: 5
# word #102: erode
# attempt: 4
# word #103: first
# attempt: 3
# word #104: click
# attempt: 4
# word #105: patsy
# attempt: 5
# word #106: hobby
# attempt: 4
# word #107: dodgy
# attempt: 6
# word #108: giant
# attempt: 3
# word #109: tunic
# attempt: 3
# word #110: hover
# attempt: 4
# word #111: askew
# attempt: 3
# word #112: apart
# attempt: 4
# word #113: junta
# attempt: 4
# word #114: betel
# attempt: 3
# word #115: guest
# attempt: 4
# word #116: saint
# attempt: 5
# word #117: ascot
# attempt: 2
# word #118: bough
# attempt: 5
# word #119: sissy
# attempt: 4
# word #120: puffy
# attempt: 3
# word #121: music
# attempt: 4
# word #122: saucy
# attempt: 4
# word #123: dogma
# attempt: 4
# word #124: tonic
# attempt: 3
# word #125: chuck
# attempt: 4
# word #126: plied
# attempt: 5
# word #127: locus
# attempt: 4
# word #128: gauze
# attempt: 5
# word #129: riser
# attempt: 3
# word #130: chime
# attempt: 5
# word #131: shook
# attempt: 3
# word #132: breed
# attempt: 6
# word #133: beard
# attempt: 4
# word #134: never
# attempt: 4
# word #135: briny
# attempt: 4
# word #136: plied
# attempt: 3
# word #137: plaza
# attempt: 5
# word #138: scree
# attempt: 5
# word #139: llama
# attempt: 4
# word #140: genie
# attempt: 3
# word #141: crest
# attempt: 3
# word #142: dairy
# attempt: 4
# word #143: gourd
# attempt: 5
# word #144: testy
# attempt: 4
# word #145: shoal
# attempt: 3
# word #146: idler
# attempt: 4
# word #147: unlit
# attempt: 4
# word #148: slimy
# attempt: 4
# word #149: shale
# attempt: 4
# word #150: guise
# attempt: 5
# word #151: logic
# attempt: 5
# word #152: cause
# attempt: 5
# word #153: prove
# attempt: 5
# word #154: downy
# attempt: 5
# word #155: greet
# attempt: 3
# word #156: ninth
# attempt: 3
# word #157: frown
# attempt: 2
# word #158: lousy
# attempt: 4
# word #159: pilot
# attempt: 4
# word #160: major
# attempt: 5
# word #161: conch
# attempt: 4
# word #162: abate
# attempt: 6
# word #163: randy
# attempt: 4
# word #164: aroma
# attempt: 5
# word #165: ready
# attempt: 5
# word #166: touch
# attempt: 3
# word #167: psalm
# attempt: 6
# word #168: awake
# attempt: 4
# word #169: abled
# attempt: 3
# word #170: bylaw
# attempt: 4
# word #171: slate
# attempt: 4
# word #172: chart
# attempt: 3
# word #173: smile
# attempt: 7
# word #174: climb
# attempt: 3
# word #175: exile
# attempt: 3
# word #176: house
# attempt: 2
# word #177: retry
# attempt: 3
# word #178: retry
# attempt: 4
# word #179: tutor
# attempt: 3
# word #180: miner
# attempt: 3
# word #181: write
# attempt: 4
# word #182: owner
# attempt: 2
# word #183: excel
# attempt: 5
# word #184: yacht
# attempt: 4
# word #185: hello
# attempt: 5
# word #186: sleep
# attempt: 4
# word #187: loyal
# attempt: 3
# word #188: afoot
# attempt: 2
# word #189: space
# attempt: 5
# word #190: timid
# attempt: 4
# word #191: knack
# attempt: 4
# word #192: bossy
# attempt: 4
# word #193: eaten
# attempt: 2
# word #194: trend
# attempt: 3
# word #195: style
# attempt: 4
# word #196: visit
# attempt: 4
# word #197: boast
# attempt: 5
# word #198: avail
# attempt: 4
# word #199: reign
# attempt: 4
# word #200: honor
# attempt: 3
# word #201: waltz
# attempt: 4
# word #202: major
# attempt: 5
# word #203: elder
# attempt: 5
# word #204: trend
# attempt: 3
# word #205: singe
# attempt: 4
# word #206: plait
# attempt: 5
# word #207: taint
# attempt: 4
# word #208: terra
# attempt: 5
# word #209: snide
# attempt: 4
# word #210: brine
# attempt: 4
# word #211: dodge
# attempt: 4
# word #212: fresh
# attempt: 4
# word #213: patch
# attempt: 4
# word #214: ghoul
# attempt: 4
# word #215: fluff
# attempt: 4
# word #216: polar
# attempt: 4
# word #217: berth
# attempt: 3
# word #218: react
# attempt: 3
# word #219: evict
# attempt: 4
# word #220: pixie
# attempt: 4
# word #221: privy
# attempt: 4
# word #222: tepee
# attempt: 4
# word #223: groom
# attempt: 4
# word #224: skimp
# attempt: 3
# word #225: sheep
# attempt: 5
# word #226: scamp
# attempt: 4
# word #227: recur
# attempt: 4
# word #228: exact
# attempt: 4
# word #229: amiss
# attempt: 4
# word #230: valet
# attempt: 5
# word #231: chime
# attempt: 5
# word #232: gnome
# attempt: 3
# word #233: aphid
# attempt: 4
# word #234: plait
# attempt: 4
# word #235: snail
# attempt: 4
# word #236: slimy
# attempt: 4
# word #237: gruel
# attempt: 4
# word #238: doubt
# attempt: 5
# word #239: drown
# attempt: 5
# word #240: morph
# attempt: 4
# word #241: mogul
# attempt: 5
# word #242: reign
# attempt: 4
# word #243: creme
# attempt: 5
# word #244: pixie
# attempt: 5
# word #245: broad
# attempt: 3
# word #246: month
# attempt: 3
# word #247: abbey
# attempt: 4
# word #248: water
# attempt: 6
# word #249: comma
# attempt: 4
# word #250: start
# attempt: 2
# word #251: cough
# attempt: 4
# word #252: faith
# attempt: 3
# word #253: fixer
# attempt: 3
# word #254: model
# attempt: 4
# word #255: widow
# attempt: 4
# word #256: gouge
# attempt: 4
# word #257: shame
# attempt: 3
# word #258: braid
# attempt: 4
# word #259: putty
# attempt: 3
# word #260: snout
# attempt: 3
# word #261: crane
# attempt: 4
# word #262: scuba
# attempt: 4
# word #263: natal
# attempt: 3
# word #264: prank
# attempt: 3
# word #265: godly
# attempt: 3
# word #266: macro
# attempt: 4
# word #267: awful
# attempt: 3
# word #268: chose
# attempt: 5
# word #269: login
# attempt: 4
# word #270: disco
# attempt: 4
# word #271: clown
# attempt: 3
# word #272: bleed
# attempt: 4
# word #273: guilt
# attempt: 6
# word #274: karma
# attempt: 4
# word #275: tease
# attempt: 4
# word #276: cheer
# attempt: 4
# word #277: catty
# attempt: 4
# word #278: topaz
# attempt: 4
# word #279: tangy
# attempt: 3
# word #280: plank
# attempt: 4
# word #281: borne
# attempt: 3
# word #282: hyper
# attempt: 3
# word #283: welch
# attempt: 5
# word #284: ratty
# attempt: 5
# word #285: intro
# attempt: 2
# word #286: ashen
# attempt: 4
# word #287: their
# attempt: 3
# word #288: groom
# attempt: 4
# word #289: crepe
# attempt: 4
# word #290: gamer
# attempt: 3
# word #291: rearm
# attempt: 4
# word #292: ether
# attempt: 5
# word #293: dolly
# attempt: 5
# word #294: matey
# attempt: 3
# word #295: tweed
# attempt: 4
# word #296: sinew
# attempt: 4
# word #297: buggy
# attempt: 4
# word #298: amiss
# attempt: 4
# word #299: night
# attempt: 3
# word #300: optic
# attempt: 3
# word #301: glide
# attempt: 5
# word #302: filly
# attempt: 3
# word #303: merit
# attempt: 5
# word #304: shady
# attempt: 4
# word #305: false
# attempt: 3
# word #306: parka
# attempt: 4
# word #307: naive
# attempt: 4
# word #308: fleet
# attempt: 3
# word #309: carat
# attempt: 4
# word #310: shaky
# attempt: 5
# word #311: deuce
# attempt: 4
# word #312: butte
# attempt: 3
# word #313: bride
# attempt: 3
# word #314: shall
# attempt: 4
# word #315: arose
# attempt: 6
# word #316: bossy
# attempt: 3
# word #317: leant
# attempt: 3
# word #318: plate
# attempt: 4
# word #319: unmet
# attempt: 2
# word #320: bylaw
# attempt: 4
# word #321: spray
# attempt: 4
# word #322: scrub
# attempt: 4
# word #323: gamma
# attempt: 4
# word #324: penny
# attempt: 3
# word #325: abbey
# attempt: 5
# word #326: tying
# attempt: 3
# word #327: beach
# attempt: 5
# word #328: serif
# attempt: 3
# word #329: field
# attempt: 4
# word #330: blown
# attempt: 3
# word #331: mogul
# attempt: 5
# word #332: bribe
# attempt: 3
# word #333: trawl
# attempt: 4
# word #334: cower
# attempt: 5
# word #335: pecan
# attempt: 3
# word #336: skull
# attempt: 4
# word #337: fraud
# attempt: 3
# word #338: since
# attempt: 4
# word #339: drown
# attempt: 4
# word #340: glare
# attempt: 3
# word #341: noise
# attempt: 3
# word #342: hefty
# attempt: 4
# word #343: globe
# attempt: 3
# word #344: worst
# attempt: 5
# word #345: judge
# attempt: 4
# word #346: manic
# attempt: 4
# word #347: fraud
# attempt: 3
# word #348: rough
# attempt: 5
# word #349: drank
# attempt: 5
# word #350: slyly
# attempt: 5
# word #351: bless
# attempt: 3
# word #352: spell
# attempt: 4
# word #353: chain
# attempt: 2
# word #354: probe
# attempt: 5
# word #355: their
# attempt: 3
# word #356: depth
# attempt: 6
# word #357: snuck
# attempt: 4
# word #358: undid
# attempt: 3
# word #359: still
# attempt: 6
# word #360: sower
# attempt: 5
# word #361: awoke
# attempt: 5
# word #362: piety
# attempt: 4
# word #363: oxide
# attempt: 3
# word #364: bough
# attempt: 5
# word #365: salve
# attempt: 4
# word #366: finer
# attempt: 3
# word #367: snail
# attempt: 4
# word #368: decoy
# attempt: 4
# word #369: bravo
# attempt: 5
# word #370: golem
# attempt: 5
# word #371: issue
# attempt: 4
# word #372: tense
# attempt: 3
# word #373: adopt
# attempt: 4
# word #374: patty
# attempt: 6
# word #375: shady
# attempt: 5
# word #376: radio
# attempt: 3
# word #377: decry
# attempt: 3
# word #378: pinch
# attempt: 4
# word #379: pubic
# attempt: 4
# word #380: timid
# attempt: 4
# word #381: along
# attempt: 2
# word #382: clock
# attempt: 4
# word #383: buggy
# attempt: 6
# word #384: hutch
# attempt: 4
# word #385: willy
# attempt: 6
# word #386: karma
# attempt: 4
# word #387: pasta
# attempt: 4
# word #388: clear
# attempt: 5
# word #389: brake
# attempt: 4
# word #390: gulch
# attempt: 4
# word #391: terse
# attempt: 3
# word #392: reach
# attempt: 4
# word #393: grate
# attempt: 5
# word #394: attic
# attempt: 3
# word #395: helix
# attempt: 3
# word #396: cramp
# attempt: 5
# word #397: glory
# attempt: 4
# word #398: haste
# attempt: 3
# word #399: state
# attempt: 3
# word #400: flood
# attempt: 3
# word #401: parer
# attempt: 4
# word #402: rerun
# attempt: 3
# word #403: bosom
# attempt: 3
# word #404: groom
# attempt: 4
# word #405: musky
# attempt: 5
# word #406: stank
# attempt: 4
# word #407: aware
# attempt: 6
# word #408: found
# attempt: 2
# word #409: ferry
# attempt: 3
# word #410: awful
# attempt: 3
# word #411: revue
# attempt: 4
# word #412: slung
# attempt: 3
# word #413: totem
# attempt: 4
# word #414: power
# attempt: 6
# word #415: price
# attempt: 4
# word #416: iliac
# attempt: 4
# word #417: lunch
# attempt: 4
# word #418: silky
# attempt: 4
# word #419: elbow
# attempt: 4
# word #420: slang
# attempt: 4
# word #421: midst
# attempt: 4
# word #422: hairy
# attempt: 3
# word #423: quail
# attempt: 6
# word #424: posse
# attempt: 7
# word #425: grind
# attempt: 3
# word #426: bingo
# attempt: 5
# word #427: favor
# attempt: 5
# word #428: trend
# attempt: 4
# word #429: slack
# attempt: 5
# word #430: avert
# attempt: 5
# word #431: snout
# attempt: 4
# word #432: glaze
# attempt: 4
# word #433: dodge
# attempt: 6
# word #434: flung
# attempt: 4
# word #435: lapel
# attempt: 3
# word #436: unity
# attempt: 4
# word #437: gnome
# attempt: 5
# word #438: spiky
# attempt: 6
# word #439: tawny
# attempt: 4
# word #440: raspy
# attempt: 4
# word #441: email
# attempt: 4
# word #442: these
# attempt: 3
# word #443: untie
# attempt: 2
# word #444: idiot
# attempt: 5
# word #445: spoon
# attempt: 3
# word #446: taken
# attempt: 2
# word #447: larva
# attempt: 4
# word #448: flake
# attempt: 4
# word #449: ennui
# attempt: 3
# word #450: unify
# attempt: 3
# word #451: super
# attempt: 4
# word #452: islet
# attempt: 4
# word #453: poppy
# attempt: 5
# word #454: rouse
# attempt: 3
# word #455: scrum
# attempt: 4
# word #456: fetal
# attempt: 4
# word #457: gonad
# attempt: 4
# word #458: goody
# attempt: 5
# word #459: fauna
# attempt: 3
# word #460: crash
# attempt: 5
# word #461: crime
# attempt: 4
# word #462: cocoa
# attempt: 4
# word #463: slant
# attempt: 4
# word #464: sower
# attempt: 7
# word #465: bleak
# attempt: 4
# word #466: shake
# attempt: 5
# word #467: viper
# attempt: 4
# word #468: shall
# attempt: 4
# word #469: booby
# attempt: 6
# word #470: gamut
# attempt: 5
# word #471: juicy
# attempt: 5
# word #472: plant
# attempt: 4
# word #473: tithe
# attempt: 4
# word #474: waste
# attempt: 4
# word #475: tilde
# attempt: 3
# word #476: dodge
# attempt: 4
# word #477: razor
# attempt: 5
# word #478: grout
# attempt: 4
# word #479: tubal
# attempt: 3
# word #480: parse
# attempt: 6
# word #481: flora
# attempt: 4
# word #482: octet
# attempt: 2
# word #483: expel
# attempt: 4
# word #484: hatch
# attempt: 4
# word #485: noise
# attempt: 4
# word #486: sound
# attempt: 3
# word #487: infer
# attempt: 3
# word #488: image
# attempt: 4
# word #489: abled
# attempt: 4
# word #490: taunt
# attempt: 7
# word #491: queue
# attempt: 5
# word #492: gecko
# attempt: 4
# word #493: album
# attempt: 5
# word #494: igloo
# attempt: 4
# word #495: vaunt
# attempt: 7
# word #496: sever
# attempt: 6
# word #497: locus
# attempt: 4
# word #498: title
# attempt: 3
# word #499: hotly
# attempt: 4
# word #500: pride
# attempt: 5
# word #501: woody
# attempt: 5
# word #502: frank
# attempt: 3
# word #503: treat
# attempt: 3
# word #504: usurp
# attempt: 4
# word #505: happy
# attempt: 4
# word #506: yield
# attempt: 3
# word #507: aging
# attempt: 3
# word #508: saucy
# attempt: 4
# word #509: stout
# attempt: 4
# word #510: weedy
# attempt: 3
# word #511: round
# attempt: 5
# word #512: serif
# attempt: 3
# word #513: plunk
# attempt: 4
# word #514: porch
# attempt: 4
# word #515: block
# attempt: 4
# word #516: bring
# attempt: 5
# word #517: lease
# attempt: 5
# word #518: urine
# attempt: 5
# word #519: segue
# attempt: 3
# word #520: dumpy
# attempt: 5
# word #521: savvy
# attempt: 5
# word #522: probe
# attempt: 5
# word #523: prose
# attempt: 5
# word #524: quilt
# attempt: 4
# word #525: probe
# attempt: 5
# word #526: outer
# attempt: 2
# word #527: shave
# attempt: 5
# word #528: curve
# attempt: 4
# word #529: flair
# attempt: 4
# word #530: rumba
# attempt: 2
# word #531: bride
# attempt: 4
# word #532: nylon
# attempt: 4
# word #533: piney
# attempt: 4
# word #534: tense
# attempt: 3
# word #535: scout
# attempt: 5
# word #536: frost
# attempt: 3
# word #537: latch
# attempt: 9
# word #538: idler
# attempt: 4
# word #539: bloom
# attempt: 4
# word #540: bless
# attempt: 5
# word #541: media
# attempt: 4
# word #542: rumba
# attempt: 5
# word #543: biome
# attempt: 4
# word #544: ledge
# attempt: 6
# word #545: scowl
# attempt: 4
# word #546: aptly
# attempt: 4
# word #547: hotel
# attempt: 4
# word #548: burst
# attempt: 3
# word #549: pound
# attempt: 3
# word #550: outgo
# attempt: 3
# word #551: semen
# attempt: 3
# word #552: modal
# attempt: 5
# word #553: leaky
# attempt: 4
# word #554: abuse
# attempt: 5
# word #555: berth
# attempt: 4
# word #556: draft
# attempt: 5
# word #557: tibia
# attempt: 4
# word #558: farce
# attempt: 3
# word #559: there
# attempt: 6
# word #560: idiom
# attempt: 5
# word #561: arise
# attempt: 4
# word #562: zesty
# attempt: 3
# word #563: envoy
# attempt: 4
# word #564: plait
# attempt: 3
# word #565: stead
# attempt: 4
# word #566: knife
# attempt: 3
# word #567: shade
# attempt: 7
# word #568: admit
# attempt: 5
# word #569: trope
# attempt: 3
# word #570: gypsy
# attempt: 4
# word #571: stomp
# attempt: 4
# word #572: water
# attempt: 5
# word #573: guest
# attempt: 5
# word #574: adore
# attempt: 4
# word #575: anvil
# attempt: 4
# word #576: still
# attempt: 4
# word #577: spark
# attempt: 4
# word #578: demon
# attempt: 3
# word #579: leper
# attempt: 5
# word #580: argue
# attempt: 4
# word #581: leery
# attempt: 3
# word #582: fluid
# attempt: 3
# word #583: flora
# attempt: 3
# word #584: wrath
# attempt: 4
# word #585: otter
# attempt: 3
# word #586: smile
# attempt: 4
# word #587: riser
# attempt: 3
# word #588: toxic
# attempt: 3
# word #589: donor
# attempt: 4
# word #590: buggy
# attempt: 5
# word #591: sweat
# attempt: 4
# word #592: white
# attempt: 5
# word #593: stalk
# attempt: 5
# word #594: goody
# attempt: 6
# word #595: debar
# attempt: 5
# word #596: comic
# attempt: 4
# word #597: photo
# attempt: 3
# word #598: bravo
# attempt: 4
# word #599: elect
# attempt: 4
# word #600: lurid
# attempt: 3
# word #601: equip
# attempt: 4
# word #602: drain
# attempt: 4
# word #603: boast
# attempt: 4
# word #604: godly
# attempt: 4
# word #605: howdy
# attempt: 5
# word #606: swath
# attempt: 4
# word #607: could
# attempt: 3
# word #608: motif
# attempt: 2
# word #609: vigil
# attempt: 5
# word #610: gnome
# attempt: 4
# word #611: lodge
# attempt: 4
# word #612: merge
# attempt: 5
# word #613: focal
# attempt: 4
# word #614: depth
# attempt: 5
# word #615: putty
# attempt: 4
# word #616: lever
# attempt: 4
# word #617: abide
# attempt: 4
# word #618: lapel
# attempt: 7
# word #619: forty
# attempt: 2
# word #620: quest
# attempt: 3
# word #621: wrest
# attempt: 4
# word #622: freed
# attempt: 3
# word #623: cruel
# attempt: 3
# word #624: enter
# attempt: 2
# word #625: clown
# attempt: 4
# word #626: shirk
# attempt: 5
# word #627: etude
# attempt: 4
# word #628: queen
# attempt: 5
# word #629: howdy
# attempt: 5
# word #630: sense
# attempt: 5
# word #631: skulk
# attempt: 5
# word #632: muddy
# attempt: 6
# word #633: forte
# attempt: 2
# word #634: abbey
# attempt: 4
# word #635: chore
# attempt: 3
# word #636: seize
# attempt: 5
# word #637: slice
# attempt: 4
# word #638: wagon
# attempt: 4
# word #639: stamp
# attempt: 7
# word #640: uncle
# attempt: 4
# word #641: leaky
# attempt: 4
# word #642: grimy
# attempt: 3
# word #643: imbue
# attempt: 4
# word #644: dunce
# attempt: 4
# word #645: dozen
# attempt: 4
# word #646: small
# attempt: 4
# word #647: arbor
# attempt: 4
# word #648: chick
# attempt: 4
# word #649: issue
# attempt: 4
# word #650: lease
# attempt: 4
# word #651: pesto
# attempt: 2
# word #652: shelf
# attempt: 2
# word #653: bleak
# attempt: 4
# word #654: proud
# attempt: 5
# word #655: sushi
# attempt: 4
# word #656: derby
# attempt: 4
# word #657: porch
# attempt: 4
# word #658: cheap
# attempt: 4
# word #659: trail
# attempt: 3
# word #660: cause
# attempt: 4
# word #661: close
# attempt: 5
# word #662: butch
# attempt: 4
# word #663: pubic
# attempt: 3
# word #664: bagel
# attempt: 4
# word #665: weary
# attempt: 3
# word #666: grain
# attempt: 5
# word #667: banal
# attempt: 5
# word #668: court
# attempt: 4
# word #669: amble
# attempt: 4
# word #670: spook
# attempt: 4
# word #671: donor
# attempt: 5
# word #672: bushy
# attempt: 4
# word #673: aunty
# attempt: 3
# word #674: brood
# attempt: 4
# word #675: carol
# attempt: 3
# word #676: kayak
# attempt: 4
# word #677: unfit
# attempt: 3
# word #678: grief
# attempt: 2
# word #679: chock
# attempt: 4
# word #680: grope
# attempt: 6
# word #681: swear
# attempt: 3
# word #682: parry
# attempt: 4
# word #683: party
# attempt: 5
# word #684: chose
# attempt: 4
# word #685: radii
# attempt: 4
# word #686: align
# attempt: 3
# word #687: overt
# attempt: 3
# word #688: stoop
# attempt: 3
# word #689: stool
# attempt: 5
# word #690: civil
# attempt: 5
# word #691: vivid
# attempt: 5
# word #692: sleek
# attempt: 3
# word #693: beard
# attempt: 4
# word #694: coral
# attempt: 3
# word #695: scale
# attempt: 3
# word #696: scour
# attempt: 6
# word #697: heart
# attempt: 3
# word #698: junto
# attempt: 5
# word #699: nasty
# attempt: 3
# word #700: rearm
# attempt: 5
# word #701: bagel
# attempt: 3
# word #702: thorn
# attempt: 2
# word #703: rapid
# attempt: 4
# word #704: regal
# attempt: 4
# word #705: quake
# attempt: 5
# word #706: putty
# attempt: 3
# word #707: sling
# attempt: 5
# word #708: lousy
# attempt: 4
# word #709: crawl
# attempt: 3
# word #710: wispy
# attempt: 4
# word #711: align
# attempt: 3
# word #712: sweet
# attempt: 4
# word #713: pansy
# attempt: 3
# word #714: cluck
# attempt: 5
# word #715: tepid
# attempt: 3
# word #716: thank
# attempt: 3
# word #717: ankle
# attempt: 4
# word #718: steed
# attempt: 5
# word #719: noose
# attempt: 4
# word #720: craze
# attempt: 6
# word #721: risky
# attempt: 4
# word #722: conic
# attempt: 5
# word #723: bulge
# attempt: 4
# word #724: cramp
# attempt: 5
# word #725: batty
# attempt: 4
# word #726: scuba
# attempt: 4
# word #727: peach
# attempt: 3
# word #728: rouse
# attempt: 3
# word #729: toxic
# attempt: 6
# word #730: clown
# attempt: 5
# word #731: sauce
# attempt: 4
# word #732: trout
# attempt: 4
# word #733: array
# attempt: 4
# word #734: flood
# attempt: 5
# word #735: topic
# attempt: 4
# word #736: saucy
# attempt: 4
# word #737: broom
# attempt: 3
# word #738: bliss
# attempt: 3
# word #739: flown
# attempt: 3
# word #740: vodka
# attempt: 3
# word #741: dense
# attempt: 5
# word #742: towel
# attempt: 4
# word #743: shied
# attempt: 4
# word #744: rumba
# attempt: 6
# word #745: curvy
# attempt: 4
# word #746: slosh
# attempt: 3
# word #747: bathe
# attempt: 4
# word #748: steed
# attempt: 5
# word #749: arson
# attempt: 5
# word #750: crank
# attempt: 3
# word #751: glory
# attempt: 5
# word #752: kinky
# attempt: 4
# word #753: sworn
# attempt: 4
# word #754: ocean
# attempt: 2
# word #755: skull
# attempt: 5
# word #756: caput
# attempt: 4
# word #757: plier
# attempt: 3
# word #758: quasi
# attempt: 5
# word #759: model
# attempt: 3
# word #760: stiff
# attempt: 3
# word #761: humid
# attempt: 4
# word #762: lodge
# attempt: 3
# word #763: winch
# attempt: 4
# word #764: basis
# attempt: 4
# word #765: apnea
# attempt: 4
# word #766: unify
# attempt: 3
# word #767: larva
# attempt: 5
# word #768: lusty
# attempt: 6
# word #769: tutor
# attempt: 4
# word #770: enemy
# attempt: 4
# word #771: seven
# attempt: 4
# word #772: clink
# attempt: 4
# word #773: crepe
# attempt: 4
# word #774: labor
# attempt: 5
# word #775: royal
# attempt: 3
# word #776: vodka
# attempt: 6
# word #777: lance
# attempt: 5
# word #778: lusty
# attempt: 4
# word #779: fetus
# attempt: 2
# word #780: peace
# attempt: 7
# word #781: today
# attempt: 4
# word #782: lucky
# attempt: 4
# word #783: drool
# attempt: 6
# word #784: scaly
# attempt: 5
# word #785: erase
# attempt: 2
# word #786: elide
# attempt: 5
# word #787: suing
# attempt: 3
# word #788: minim
# attempt: 3
# word #789: split
# attempt: 4
# word #790: purer
# attempt: 6
# word #791: badge
# attempt: 4
# word #792: chart
# attempt: 4
# word #793: claim
# attempt: 4
# word #794: jolly
# attempt: 3
# word #795: croak
# attempt: 4
# word #796: dolly
# attempt: 5
# word #797: credo
# attempt: 4
# word #798: kappa
# attempt: 4
# word #799: savor
# attempt: 5
# word #800: allow
# attempt: 5
# word #801: impel
# attempt: 5
# word #802: clued
# attempt: 5
# word #803: cheek
# attempt: 4
# word #804: frank
# attempt: 4
# word #805: macho
# attempt: 4
# word #806: owner
# attempt: 2
# word #807: mealy
# attempt: 4
# word #808: roger
# attempt: 4
# word #809: joist
# attempt: 6
# word #810: worth
# attempt: 6
# word #811: dwelt
# attempt: 3
# word #812: ahead
# attempt: 4
# word #813: savoy
# attempt: 4
# word #814: exult
# attempt: 4
# word #815: allay
# attempt: 4
# word #816: rumor
# attempt: 4
# word #817: semen
# attempt: 3
# word #818: spicy
# attempt: 4
# word #819: inner
# attempt: 3
# word #820: witty
# attempt: 7
# word #821: spelt
# attempt: 4
# word #822: front
# attempt: 2
# word #823: tumor
# attempt: 3
# word #824: forte
# attempt: 2
# word #825: frown
# attempt: 2
# word #826: milky
# attempt: 4
# word #827: chafe
# attempt: 3
# word #828: wrath
# attempt: 3
# word #829: split
# attempt: 4
# word #830: scarf
# attempt: 3
# word #831: felon
# attempt: 2
# word #832: magma
# attempt: 3
# word #833: giver
# attempt: 5
# word #834: smote
# attempt: 3
# word #835: wager
# attempt: 4
# word #836: store
# attempt: 3
# word #837: axiom
# attempt: 4
# word #838: elfin
# attempt: 2
# word #839: surly
# attempt: 2
# word #840: enter
# attempt: 2
# word #841: every
# attempt: 4
# word #842: repel
# attempt: 5
# word #843: deter
# attempt: 4
# word #844: swash
# attempt: 4
# word #845: stuck
# attempt: 4
# word #846: wrest
# attempt: 3
# word #847: usage
# attempt: 4
# word #848: score
# attempt: 5
# word #849: latte
# attempt: 4
# word #850: pried
# attempt: 6
# word #851: haute
# attempt: 3
# word #852: major
# attempt: 5
# word #853: pique
# attempt: 4
# word #854: queen
# attempt: 3
# word #855: foyer
# attempt: 2
# word #856: gauge
# attempt: 4
# word #857: exile
# attempt: 5
# word #858: youth
# attempt: 5
# word #859: igloo
# attempt: 3
# word #860: movie
# attempt: 4
# word #861: derby
# attempt: 4
# word #862: cubic
# attempt: 4
# word #863: price
# attempt: 3
# word #864: candy
# attempt: 4
# word #865: gamma
# attempt: 4
# word #866: wacky
# attempt: 3
# word #867: shaft
# attempt: 3
# word #868: ditty
# attempt: 5
# word #869: afoot
# attempt: 2
# word #870: sheer
# attempt: 5
# word #871: stomp
# attempt: 6
# word #872: locus
# attempt: 4
# word #873: wooer
# attempt: 5
# word #874: snail
# attempt: 3
# word #875: derby
# attempt: 4
# word #876: pulpy
# attempt: 5
# word #877: zebra
# attempt: 4
# word #878: truth
# attempt: 4
# word #879: trick
# attempt: 2
# word #880: pasta
# attempt: 3
# word #881: wager
# attempt: 5
# word #882: ripen
# attempt: 6
# word #883: borne
# attempt: 3
# word #884: renew
# attempt: 3
# word #885: unify
# attempt: 3
# word #886: mealy
# attempt: 4
# word #887: murky
# attempt: 4
# word #888: bulge
# attempt: 4
# word #889: taint
# attempt: 4
# word #890: crust
# attempt: 3
# word #891: furor
# attempt: 3
# word #892: alike
# attempt: 6
# word #893: boozy
# attempt: 5
# word #894: small
# attempt: 5
# word #895: taffy
# attempt: 3
# word #896: manor
# attempt: 3
# word #897: bossy
# attempt: 6
# word #898: scrap
# attempt: 3
# word #899: rowdy
# attempt: 5
# word #900: month
# attempt: 3
# word #901: knife
# attempt: 3
# word #902: drool
# attempt: 3
# word #903: semen
# attempt: 3
# word #904: blood
# attempt: 4
# word #905: igloo
# attempt: 3
# word #906: biome
# attempt: 5
# word #907: spree
# attempt: 4
# word #908: salty
# attempt: 3
# word #909: rinse
# attempt: 4
# word #910: chock
# attempt: 6
# word #911: ebony
# attempt: 3
# word #912: boxer
# attempt: 8
# word #913: hyper
# attempt: 6
# word #914: pygmy
# attempt: 3
# word #915: crony
# attempt: 3
# word #916: human
# attempt: 4
# word #917: suave
# attempt: 5
# word #918: poise
# attempt: 5
# word #919: lower
# attempt: 4
# word #920: glove
# attempt: 4
# word #921: trice
# attempt: 4
# word #922: holly
# attempt: 3
# word #923: cobra
# attempt: 4
# word #924: syrup
# attempt: 4
# word #925: lance
# attempt: 3
# word #926: beady
# attempt: 5
# word #927: honey
# attempt: 3
# word #928: spoke
# attempt: 5
# word #929: truer
# attempt: 4
# word #930: pilot
# attempt: 4
# word #931: empty
# attempt: 3
# word #932: riper
# attempt: 4
# word #933: sloth
# attempt: 4
# word #934: riser
# attempt: 5
# word #935: grout
# attempt: 4
# word #936: humid
# attempt: 3
# word #937: atoll
# attempt: 4
# word #938: range
# attempt: 4
# word #939: actor
# attempt: 4
# word #940: ladle
# attempt: 4
# word #941: hobby
# attempt: 5
# word #942: diode
# attempt: 4
# word #943: agape
# attempt: 5
# word #944: sassy
# attempt: 4
# word #945: randy
# attempt: 3
# word #946: truck
# attempt: 3
# word #947: angst
# attempt: 4
# word #948: flunk
# attempt: 3
# word #949: sneak
# attempt: 4
# word #950: style
# attempt: 3
# word #951: nerve
# attempt: 4
# word #952: perch
# attempt: 4
# word #953: doing
# attempt: 4
# word #954: slash
# attempt: 4
# word #955: stove
# attempt: 5
# word #956: mocha
# attempt: 4
# word #957: knead
# attempt: 4
# word #958: natal
# attempt: 2
# word #959: sight
# attempt: 5
# word #960: islet
# attempt: 3
# word #961: chirp
# attempt: 4
# word #962: entry
# attempt: 3
# word #963: abode
# attempt: 5
# word #964: sweat
# attempt: 3
# word #965: guano
# attempt: 4
# word #966: beget
# attempt: 3
# word #967: salvo
# attempt: 4
# word #968: glean
# attempt: 3
# word #969: dandy
# attempt: 4
# word #970: bigot
# attempt: 3
# word #971: moody
# attempt: 4
# word #972: groin
# attempt: 4
# word #973: smash
# attempt: 4
# word #974: glove
# attempt: 5
# word #975: lucky
# attempt: 4
# word #976: greed
# attempt: 4
# word #977: elder
# attempt: 3
# word #978: fault
# attempt: 3
# word #979: decay
# attempt: 4
# word #980: agent
# attempt: 3
# word #981: slimy
# attempt: 3
# word #982: trove
# attempt: 5
# word #983: sepia
# attempt: 3
# word #984: where
# attempt: 4
# word #985: pulpy
# attempt: 4
# word #986: shire
# attempt: 4
# word #987: demon
# attempt: 4
# word #988: thing
# attempt: 3
# word #989: chose
# attempt: 4
# word #990: timer
# attempt: 3
# word #991: porch
# attempt: 4
# word #992: taken
# attempt: 2
# word #993: cavil
# attempt: 5
# word #994: raven
# attempt: 4
# word #995: mason
# attempt: 5
# word #996: trait
# attempt: 4
# word #997: synod
# attempt: 4
# word #998: ingot
# attempt: 3
# word #999: kinky
# attempt: 5
# word #1000: month
# attempt: 4

# %%
# Testing phase
testing_attempts = []
word = 0
the_word = None
feedback = []
best_starting_word = []
best_starting_word_attempts = float('inf')
# print(possible_words)

counter = 0
for element in best_initial_words:  
    initial_guess = best_initial_words[counter]
    print(f"Initial Guess: {initial_guess}")

    for target_word in testing_set:
        attempts = 1
        previous_guesses = [(initial_guess, evaluate_guess(target_word, initial_guess))]
        word += 1
        print(f"word #{word}: {target_word}")

        while True:
            attempts += 1
            guess = bayesian_choose_word(possible_words, previous_guesses)
            # print(guess)
            if attempts == 1:
                # guess = random.choice(great_starting_word)
                the_word = guess
            # elif attempts == 2:
            #     the_word = guess
            
            feedback = evaluate_guess(target_word, guess)
            previous_guesses.append((guess, feedback))
            if target_word == guess:
                print(f"attempt: {attempts}")
                testing_attempts.append(attempts)
                if attempts < 3:
                    best_starting_word.append(the_word)
                    # best_starting_word_attempts = attempts
                break
    counter += 1
# Out:
# Initial Guess: often
# word #1: noise
# attempt: 4
# word #2: bleak
# attempt: 4
# word #3: grail
# attempt: 5
# word #4: phony
# attempt: 4
# word #5: mason
# attempt: 4
# word #6: noble
# attempt: 3
# word #7: pique
# attempt: 4
# word #8: retry
# attempt: 4
# word #9: cause
# attempt: 4
# word #10: tempo
# attempt: 3
# word #11: given
# attempt: 5
# word #12: smirk
# attempt: 4
# word #13: occur
# attempt: 3
# word #14: splat
# attempt: 4
# word #15: mercy
# attempt: 5
# word #16: adult
# attempt: 4
# word #17: graph
# attempt: 4
# word #18: leaky
# attempt: 5
# word #19: agent
# attempt: 4
# word #20: uncle
# attempt: 4
# word #21: knelt
# attempt: 4
# word #22: skunk
# attempt: 5
# word #23: snail
# attempt: 3
# word #24: truth
# attempt: 6
# word #25: binge
# attempt: 3
# word #26: viola
# attempt: 4
# word #27: chime
# attempt: 4
# word #28: bunch
# attempt: 5
# word #29: spurt
# attempt: 5
# word #30: while
# attempt: 5
# word #31: merry
# attempt: 5
# word #32: beret
# attempt: 3
# word #33: daddy
# attempt: 4
# word #34: azure
# attempt: 4
# word #35: coach
# attempt: 5
# word #36: smile
# attempt: 5
# word #37: loyal
# attempt: 4
# word #38: rocky
# attempt: 4
# word #39: right
# attempt: 5
# word #40: carol
# attempt: 4
# word #41: brush
# attempt: 3
# word #42: stone
# attempt: 2
# word #43: snare
# attempt: 3
# word #44: close
# attempt: 4
# word #45: frank
# attempt: 4
# word #46: music
# attempt: 4
# word #47: angel
# attempt: 4
# word #48: exert
# attempt: 4
# word #49: rayon
# attempt: 5
# word #50: clear
# attempt: 4
# word #51: whisk
# attempt: 4
# word #52: older
# attempt: 4
# word #53: quote
# attempt: 3
# word #54: lucky
# attempt: 5
# word #55: rouse
# attempt: 5
# word #56: dwell
# attempt: 5
# word #57: gnash
# attempt: 3
# word #58: birch
# attempt: 4
# word #59: giddy
# attempt: 3
# word #60: await
# attempt: 4
# word #61: onion
# attempt: 3
# word #62: space
# attempt: 4
# word #63: bride
# attempt: 4
# word #64: audio
# attempt: 4
# word #65: caper
# attempt: 4
# word #66: write
# attempt: 7
# word #67: peace
# attempt: 3
# word #68: choir
# attempt: 3
# word #69: ocean
# attempt: 2
# word #70: wordy
# attempt: 5
# word #71: verve
# attempt: 5
# word #72: spice
# attempt: 4
# word #73: beach
# attempt: 4
# word #74: quest
# attempt: 3
# word #75: magma
# attempt: 4
# word #76: exact
# attempt: 3
# word #77: amiss
# attempt: 4
# word #78: scrub
# attempt: 5
# word #79: index
# attempt: 4
# word #80: snaky
# attempt: 4
# word #81: wrath
# attempt: 2
# word #82: quick
# attempt: 5
# word #83: hello
# attempt: 3
# word #84: empty
# attempt: 3
# word #85: lover
# attempt: 5
# word #86: bully
# attempt: 4
# word #87: brook
# attempt: 4
# word #88: polyp
# attempt: 5
# word #89: anode
# attempt: 4
# word #90: chart
# attempt: 6
# word #91: party
# attempt: 5
# word #92: beget
# attempt: 4
# word #93: tenth
# attempt: 4
# word #94: style
# attempt: 4
# word #95: bathe
# attempt: 4
# word #96: curly
# attempt: 4
# word #97: ethos
# attempt: 4
# word #98: disco
# attempt: 3
# word #99: heart
# attempt: 3
# word #100: wheel
# attempt: 5
# word #101: hobby
# attempt: 6
# word #102: whale
# attempt: 5
# word #103: froze
# attempt: 3
# word #104: burly
# attempt: 5
# word #105: flank
# attempt: 3
# word #106: tonic
# attempt: 3
# word #107: flyer
# attempt: 4
# word #108: droop
# attempt: 4
# word #109: topaz
# attempt: 4
# word #110: crone
# attempt: 5
# word #111: fiend
# attempt: 3
# word #112: barge
# attempt: 5
# word #113: whirl
# attempt: 5
# word #114: earth
# attempt: 3
# word #115: folly
# attempt: 4
# word #116: enter
# attempt: 2
# word #117: cower
# attempt: 4
# word #118: donut
# attempt: 4
# word #119: windy
# attempt: 4
# word #120: venom
# attempt: 4
# word #121: irate
# attempt: 4
# word #122: hotel
# attempt: 2
# word #123: mossy
# attempt: 4
# word #124: bleep
# attempt: 4
# word #125: straw
# attempt: 5
# word #126: diner
# attempt: 3
# word #127: tract
# attempt: 3
# word #128: about
# attempt: 5
# word #129: guest
# attempt: 4
# word #130: rodeo
# attempt: 3
# word #131: grand
# attempt: 4
# word #132: covet
# attempt: 3
# word #133: taste
# attempt: 3
# word #134: crane
# attempt: 5
# word #135: frost
# attempt: 3
# word #136: kazoo
# attempt: 6
# word #137: shyly
# attempt: 5
# word #138: ranch
# attempt: 4
# word #139: strap
# attempt: 3
# word #140: maybe
# attempt: 4
# word #141: crime
# attempt: 4
# word #142: plunk
# attempt: 3
# word #143: wrong
# attempt: 5
# word #144: guard
# attempt: 4
# word #145: again
# attempt: 6
# word #146: balsa
# attempt: 4
# word #147: crumb
# attempt: 4
# word #148: hater
# attempt: 4
# word #149: scout
# attempt: 6
# word #150: ennui
# attempt: 3
# word #151: beast
# attempt: 4
# word #152: nanny
# attempt: 4
# word #153: humid
# attempt: 4
# word #154: jazzy
# attempt: 8
# word #155: agile
# attempt: 4
# word #156: kneel
# attempt: 4
# word #157: mouse
# attempt: 5
# word #158: skimp
# attempt: 4
# word #159: ramen
# attempt: 4
# word #160: swine
# attempt: 5
# word #161: bagel
# attempt: 3
# word #162: utter
# attempt: 3
# word #163: clerk
# attempt: 4
# word #164: igloo
# attempt: 4
# word #165: brash
# attempt: 4
# word #166: flask
# attempt: 3
# word #167: grief
# attempt: 3
# word #168: shorn
# attempt: 3
# word #169: plank
# attempt: 6
# word #170: latte
# attempt: 4
# word #171: canoe
# attempt: 4
# word #172: scarf
# attempt: 3
# word #173: acrid
# attempt: 4
# word #174: snack
# attempt: 4
# word #175: broom
# attempt: 5
# word #176: ethic
# attempt: 3
# word #177: cocoa
# attempt: 4
# word #178: aglow
# attempt: 4
# word #179: ghoul
# attempt: 4
# word #180: anger
# attempt: 3
# word #181: below
# attempt: 4
# word #182: guppy
# attempt: 4
# word #183: horde
# attempt: 5
# word #184: sulky
# attempt: 5
# word #185: range
# attempt: 3
# word #186: plaza
# attempt: 5
# word #187: cedar
# attempt: 4
# word #188: circa
# attempt: 4
# word #189: logic
# attempt: 4
# word #190: metro
# attempt: 3
# word #191: joker
# attempt: 3
# word #192: ditto
# attempt: 2
# word #193: unzip
# attempt: 4
# word #194: broke
# attempt: 6
# word #195: kayak
# attempt: 3
# word #196: plate
# attempt: 4
# word #197: thump
# attempt: 4
# word #198: hound
# attempt: 3
# word #199: whiff
# attempt: 4
# word #200: dwelt
# attempt: 4
# word #201: agony
# attempt: 3
# word #202: thief
# attempt: 2
# word #203: carat
# attempt: 4
# word #204: borax
# attempt: 4
# word #205: qualm
# attempt: 5
# word #206: under
# attempt: 4
# word #207: snafu
# attempt: 4
# word #208: ledge
# attempt: 4
# word #209: locus
# attempt: 3
# word #210: leafy
# attempt: 3
# word #211: smash
# attempt: 6
# word #212: ratio
# attempt: 3
# word #213: flora
# attempt: 2
# word #214: stock
# attempt: 5
# word #215: march
# attempt: 4
# word #216: every
# attempt: 4
# word #217: bread
# attempt: 4
# word #218: beset
# attempt: 3
# word #219: hurry
# attempt: 4
# word #220: guano
# attempt: 3
# word #221: untie
# attempt: 2
# word #222: voter
# attempt: 2
# word #223: grout
# attempt: 4
# word #224: staid
# attempt: 6
# word #225: duvet
# attempt: 4
# word #226: tough
# attempt: 4
# word #227: glove
# attempt: 4
# word #228: credo
# attempt: 4
# word #229: yacht
# attempt: 4
# word #230: mealy
# attempt: 4
# word #231: cider
# attempt: 4
# word #232: sweep
# attempt: 3
# word #233: surly
# attempt: 6
# word #234: blame
# attempt: 6
# word #235: birth
# attempt: 4
# word #236: email
# attempt: 4
# word #237: revel
# attempt: 5
# word #238: where
# attempt: 5
# word #239: regal
# attempt: 4
# word #240: horse
# attempt: 5
# word #241: pinky
# attempt: 4
# word #242: toxic
# attempt: 3
# word #243: trend
# attempt: 3
# word #244: squat
# attempt: 4
# word #245: above
# attempt: 4
# word #246: moose
# attempt: 5
# word #247: polka
# attempt: 4
# word #248: worse
# attempt: 4
# word #249: syrup
# attempt: 3
# word #250: fifty
# attempt: 3
# word #251: arbor
# attempt: 6
# word #252: vague
# attempt: 4
# word #253: riper
# attempt: 8
# word #254: ruddy
# attempt: 3
# word #255: sweat
# attempt: 3
# word #256: kiosk
# attempt: 5
# word #257: avail
# attempt: 5
# word #258: cache
# attempt: 3
# word #259: magic
# attempt: 3
# word #260: salsa
# attempt: 4
# word #261: sound
# attempt: 3
# word #262: usage
# attempt: 4
# word #263: giant
# attempt: 3
# word #264: debug
# attempt: 5
# word #265: heady
# attempt: 4
# word #266: stage
# attempt: 6
# word #267: flail
# attempt: 5
# word #268: apple
# attempt: 5
# word #269: ninth
# attempt: 3
# word #270: dance
# attempt: 3
# word #271: unlit
# attempt: 3
# word #272: tasty
# attempt: 5
# word #273: shirk
# attempt: 5
# word #274: scold
# attempt: 3
# word #275: cross
# attempt: 5
# word #276: crave
# attempt: 5
# word #277: fishy
# attempt: 4
# word #278: flirt
# attempt: 3
# word #279: worry
# attempt: 5
# word #280: beefy
# attempt: 3
# word #281: maize
# attempt: 4
# word #282: count
# attempt: 5
# word #283: elude
# attempt: 4
# word #284: matey
# attempt: 3
# word #285: blurb
# attempt: 3
# word #286: alter
# attempt: 5
# word #287: mucky
# attempt: 4
# word #288: chard
# attempt: 4
# word #289: adopt
# attempt: 3
# word #290: frock
# attempt: 3
# word #291: spire
# attempt: 3
# word #292: koala
# attempt: 4
# word #293: human
# attempt: 4
# word #294: leapt
# attempt: 3
# word #295: sedan
# attempt: 4
# word #296: grimy
# attempt: 4
# word #297: pixie
# attempt: 5
# word #298: opera
# attempt: 3
# word #299: lemon
# attempt: 4
# word #300: belie
# attempt: 5
# word #301: sleek
# attempt: 5
# word #302: layer
# attempt: 4
# word #303: antic
# attempt: 2
# word #304: skirt
# attempt: 3
# word #305: whine
# attempt: 4
# word #306: manly
# attempt: 4
# word #307: molar
# attempt: 4
# word #308: havoc
# attempt: 3
# word #309: impel
# attempt: 5
# word #310: condo
# attempt: 3
# word #311: judge
# attempt: 5
# word #312: extra
# attempt: 3
# word #313: poise
# attempt: 4
# word #314: aorta
# attempt: 5
# word #315: excel
# attempt: 5
# word #316: lunar
# attempt: 3
# word #317: third
# attempt: 4
# word #318: slate
# attempt: 4
# word #319: taper
# attempt: 4
# word #320: chord
# attempt: 4
# word #321: probe
# attempt: 6
# word #322: rival
# attempt: 4
# word #323: usual
# attempt: 4
# word #324: spoke
# attempt: 4
# word #325: apply
# attempt: 3
# word #326: naive
# attempt: 4
# word #327: knock
# attempt: 6
# word #328: braid
# attempt: 5
# word #329: infer
# attempt: 3
# word #330: joust
# attempt: 3
# word #331: amber
# attempt: 3
# word #332: woken
# attempt: 3
# word #333: adore
# attempt: 3
# word #334: torso
# attempt: 2
# word #335: chafe
# attempt: 3
# word #336: eject
# attempt: 3
# word #337: study
# attempt: 4
# word #338: undue
# attempt: 4
# word #339: tepid
# attempt: 3
# word #340: happy
# attempt: 4
# word #341: clean
# attempt: 3
# word #342: itchy
# attempt: 4
# word #343: feast
# attempt: 3
# word #344: drive
# attempt: 5
# word #345: prime
# attempt: 3
# word #346: axiom
# attempt: 4
# word #347: brave
# attempt: 5
# word #348: avert
# attempt: 5
# word #349: glyph
# attempt: 4
# word #350: there
# attempt: 4
# word #351: baker
# attempt: 3
# word #352: snarl
# attempt: 4
# word #353: maple
# attempt: 4
# word #354: inane
# attempt: 5
# word #355: valet
# attempt: 5
# word #356: medal
# attempt: 4
# word #357: unite
# attempt: 3
# word #358: rainy
# attempt: 4
# word #359: spell
# attempt: 4
# word #360: begin
# attempt: 4
# word #361: stale
# attempt: 4
# word #362: dream
# attempt: 4
# word #363: photo
# attempt: 5
# word #364: aloud
# attempt: 4
# word #365: inept
# attempt: 4
# word #366: piney
# attempt: 4
# word #367: aptly
# attempt: 3
# word #368: waltz
# attempt: 5
# word #369: libel
# attempt: 3
# word #370: sneak
# attempt: 3
# word #371: carry
# attempt: 5
# word #372: flout
# attempt: 3
# word #373: foggy
# attempt: 5
# word #374: fault
# attempt: 4
# word #375: mummy
# attempt: 6
# word #376: spiel
# attempt: 6
# word #377: grove
# attempt: 4
# word #378: denim
# attempt: 4
# word #379: quirk
# attempt: 5
# word #380: exist
# attempt: 4
# word #381: stein
# attempt: 2
# word #382: spade
# attempt: 6
# word #383: catch
# attempt: 5
# word #384: floor
# attempt: 4
# word #385: equal
# attempt: 4
# word #386: ionic
# attempt: 4
# word #387: valid
# attempt: 4
# word #388: enjoy
# attempt: 4
# word #389: howdy
# attempt: 6
# word #390: vigor
# attempt: 4
# word #391: dandy
# attempt: 6
# word #392: sloth
# attempt: 5
# word #393: marsh
# attempt: 5
# word #394: bough
# attempt: 5
# word #395: sting
# attempt: 4
# word #396: twine
# attempt: 3
# word #397: leave
# attempt: 4
# word #398: scorn
# attempt: 4
# word #399: scald
# attempt: 6
# word #400: usurp
# attempt: 5
# word #401: soggy
# attempt: 4
# word #402: brisk
# attempt: 3
# word #403: admit
# attempt: 3
# word #404: grate
# attempt: 7
# word #405: glory
# attempt: 4
# word #406: saint
# attempt: 3
# word #407: recap
# attempt: 4
# word #408: alike
# attempt: 4
# word #409: trice
# attempt: 4
# word #410: stick
# attempt: 5
# word #411: chute
# attempt: 4
# word #412: parer
# attempt: 4
# word #413: doubt
# attempt: 5
# word #414: thyme
# attempt: 4
# word #415: alpha
# attempt: 5
# word #416: booze
# attempt: 4
# word #417: tibia
# attempt: 3
# word #418: lofty
# attempt: 3
# word #419: theme
# attempt: 5
# word #420: class
# attempt: 5
# word #421: leery
# attempt: 3
# word #422: taunt
# attempt: 8
# word #423: whoop
# attempt: 4
# word #424: inter
# attempt: 2
# word #425: gully
# attempt: 5
# word #426: charm
# attempt: 5
# word #427: fungi
# attempt: 3
# word #428: prize
# attempt: 5
# word #429: onset
# attempt: 2
# word #430: chief
# attempt: 3
# word #431: gauze
# attempt: 5
# word #432: ruder
# attempt: 6
# word #433: irony
# attempt: 3
# word #434: clown
# attempt: 4
# word #435: needy
# attempt: 4
# word #436: woven
# attempt: 5
# word #437: merit
# attempt: 4
# word #438: waste
# attempt: 6
# word #439: treat
# attempt: 5
# word #440: shrug
# attempt: 4
# word #441: twang
# attempt: 4
# word #442: twice
# attempt: 4
# word #443: gruel
# attempt: 3
# word #444: poker
# attempt: 3
# word #445: khaki
# attempt: 4
# word #446: hunky
# attempt: 2
# word #447: label
# attempt: 4
# word #448: glean
# attempt: 3
# word #449: cling
# attempt: 4
# word #450: patty
# attempt: 6
# word #451: unfit
# attempt: 3
# word #452: smear
# attempt: 3
# word #453: alien
# attempt: 3
# word #454: buggy
# attempt: 5
# word #455: rhyme
# attempt: 3
# word #456: youth
# attempt: 4
# word #457: coyly
# attempt: 4
# word #458: quart
# attempt: 3
# word #459: cramp
# attempt: 4
# word #460: bluff
# attempt: 4
# word #461: upset
# attempt: 4
# word #462: stomp
# attempt: 3
# word #463: motto
# attempt: 4
# word #464: cinch
# attempt: 4
# word #465: elope
# attempt: 4
# word #466: power
# attempt: 7
# word #467: midge
# attempt: 4
# word #468: tryst
# attempt: 4
# word #469: aphid
# attempt: 4
# word #470: trite
# attempt: 4
# word #471: angry
# attempt: 4
# word #472: flock
# attempt: 4
# word #473: wacky
# attempt: 5
# word #474: roomy
# attempt: 3
# word #475: wedge
# attempt: 4
# word #476: liver
# attempt: 6
# word #477: bland
# attempt: 6
# word #478: night
# attempt: 4
# word #479: madam
# attempt: 2
# word #480: berth
# attempt: 3
# word #481: stead
# attempt: 3
# word #482: voice
# attempt: 5
# word #483: agape
# attempt: 4
# word #484: fluff
# attempt: 3
# word #485: field
# attempt: 3
# word #486: sever
# attempt: 5
# word #487: lilac
# attempt: 5
# word #488: egret
# attempt: 4
# word #489: pinto
# attempt: 3
# word #490: hutch
# attempt: 5
# word #491: gawky
# attempt: 4
# word #492: droll
# attempt: 5
# word #493: retro
# attempt: 3
# word #494: rusty
# attempt: 3
# word #495: beady
# attempt: 5
# word #496: smite
# attempt: 2
# word #497: brink
# attempt: 4
# word #498: awful
# attempt: 3
# word #499: gloat
# attempt: 4
# word #500: input
# attempt: 4
# word #501: loser
# attempt: 5
# word #502: cacao
# attempt: 3
# word #503: blown
# attempt: 6
# word #504: apron
# attempt: 5
# word #505: primo
# attempt: 4
# word #506: atone
# attempt: 3
# word #507: donor
# attempt: 4
# word #508: float
# attempt: 4
# word #509: goose
# attempt: 3
# word #510: piety
# attempt: 3
# word #511: girth
# attempt: 4
# word #512: trait
# attempt: 5
# word #513: flood
# attempt: 3
# word #514: gloom
# attempt: 4
# word #515: depth
# attempt: 3
# word #516: froth
# attempt: 3
# word #517: phase
# attempt: 4
# word #518: showy
# attempt: 4
# word #519: creak
# attempt: 6
# word #520: manor
# attempt: 4
# word #521: atoll
# attempt: 4
# word #522: bayou
# attempt: 3
# word #523: crept
# attempt: 5
# word #524: tiara
# attempt: 5
# word #525: asset
# attempt: 4
# word #526: vouch
# attempt: 5
# word #527: album
# attempt: 3
# word #528: hinge
# attempt: 4
# word #529: money
# attempt: 3
# word #530: scrap
# attempt: 3
# word #531: gamer
# attempt: 4
# word #532: glass
# attempt: 5
# word #533: scour
# attempt: 5
# word #534: being
# attempt: 4
# word #535: delve
# attempt: 4
# word #536: yield
# attempt: 5
# word #537: metal
# attempt: 4
# word #538: tipsy
# attempt: 4
# word #539: slung
# attempt: 4
# word #540: farce
# attempt: 3
# word #541: gecko
# attempt: 3
# word #542: fetus
# attempt: 4
# word #543: shine
# attempt: 5
# word #544: canny
# attempt: 3
# word #545: midst
# attempt: 4
# word #546: badge
# attempt: 4
# word #547: homer
# attempt: 3
# word #548: train
# attempt: 2
# word #549: hairy
# attempt: 5
# word #550: story
# attempt: 5
# word #551: forgo
# attempt: 3
# word #552: larva
# attempt: 3
# word #553: trash
# attempt: 3
# word #554: zesty
# attempt: 5
# word #555: shown
# attempt: 6
# word #556: heist
# attempt: 4
# word #557: askew
# attempt: 4
# word #558: inert
# attempt: 4
# word #559: olive
# attempt: 3
# word #560: plant
# attempt: 3
# word #561: oxide
# attempt: 3
# word #562: cargo
# attempt: 4
# word #563: foyer
# attempt: 2
# word #564: flair
# attempt: 3
# word #565: ample
# attempt: 4
# word #566: cheek
# attempt: 4
# word #567: shame
# attempt: 8
# word #568: mince
# attempt: 5
# word #569: chunk
# attempt: 4
# word #570: royal
# attempt: 5
# word #571: squad
# attempt: 3
# word #572: black
# attempt: 5
# word #573: stair
# attempt: 4
# word #574: scare
# attempt: 4
# word #575: foray
# attempt: 3
# word #576: comma
# attempt: 4
# word #577: natal
# attempt: 2
# word #578: shawl
# attempt: 5
# word #579: fewer
# attempt: 5
# word #580: trope
# attempt: 4
# word #581: snout
# attempt: 3
# word #582: lowly
# attempt: 4
# word #583: stove
# attempt: 4
# word #584: shall
# attempt: 3
# word #585: found
# attempt: 2
# word #586: nymph
# attempt: 4
# word #587: epoxy
# attempt: 5
# word #588: depot
# attempt: 3
# word #589: chest
# attempt: 4
# word #590: purge
# attempt: 4
# word #591: their
# attempt: 4
# word #592: slosh
# attempt: 5
# word #593: renew
# attempt: 4
# word #594: allow
# attempt: 4
# word #595: saute
# attempt: 5
# word #596: movie
# attempt: 3
# word #597: cater
# attempt: 3
# word #598: tease
# attempt: 4
# word #599: smelt
# attempt: 4
# word #600: focus
# attempt: 4
# word #601: today
# attempt: 4
# word #602: watch
# attempt: 9
# word #603: lapse
# attempt: 4
# word #604: month
# attempt: 4
# word #605: sweet
# attempt: 3
# word #606: hoard
# attempt: 4
# word #607: cloth
# attempt: 3
# word #608: brine
# attempt: 5
# word #609: ahead
# attempt: 3
# word #610: mourn
# attempt: 4
# word #611: nasty
# attempt: 3
# word #612: rupee
# attempt: 4
# word #613: choke
# attempt: 4
# word #614: chant
# attempt: 3
# word #615: spill
# attempt: 4
# word #616: vivid
# attempt: 3
# word #617: bloke
# attempt: 5
# word #618: trove
# attempt: 3
# word #619: thorn
# attempt: 3
# word #620: other
# attempt: 2
# word #621: tacit
# attempt: 4
# word #622: swill
# attempt: 5
# word #623: dodge
# attempt: 4
# word #624: shake
# attempt: 5
# word #625: caulk
# attempt: 5
# word #626: agora
# attempt: 4
# word #627: aroma
# attempt: 5
# word #628: cynic
# attempt: 4
# word #629: robin
# attempt: 4
# word #630: ultra
# attempt: 4
# word #631: ulcer
# attempt: 5
# word #632: pause
# attempt: 3
# word #633: humor
# attempt: 4
# word #634: frame
# attempt: 3
# word #635: elder
# attempt: 4
# word #636: skill
# attempt: 3
# word #637: aloft
# attempt: 3
# word #638: pleat
# attempt: 5
# word #639: shard
# attempt: 6
# word #640: moist
# attempt: 6
# word #641: those
# attempt: 2
# word #642: light
# attempt: 7
# word #643: wrung
# attempt: 4
# word #644: could
# attempt: 3
# word #645: perky
# attempt: 4
# word #646: mount
# attempt: 3
# word #647: whack
# attempt: 4
# word #648: sugar
# attempt: 4
# word #649: knoll
# attempt: 4
# word #650: crimp
# attempt: 4
# word #651: wince
# attempt: 4
# word #652: prick
# attempt: 5
# word #653: robot
# attempt: 4
# word #654: point
# attempt: 3
# word #655: proxy
# attempt: 4
# word #656: shire
# attempt: 5
# word #657: solar
# attempt: 3
# word #658: panic
# attempt: 4
# word #659: tangy
# attempt: 3
# word #660: abbey
# attempt: 5
# word #661: favor
# attempt: 3
# word #662: drink
# attempt: 4
# word #663: query
# attempt: 4
# word #664: gorge
# attempt: 3
# word #665: crank
# attempt: 3
# word #666: slump
# attempt: 4
# word #667: banal
# attempt: 4
# word #668: tiger
# attempt: 5
# word #669: siege
# attempt: 6
# word #670: truss
# attempt: 4
# word #671: boost
# attempt: 4
# word #672: rebus
# attempt: 4
# word #673: unify
# attempt: 3
# word #674: troll
# attempt: 4
# word #675: tapir
# attempt: 3
# word #676: aside
# attempt: 5
# word #677: ferry
# attempt: 4
# word #678: acute
# attempt: 3
# word #679: picky
# attempt: 5
# word #680: weary
# attempt: 3
# word #681: gripe
# attempt: 3
# word #682: craze
# attempt: 4
# word #683: pluck
# attempt: 4
# word #684: brake
# attempt: 6
# word #685: baton
# attempt: 2
# word #686: champ
# attempt: 4
# word #687: peach
# attempt: 6
# word #688: using
# attempt: 4
# word #689: trace
# attempt: 3
# word #690: vital
# attempt: 5
# word #691: sonic
# attempt: 5
# word #692: masse
# attempt: 3
# word #693: conic
# attempt: 4
# word #694: viral
# attempt: 5
# word #695: rhino
# attempt: 4
# word #696: break
# attempt: 4
# word #697: triad
# attempt: 4
# word #698: epoch
# attempt: 4
# word #699: usher
# attempt: 6
# word #700: exult
# attempt: 5
# word #701: grime
# attempt: 5
# word #702: cheat
# attempt: 5
# word #703: solve
# attempt: 3
# word #704: bring
# attempt: 6
# word #705: prove
# attempt: 6
# word #706: store
# attempt: 3
# word #707: tilde
# attempt: 4
# word #708: clock
# attempt: 5
# word #709: wrote
# attempt: 3
# word #710: retch
# attempt: 4
# word #711: perch
# attempt: 5
# word #712: rouge
# attempt: 4
# word #713: radio
# attempt: 4
# word #714: surer
# attempt: 3
# word #715: finer
# attempt: 2
# word #716: vodka
# attempt: 4
# word #717: heron
# attempt: 3
# word #718: chill
# attempt: 3
# word #719: gaudy
# attempt: 5
# word #720: pithy
# attempt: 3
# word #721: smart
# attempt: 4
# word #722: badly
# attempt: 4
# word #723: rogue
# attempt: 3
# word #724: group
# attempt: 4
# word #725: fixer
# attempt: 5
# word #726: groin
# attempt: 2
# word #727: duchy
# attempt: 5
# word #728: coast
# attempt: 3
# word #729: blurt
# attempt: 3
# word #730: pulpy
# attempt: 5
# word #731: altar
# attempt: 4
# word #732: great
# attempt: 5
# word #733: briar
# attempt: 3
# word #734: click
# attempt: 4
# word #735: gouge
# attempt: 4
# word #736: world
# attempt: 4
# word #737: erode
# attempt: 5
# word #738: boozy
# attempt: 5
# word #739: dozen
# attempt: 3
# word #740: fling
# attempt: 3
# word #741: growl
# attempt: 6
# word #742: abyss
# attempt: 3
# word #743: steed
# attempt: 6
# word #744: enema
# attempt: 4
# word #745: jaunt
# attempt: 7
# word #746: comet
# attempt: 4
# word #747: tweed
# attempt: 5
# word #748: pilot
# attempt: 4
# word #749: dutch
# attempt: 4
# word #750: belch
# attempt: 5
# word #751: ought
# attempt: 3
# word #752: dowry
# attempt: 4
# word #753: thumb
# attempt: 4
# word #754: hyper
# attempt: 3
# word #755: hatch
# attempt: 3
# word #756: alone
# attempt: 4
# word #757: motor
# attempt: 3
# word #758: aback
# attempt: 5
# word #759: guild
# attempt: 4
# word #760: kebab
# attempt: 4
# word #761: spend
# attempt: 3
# word #762: fjord
# attempt: 4
# word #763: essay
# attempt: 5
# word #764: spray
# attempt: 3
# word #765: spicy
# attempt: 4
# word #766: agate
# attempt: 5
# word #767: salad
# attempt: 5
# word #768: basic
# attempt: 4
# word #769: moult
# attempt: 4
# word #770: corny
# attempt: 4
# word #771: forge
# attempt: 3
# word #772: civic
# attempt: 4
# word #773: islet
# attempt: 4
# word #774: labor
# attempt: 6
# word #775: gamma
# attempt: 4
# word #776: lying
# attempt: 5
# word #777: audit
# attempt: 3
# word #778: round
# attempt: 3
# word #779: loopy
# attempt: 4
# word #780: lusty
# attempt: 3
# word #781: golem
# attempt: 4
# word #782: goner
# attempt: 2
# word #783: greet
# attempt: 3
# word #784: start
# attempt: 4
# word #785: lapel
# attempt: 5
# word #786: biome
# attempt: 4
# word #787: parry
# attempt: 4
# word #788: shrub
# attempt: 4
# word #789: front
# attempt: 2
# word #790: wooer
# attempt: 5
# word #791: totem
# attempt: 2
# word #792: flick
# attempt: 4
# word #793: delta
# attempt: 4
# word #794: bleed
# attempt: 3
# word #795: argue
# attempt: 5
# word #796: swirl
# attempt: 3
# word #797: error
# attempt: 4
# word #798: agree
# attempt: 3
# word #799: offal
# attempt: 2
# word #800: flume
# attempt: 4
# word #801: crass
# attempt: 5
# word #802: panel
# attempt: 3
# word #803: stout
# attempt: 6
# word #804: bribe
# attempt: 4
# word #805: drain
# attempt: 5
# word #806: yearn
# attempt: 3
# word #807: print
# attempt: 5
# word #808: seedy
# attempt: 5
# word #809: ivory
# attempt: 4
# word #810: belly
# attempt: 6
# word #811: stand
# attempt: 4
# word #812: first
# attempt: 3
# word #813: forth
# attempt: 2
# word #814: booby
# attempt: 5
# word #815: flesh
# attempt: 4
# word #816: unmet
# attempt: 4
# word #817: linen
# attempt: 3
# word #818: maxim
# attempt: 3
# word #819: pound
# attempt: 5
# word #820: mimic
# attempt: 4
# word #821: spike
# attempt: 4
# word #822: cluck
# attempt: 5
# word #823: crate
# attempt: 4
# word #824: digit
# attempt: 5
# word #825: repay
# attempt: 5
# word #826: sower
# attempt: 4
# word #827: crazy
# attempt: 4
# word #828: adobe
# attempt: 5
# word #829: outdo
# attempt: 2
# word #830: trawl
# attempt: 5
# word #831: whelp
# attempt: 4
# word #832: unfed
# attempt: 2
# word #833: paper
# attempt: 6
# word #834: staff
# attempt: 3
# word #835: croak
# attempt: 6
# word #836: helix
# attempt: 2
# word #837: floss
# attempt: 4
# word #838: pride
# attempt: 4
# word #839: batty
# attempt: 7
# word #840: react
# attempt: 3
# word #841: marry
# attempt: 6
# word #842: abase
# attempt: 5
# word #843: colon
# attempt: 3
# word #844: stool
# attempt: 5
# word #845: crust
# attempt: 5
# word #846: fresh
# attempt: 3
# word #847: death
# attempt: 5
# word #848: major
# attempt: 4
# word #849: feign
# attempt: 2
# word #850: abate
# attempt: 5
# word #851: bench
# attempt: 3
# word #852: quiet
# attempt: 5
# word #853: grade
# attempt: 6
# word #854: stink
# attempt: 3
# word #855: karma
# attempt: 6
# word #856: model
# attempt: 4
# word #857: dwarf
# attempt: 3
# word #858: heath
# attempt: 3
# word #859: serve
# attempt: 5
# word #860: naval
# attempt: 4
# word #861: evade
# attempt: 5
# word #862: focal
# attempt: 4
# word #863: blush
# attempt: 4
# word #864: awake
# attempt: 6
# word #865: humph
# attempt: 4
# word #866: sissy
# attempt: 5
# word #867: rebut
# attempt: 4
# word #868: cigar
# attempt: 5

# %%
# Print average attempts for training and testing
avg_training_attempts = sum(training_attempts) / len(training_attempts)
avg_testing_attempts = sum(testing_attempts) / len(testing_attempts)

print(f"Average attempts during training: {avg_training_attempts:.2f}")
print(f"Average attempts during testing: {avg_testing_attempts:.2f}")
# Out:
# Average attempts during training: 4.01
# Average attempts during testing: 4.02

# %%
import matplotlib.pyplot as plt

unique_elements, counts = [], []

for item in set(training_attempts):
    unique_elements.append(item)
    counts.append(training_attempts.count(item))

# Create a bar graph
bars = plt.bar(unique_elements, counts, color='#ec443c')
for i, bar in enumerate(bars):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, f'{yval}', ha='center', va='bottom', fontsize=8)

# Add data labels
# for i, count in enumerate(counts):
#     plt.text(unique_elements[i], count + 0.1, str(count), ha='center', va='bottom')

# Add labels and title
plt.xlabel('Elements')
plt.ylabel('Frequency')
plt.title('Frequency of Attempts in Training')

# Show the plot
plt.show()

unique_elements, counts = [], []

for item in set(testing_attempts):
    unique_elements.append(item)
    counts.append(testing_attempts.count(item))

# Create a bar graph
bars = plt.bar(unique_elements, counts, color='#ec443c')
for i, bar in enumerate(bars):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, f'{yval}', ha='center', va='bottom', fontsize=8)

# Add data labels
# for i, count in enumerate(counts):
#     plt.text(unique_elements[i], count + 0.1, str(count), ha='center', va='bottom')

# Add labels and title
plt.xlabel('Elements')
plt.ylabel('Frequency')
plt.title('Frequency of Attempts in Testing')

# Show the plot
plt.show()

# %%
# Main game loop
attempts = 0
previous_guesses = []

print("Let's Play Wordle!")
print("Please think of a word and provide feedback as follows:")
print("0 for MISS, 1 for MISPLACED, and 2 for EXACT.")

while True:
    attempts += 1
    guess = bayesian_choose_word(possible_words, previous_guesses)
    
    # First step to set the first word
    if attempts == 1: guess = random.choice(great_starting_word)
    
    feedback = []
    while True:
        try:
            feedback_input = input(f"Attempt {attempts}: {guess} - Enter feedback (0/1/2): ")
            feedback_input = [int(f) for f in feedback_input]
            if all(f in [0, 1, 2] for f in feedback_input) and len(feedback_input) == 5:
                for i in range(len(feedback_input)):
                    if feedback_input[i] == 0:
                        feedback.append("⬛")
                    elif feedback_input[i] == 1:
                        feedback.append("🟨")
                    elif feedback_input[i] == 2:
                        feedback.append("🟩")
            else:
                print("Invalid feedback. Please provide feedback as 0, 1, or 2.")
        except ValueError:
            print("Invalid feedback. Please provide feedback as 0, 1, or 2.")
        if len(feedback) == len(feedback_input):
            feedback = "".join(feedback)
            break
    previous_guesses.append((guess, feedback))
    print(feedback)

    if feedback.count("🟩") == 5:
        print(f"Congratulations! The word was '{guess}'. It took {attempts} attempts to guess.")
        break
# Out:
# Let's Play Wordle!
# Please think of a word and provide feedback as follows:
# 0 for MISS, 1 for MISPLACED, and 2 for EXACT.
# Invalid feedback. Please provide feedback as 0, 1, or 2.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\shid0\Desktop\play_wordle_reduced.ipynb Cell 11 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/shid0/Desktop/play_wordle_reduced.ipynb#X13sZmlsZQ%3D%3D?line=8'>9</a> while True:
#      <a href='vscode-notebook-cell:/c%3A/Users/shid0/Desktop/play_wordle_reduced.ipynb#X13sZmlsZQ%3D%3D?line=9'>10</a>     attempts += 1
# ---> <a href='vscode-notebook-cell:/c%3A/Users/shid0/Desktop/play_wordle_reduced.ipynb#X13sZmlsZQ%3D%3D?line=10'>11</a>     guess = bayesian_choose_word(possible_words, previous_guesses)
#      <a href='vscode-notebook-cell:/c%3A/Users/shid0/Desktop/play_wordle_reduced.ipynb#X13sZmlsZQ%3D%3D?line=12'>13</a>     # First step to set the first word
#      <a href='vscode-notebook-cell:/c%3A/Users/shid0/Desktop/play_wordle_reduced.ipynb#X13sZmlsZQ%3D%3D?line=13'>14</a>     if attempts == 1: guess = random.choice(great_starting_word)
#
# c:\Users\shid0\Desktop\play_wordle_reduced.ipynb Cell 11 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/shid0/Desktop/play_wordle_reduced.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> for word in possible_words:
#       <a href='vscode-notebook-cell:/c%3A/Users/shid0/Desktop/play_wordle_reduced.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a>     for guess, feedback in previous_guesses:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/shid0/Desktop/play_wordle_reduced.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a>         guess_feedback = evaluate_guess(word, guess)
#       <a href='vscode-notebook-cell:/c%3A/Users/shid0/Desktop/play_wordle_reduced.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a>         if guess_feedback == feedback:
#       <a href='vscode-notebook-cell:/c%3A/Users/shid0/Desktop/play_wordle_reduced.ipynb#X13sZmlsZQ%3D%3D?line=7'>8</a>             scores[word] += 1
#
# c:\Users\shid0\Desktop\play_wordle_reduced.ipynb Cell 11 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/shid0/Desktop/play_wordle_reduced.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a> remaining_secret_letters = list(secret_word)
#       <a href='vscode-notebook-cell:/c%3A/Users/shid0/Desktop/play_wordle_reduced.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> # First, check exact matches (greens)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/shid0/Desktop/play_wordle_reduced.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a> for i, (g1, g2) in enumerate(zip(secret_word, guess_copy)):
#       <a href='vscode-notebook-cell:/c%3A/Users/shid0/Desktop/play_wordle_reduced.ipynb#X13sZmlsZQ%3D%3D?line=7'>8</a>     if g1 == g2:
#       <a href='vscode-notebook-cell:/c%3A/Users/shid0/Desktop/play_wordle_reduced.ipynb#X13sZmlsZQ%3D%3D?line=8'>9</a>         feedback.append("🟩")
#
# TypeError: 'NoneType' object is not iterable
